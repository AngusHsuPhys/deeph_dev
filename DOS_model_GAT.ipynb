# %%
import os
from typing import Union, Tuple
from math import ceil, sqrt
from torch.utils.data import SubsetRandomSampler, DataLoader

import torch
from torch import nn
import torch.nn.functional as F
from torch import package
from torch.nn import MSELoss, L1Loss, SmoothL1Loss
import torch.optim as optim
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.norm import LayerNorm, PairNorm, InstanceNorm
from torch_geometric.typing import PairTensor, Adj, OptTensor, Size
from torch_geometric.nn.inits import glorot, zeros
from torch_geometric.utils import softmax
from torch_geometric.nn.models.dimenet import BesselBasisLayer
from torch_scatter import scatter_add, scatter
import numpy as np
from scipy.special import comb
from deeph.data import HData

from deeph.from_se3_transformer import SphericalHarmonics
from deeph.from_schnetpack import GaussianBasis
from deeph.from_PyG_future import GraphNorm, DiffGroupNorm
from deeph.from_HermNet import RBF, cosine_cutoff, ShiftedSoftplus, _eps
from inspect import signature

from deeph.utils import LossRecord

# %%
class GAT_Crystal(MessagePassing):
    def __init__(self, in_features, out_features, edge_dim, heads, concat=False, normalization: str = None,
                 dropout=0, bias=True, **kwargs):
        super(GAT_Crystal, self).__init__(node_dim=0, aggr='add', flow='target_to_source', **kwargs)
        self.in_features = in_features
        self.out_features = out_features
        self.heads = heads
        self.concat = concat
        self.dropout = dropout
        self.neg_slope = 0.2
        self.prelu = nn.PReLU()
        self.bn1 = nn.BatchNorm1d(heads)
        self.W = nn.Parameter(torch.Tensor(in_features + edge_dim, heads * out_features))
        self.att = nn.Parameter(torch.Tensor(1, heads, 2 * out_features))

        if bias and concat:
            self.bias = nn.Parameter(torch.Tensor(heads * out_features))
        elif bias and not concat:
            self.bias = nn.Parameter(torch.Tensor(out_features))
        else:
            self.register_parameter('bias', None)

        self.normalization = normalization
        if self.normalization == 'BatchNorm':
            self.bn = nn.BatchNorm1d(out_features, track_running_stats=True)
        elif self.normalization == 'LayerNorm':
            self.ln = LayerNorm(out_features)
        elif self.normalization == 'PairNorm':
            self.pn = PairNorm(out_features)
        elif self.normalization == 'InstanceNorm':
            self.instance_norm = InstanceNorm(out_features)
        elif self.normalization == 'GraphNorm':
            self.gn = GraphNorm(out_features)
        elif self.normalization == 'DiffGroupNorm':
            self.group_norm = DiffGroupNorm(out_features, 128)
        elif self.normalization is None:
            pass
        else:
            raise ValueError('Unknown normalization function: {}'.format(normalization))

        self.reset_parameters()

    def reset_parameters(self):
        glorot(self.W)
        glorot(self.att)
        zeros(self.bias)

    def forward(self, x, edge_index, edge_attr, batch, distance):
        out = self.propagate(edge_index, x=x, edge_attr=edge_attr)

        if self.normalization == 'BatchNorm':
            out = self.bn(out)
        elif self.normalization == 'LayerNorm':
            out = self.ln(out, batch)
        elif self.normalization == 'PairNorm':
            out = self.pn(out, batch)
        elif self.normalization == 'InstanceNorm':
            out = self.instance_norm(out, batch)
        elif self.normalization == 'GraphNorm':
            out = self.gn(out, batch)
        elif self.normalization == 'DiffGroupNorm':
            out = self.group_norm(out)
        return out

    def message(self, edge_index_i, x_i, x_j, size_i, index, ptr: OptTensor, edge_attr):
        x_i = torch.cat([x_i, edge_attr], dim=-1)
        x_j = torch.cat([x_j, edge_attr], dim=-1)

        x_i = F.softplus(torch.matmul(x_i, self.W))
        x_j = F.softplus(torch.matmul(x_j, self.W))
        x_i = x_i.view(-1, self.heads, self.out_features)
        x_j = x_j.view(-1, self.heads, self.out_features)

        alpha = F.softplus((torch.cat([x_i, x_j], dim=-1) * self.att).sum(dim=-1))
        alpha = F.softplus(self.bn1(alpha))

        alpha = softmax(alpha, index, ptr, size_i)

        alpha = F.dropout(alpha, p=self.dropout, training=self.training)

        return x_j * alpha.view(-1, self.heads, 1)

    def update(self, aggr_out, x):
        if self.concat is True:
            aggr_out = aggr_out.view(-1, self.heads * self.out_features)
        else:
            aggr_out = aggr_out.mean(dim=1)
        if self.bias is not None:  aggr_out = aggr_out + self.bias
        return aggr_out

# %%
class MPLayer(nn.Module):
    def __init__(self, in_atom_fea_len, in_edge_fea_len, out_edge_fea_len, if_exp, if_edge_update, normalization,
                 atom_update_net, gauss_stop, output_layer=False):
        super(MPLayer, self).__init__()
        self.cgconv = GAT_Crystal(
            in_features=in_atom_fea_len,
            out_features=in_atom_fea_len,
            edge_dim=in_edge_fea_len,
            heads=3,
            normalization=normalization
        )

        self.if_edge_update = if_edge_update
        self.atom_update_net = atom_update_net
        if if_edge_update:
            if output_layer:
                self.e_lin = nn.Sequential(nn.Linear(in_edge_fea_len + in_atom_fea_len * 2, 128),
                                           nn.SiLU(),
                                           nn.Linear(128, out_edge_fea_len),
                                           )
            else:
                self.e_lin = nn.Sequential(nn.Linear(in_edge_fea_len + in_atom_fea_len * 2, 128),
                                           nn.SiLU(),
                                           nn.Linear(128, out_edge_fea_len),
                                           nn.SiLU(),
                                           )

    def forward(self, atom_fea, edge_idx, edge_fea, batch, distance, edge_vec):
        atom_fea = self.cgconv(atom_fea, edge_idx, edge_fea, batch, distance)
        atom_fea_s = atom_fea
        if self.if_edge_update:
            row, col = edge_idx
            edge_fea = self.e_lin(torch.cat([atom_fea_s[row], atom_fea_s[col], edge_fea], dim=-1))
            return atom_fea, edge_fea
        else:
            return atom_fea

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
from torch_scatter import scatter_add
from math import ceil

class LCMPLayer(nn.Module):
    def __init__(self, in_atom_fea_len, in_edge_fea_len, out_edge_fea_len, num_l,
                 normalization: str = None, bias: bool = True, if_exp: bool = False):
        super(LCMPLayer, self).__init__()
        self.in_atom_fea_len = in_atom_fea_len
        self.normalization = normalization
        self.if_exp = if_exp

        self.lin_f = nn.Linear(in_atom_fea_len * 2 + in_edge_fea_len, in_atom_fea_len, bias=bias)
        self.lin_s = nn.Linear(in_atom_fea_len * 2 + in_edge_fea_len, in_atom_fea_len, bias=bias)
        self.bn = nn.BatchNorm1d(in_atom_fea_len, track_running_stats=True)

        self.e_lin = nn.Sequential(
            nn.Linear(in_edge_fea_len + in_atom_fea_len * 2 - num_l ** 2, 128),
            nn.SiLU(),
            nn.Linear(128, out_edge_fea_len)
        )
        
        self.final_linear = nn.Linear(out_edge_fea_len, 999)  # New linear layer to reduce to a single number
        
        # Attention mechanism components
        self.attention_net = nn.Linear(out_edge_fea_len, 999)

        self.reset_parameters()

    def reset_parameters(self):
        self.lin_f.reset_parameters()
        self.lin_s.reset_parameters()
        if self.normalization == 'BatchNorm':
            self.bn.reset_parameters()
        self.final_linear.reset_parameters()
        self.attention_net.reset_parameters()

    def forward(self, atom_fea, edge_fea, sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index, distance,
                huge_structure, output_final_layer_neuron):
        if huge_structure:
            sub_graph_batch_num = 8

            sub_graph_num = sub_atom_idx.shape[0]
            sub_graph_batch_size = ceil(sub_graph_num / sub_graph_batch_num)

            num_edge = edge_fea.shape[0]
            vf_update = torch.zeros((num_edge * 2, self.in_atom_fea_len)).type(torch.get_default_dtype()).to(atom_fea.device)
            for sub_graph_batch_index in range(sub_graph_batch_num):
                if sub_graph_batch_index == sub_graph_batch_num - 1:
                    sub_graph_idx = slice(sub_graph_batch_size * sub_graph_batch_index, sub_graph_num)
                else:
                    sub_graph_idx = slice(sub_graph_batch_size * sub_graph_batch_index,
                                          sub_graph_batch_size * (sub_graph_batch_index + 1))

                sub_atom_idx_batch = sub_atom_idx[sub_graph_idx]
                sub_edge_idx_batch = sub_edge_idx[sub_graph_idx]
                sub_edge_ang_batch = sub_edge_ang[sub_graph_idx]
                sub_index_batch = sub_index[sub_graph_idx]

                z = torch.cat([atom_fea[sub_atom_idx_batch][:, 0, :], atom_fea[sub_atom_idx_batch][:, 1, :],
                               edge_fea[sub_edge_idx_batch], sub_edge_ang_batch], dim=-1)
                out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))

                if self.if_exp:
                    sigma = 3
                    n = 2
                    out = out * torch.exp(-distance[sub_edge_idx_batch] ** n / sigma ** n / 2).view(-1, 1)

                vf_update += scatter_add(out, sub_index_batch, dim=0, dim_size=num_edge * 2)

            if self.normalization == 'BatchNorm':
                vf_update = self.bn(vf_update)
            vf_update = vf_update.reshape(num_edge, 2, -1)
            if output_final_layer_neuron != '':
                final_layer_neuron = torch.cat([vf_update[:, 0, :], vf_update[:, 1, :], edge_fea],
                                               dim=-1).detach().cpu().numpy()
                np.save(os.path.join(output_final_layer_neuron, 'final_layer_neuron.npy'), final_layer_neuron)
            out = self.e_lin(torch.cat([vf_update[:, 0, :], vf_update[:, 1, :], edge_fea], dim=-1))
            # Compute attention scores and apply attention weights
            attention_logits = self.attention_net(out)
            attention_weights = F.softmax(attention_logits, dim=0)
            weighted_out = out * attention_weights
            aggregated_feature = weighted_out.sum(dim=0, keepdim=True)

            # Final linear layer to produce a single number
            # out = self.final_linear(aggregated_feature)
            out = aggregated_feature.squeeze(0)

            return out

        num_edge = edge_fea.shape[0]
        z = torch.cat(
            [atom_fea[sub_atom_idx][:, 0, :], atom_fea[sub_atom_idx][:, 1, :], edge_fea[sub_edge_idx], sub_edge_ang],
            dim=-1)
        out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))

        if self.if_exp:
            sigma = 3
            n = 2
            out = out * torch.exp(-distance[sub_edge_idx] ** n / sigma ** n / 2).view(-1, 1)

        out = scatter_add(out, sub_index, dim=0)
        if self.normalization == 'BatchNorm':
            out = self.bn(out)
        out = out.reshape(num_edge, 2, -1)
        if output_final_layer_neuron != '':
            final_layer_neuron = torch.cat([out[:, 0, :], out[:, 1, :], edge_fea], dim=-1).detach().cpu().numpy()
            np.save(os.path.join(output_final_layer_neuron, 'final_layer_neuron.npy'), final_layer_neuron)
        out = self.e_lin(torch.cat([out[:, 0, :], out[:, 1, :], edge_fea], dim=-1))

        # Compute attention scores and apply attention weights
        attention_logits = self.attention_net(out)
        attention_weights = F.softmax(attention_logits, dim=0)
        weighted_out = out * attention_weights
        aggregated_feature = weighted_out.sum(dim=0, keepdim=True)

        # Final linear layer to produce a single number
        # out = self.final_linear(aggregated_feature)
        out = aggregated_feature.squeeze(0)
        return out

# %%
class MultipleLinear(nn.Module):
    def __init__(self, num_linear: int, in_fea_len: int, out_fea_len: int, bias: bool = True) -> None:
        super(MultipleLinear, self).__init__()
        self.num_linear = num_linear
        self.out_fea_len = out_fea_len
        self.weight = nn.Parameter(torch.Tensor(num_linear, in_fea_len, out_fea_len))
        if bias:
            self.bias = nn.Parameter(torch.Tensor(num_linear, out_fea_len))
        else:
            self.register_parameter('bias', None)
        # self.ln = LayerNorm(num_linear * out_fea_len)
        # self.gn = GraphNorm(out_fea_len)
        self.reset_parameters()

    def reset_parameters(self) -> None:
        nn.init.kaiming_uniform_(self.weight, a=sqrt(5))
        if self.bias is not None:
            fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.weight)
            bound = 1 / sqrt(fan_in)
            nn.init.uniform_(self.bias, -bound, bound)

    def forward(self, input: torch.Tensor, batch_edge: torch.Tensor) -> torch.Tensor:
        output = torch.matmul(input, self.weight)

        if self.bias is not None:
            output += self.bias[:, None, :]
        return output

# %%
class HGNN(nn.Module):
    def __init__(self, num_species, in_atom_fea_len, in_edge_fea_len, num_orbital,
                 distance_expansion, gauss_stop, if_exp, if_MultipleLinear, if_edge_update, if_lcmp,
                 normalization, atom_update_net, separate_onsite,
                 trainable_gaussians, type_affine, num_l=5):
        super(HGNN, self).__init__()
        self.num_species = num_species
        self.embed = nn.Embedding(num_species + 5, in_atom_fea_len)

        # pair-type aware affine
        if type_affine:
            self.type_affine = nn.Embedding(
                num_species ** 2, 2,
                _weight=torch.stack([torch.ones(num_species ** 2), torch.zeros(num_species ** 2)], dim=-1)
            )
        else:
            self.type_affine = None

        if if_edge_update or (if_edge_update is False and if_lcmp is False):
            distance_expansion_len = in_edge_fea_len
        else:
            distance_expansion_len = in_edge_fea_len - num_l ** 2
        if distance_expansion == 'GaussianBasis':
            self.distance_expansion = GaussianBasis(
                0.0, gauss_stop, distance_expansion_len, trainable=trainable_gaussians
            )

        self.if_MultipleLinear = if_MultipleLinear
        self.if_edge_update = if_edge_update
        self.if_lcmp = if_lcmp
        self.atom_update_net = atom_update_net
        self.separate_onsite = separate_onsite

        if if_lcmp == True:
            mp_output_edge_fea_len = in_edge_fea_len - num_l ** 2
        else:
            assert if_MultipleLinear == False
            mp_output_edge_fea_len = in_edge_fea_len

        if if_edge_update == True:
            self.mp1 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp2 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp3 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp4 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp5 = MPLayer(in_atom_fea_len, in_edge_fea_len, mp_output_edge_fea_len, if_exp, if_edge_update,
                               normalization, atom_update_net, gauss_stop)
        else:
            self.mp1 = MPLayer(in_atom_fea_len, distance_expansion_len, None, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp2 = MPLayer(in_atom_fea_len, distance_expansion_len, None, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp3 = MPLayer(in_atom_fea_len, distance_expansion_len, None, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp4 = MPLayer(in_atom_fea_len, distance_expansion_len, None, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp5 = MPLayer(in_atom_fea_len, distance_expansion_len, None, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)

        if if_lcmp == True:
            if self.if_MultipleLinear == True:
                self.lcmp = LCMPLayer(in_atom_fea_len, in_edge_fea_len, 32, num_l, if_exp=if_exp)
                self.multiple_linear1 = MultipleLinear(num_orbital, 32, 16)
                self.multiple_linear2 = MultipleLinear(num_orbital, 16, 1)
            else:
                self.lcmp = LCMPLayer(in_atom_fea_len, in_edge_fea_len, num_orbital, num_l, if_exp=if_exp)
        else:
            self.mp_output = MPLayer(in_atom_fea_len, in_edge_fea_len, num_orbital, if_exp, if_edge_update=True,
                                     normalization=normalization, atom_update_net=atom_update_net,
                                     gauss_stop=gauss_stop, output_layer=True)


    def forward(self, atom_attr, edge_idx, edge_attr, batch,
                sub_atom_idx=None, sub_edge_idx=None, sub_edge_ang=None, sub_index=None,
                huge_structure=False, output_final_layer_neuron=''):
        batch_edge = batch[edge_idx[0]]
        atom_fea0 = self.embed(atom_attr)
        distance = edge_attr[:, 0]
        edge_vec = edge_attr[:, 1:4] - edge_attr[:, 4:7]
        if self.type_affine is None:
            edge_fea0 = self.distance_expansion(distance)
        else:
            affine_coeff = self.type_affine(self.num_species * atom_attr[edge_idx[0]] + atom_attr[edge_idx[1]])
            edge_fea0 = self.distance_expansion(distance * affine_coeff[:, 0] + affine_coeff[:, 1])

        if self.if_edge_update == True:
            atom_fea, edge_fea = self.mp1(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea, edge_fea = self.mp2(atom_fea, edge_idx, edge_fea, batch, distance, edge_vec)
            atom_fea0, edge_fea0 = atom_fea0 + atom_fea, edge_fea0 + edge_fea
            atom_fea, edge_fea = self.mp3(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea, edge_fea = self.mp4(atom_fea, edge_idx, edge_fea, batch, distance, edge_vec)
            atom_fea0, edge_fea0 = atom_fea0 + atom_fea, edge_fea0 + edge_fea
            atom_fea, edge_fea = self.mp5(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)

            if self.if_lcmp == True:
                if self.atom_update_net == 'PAINN':
                    atom_fea_s = atom_fea.node_fea_s
                else:
                    atom_fea_s = atom_fea
                out = self.lcmp(atom_fea_s, edge_fea, sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index, distance,
                                huge_structure, output_final_layer_neuron)
            else:
                atom_fea, edge_fea = self.mp_output(atom_fea, edge_idx, edge_fea, batch, distance, edge_vec)
                out = edge_fea
        else:
            atom_fea = self.mp1(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea = self.mp2(atom_fea, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea0 = atom_fea0 + atom_fea
            atom_fea = self.mp3(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea = self.mp4(atom_fea, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea0 = atom_fea0 + atom_fea
            atom_fea = self.mp5(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)

            if self.atom_update_net == 'PAINN':
                atom_fea_s = atom_fea.node_fea_s
            else:
                atom_fea_s = atom_fea
            if self.if_lcmp == True:
                out = self.lcmp(atom_fea_s, edge_fea0, sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index, distance,
                                huge_structure, output_final_layer_neuron)
            else:
                atom_fea, edge_fea = self.mp_output(atom_fea, edge_idx, edge_fea0, batch, distance, edge_vec)
                out = edge_fea

        if self.if_MultipleLinear == True:
            out = self.multiple_linear1(F.silu(out), batch_edge)
            out = self.multiple_linear2(F.silu(out), batch_edge)
            out = out.T

        return out

# %%
dataset = HData(
    raw_data_dir='/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/processed',
    graph_dir='/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/graph',
    interface='h5',
    target='hamiltonian',
    dataset_name='Bi_soc',
    multiprocessing=0,
    radius='-1.0',
    max_num_nbr=0,
    num_l='5',
    max_element='-1',
    create_from_DFT='True',
    if_lcmp_graph='True',
    separate_onsite='False',
    new_sp=False,
    default_dtype_torch=torch.get_default_dtype(),
)
# Out:
# Graph data file: HGraph-h5-Bi_soc-5l-FromDFT.pkl
# Use existing graph data file
# Atomic types: [83]
# Finish loading the processed 80 structures (spinful: True, the number of atomic types: 1), cost 1 seconds

# %%
import configparser
import json
from deeph.kernel import DeepHKernel
# Initialize the ConfigParser
config = configparser.ConfigParser()

# Read the configuration file
config.read('/home/t.hsu/deeph_dev/default.ini')

config.read('/home/t.hsu/deeph_dev/train.ini')  # Replace 'config.ini' with your actual file name
kernel = DeepHKernel(config)
_, _, _, _ = kernel.get_dataset()
num_species = len(dataset.info["index_to_Z"])
orbital = json.loads(config.get('basic', 'orbital'))
num_orbital = len(orbital)
spinful = True
if_lcmp = True
separate_onsite = False
if spinful:
    out_fea_len = num_orbital * 8
else:
    out_fea_len = num_orbital
print('DeepH', out_fea_len)
out_fea_len = 999
print('DOS', out_fea_len)
# Out:
# /home/t.hsu/miniconda3/envs/gpu_test/lib/python3.10/site-packages/deeph/kernel.py:53: UserWarning: Unable to copy scripts
#   warnings.warn("Unable to copy scripts")
# ====== CONFIG ======
# [basic]
# graph_dir=/home/t.hsu/example2/work_dir/dataset/graph
# save_dir=/home/t.hsu/example2/work_dir/trained_model
# raw_dir=/home/t.hsu/example2/work_dir/dataset/processed
# dataset_name=Bi_soc
# only_get_graph=False
# interface=h5
# target=hamiltonian
# disable_cuda=False
# device=cuda:0
# num_threads=64
# save_to_time_folder=False
# save_csv=False
# tb_writer=True
# seed=42
# multiprocessing=0
# orbital=[{"83 83": [0, 0]}, {"83 83": [0, 1]}, {"83 83": [0, 2]}, {"83 83": [0, 3]}, {"83 83": [0, 4]}, {"83 83": [0, 5]}, {"83 83": [0, 6]}, {"83 83": [0, 7]}, {"83 83": [0, 8]}, {"83 83": [0, 9]}, {"83 83": [0, 10]}, {"83 83": [0, 11]}, {"83 83": [0, 12]}, {"83 83": [0, 13]}, {"83 83": [0, 14]}, {"83 83": [0, 15]}, {"83 83": [0, 16]}, {"83 83": [0, 17]}, {"83 83": [0, 18]}, {"83 83": [1, 0]}, {"83 83": [1, 1]}, {"83 83": [1, 2]}, {"83 83": [1, 3]}, {"83 83": [1, 4]}, {"83 83": [1, 5]}, {"83 83": [1, 6]}, {"83 83": [1, 7]}, {"83 83": [1, 8]}, {"83 83": [1, 9]}, {"83 83": [1, 10]}, {"83 83": [1, 11]}, {"83 83": [1, 12]}, {"83 83": [1, 13]}, {"83 83": [1, 14]}, {"83 83": [1, 15]}, {"83 83": [1, 16]}, {"83 83": [1, 17]}, {"83 83": [1, 18]}, {"83 83": [2, 0]}, {"83 83": [2, 1]}, {"83 83": [2, 2]}, {"83 83": [2, 3]}, {"83 83": [2, 4]}, {"83 83": [2, 5]}, {"83 83": [2, 6]}, {"83 83": [2, 7]}, {"83 83": [2, 8]}, {"83 83": [2, 9]}, {"83 83": [2, 10]}, {"83 83": [2, 11]}, {"83 83": [2, 12]}, {"83 83": [2, 13]}, {"83 83": [2, 14]}, {"83 83": [2, 15]}, {"83 83": [2, 16]}, {"83 83": [2, 17]}, {"83 83": [2, 18]}, {"83 83": [3, 0]}, {"83 83": [3, 1]}, {"83 83": [3, 2]}, {"83 83": [3, 3]}, {"83 83": [3, 4]}, {"83 83": [3, 5]}, {"83 83": [3, 6]}, {"83 83": [3, 7]}, {"83 83": [3, 8]}, {"83 83": [3, 9]}, {"83 83": [3, 10]}, {"83 83": [3, 11]}, {"83 83": [3, 12]}, {"83 83": [3, 13]}, {"83 83": [3, 14]}, {"83 83": [3, 15]}, {"83 83": [3, 16]}, {"83 83": [3, 17]}, {"83 83": [3, 18]}, {"83 83": [4, 0]}, {"83 83": [4, 1]}, {"83 83": [4, 2]}, {"83 83": [4, 3]}, {"83 83": [4, 4]}, {"83 83": [4, 5]}, {"83 83": [4, 6]}, {"83 83": [4, 7]}, {"83 83": [4, 8]}, {"83 83": [4, 9]}, {"83 83": [4, 10]}, {"83 83": [4, 11]}, {"83 83": [4, 12]}, {"83 83": [4, 13]}, {"83 83": [4, 14]}, {"83 83": [4, 15]}, {"83 83": [4, 16]}, {"83 83": [4, 17]}, {"83 83": [4, 18]}, {"83 83": [5, 0]}, {"83 83": [5, 1]}, {"83 83": [5, 2]}, {"83 83": [5, 3]}, {"83 83": [5, 4]}, {"83 83": [5, 5]}, {"83 83": [5, 6]}, {"83 83": [5, 7]}, {"83 83": [5, 8]}, {"83 83": [5, 9]}, {"83 83": [5, 10]}, {"83 83": [5, 11]}, {"83 83": [5, 12]}, {"83 83": [5, 13]}, {"83 83": [5, 14]}, {"83 83": [5, 15]}, {"83 83": [5, 16]}, {"83 83": [5, 17]}, {"83 83": [5, 18]}, {"83 83": [6, 0]}, {"83 83": [6, 1]}, {"83 83": [6, 2]}, {"83 83": [6, 3]}, {"83 83": [6, 4]}, {"83 83": [6, 5]}, {"83 83": [6, 6]}, {"83 83": [6, 7]}, {"83 83": [6, 8]}, {"83 83": [6, 9]}, {"83 83": [6, 10]}, {"83 83": [6, 11]}, {"83 83": [6, 12]}, {"83 83": [6, 13]}, {"83 83": [6, 14]}, {"83 83": [6, 15]}, {"83 83": [6, 16]}, {"83 83": [6, 17]}, {"83 83": [6, 18]}, {"83 83": [7, 0]}, {"83 83": [7, 1]}, {"83 83": [7, 2]}, {"83 83": [7, 3]}, {"83 83": [7, 4]}, {"83 83": [7, 5]}, {"83 83": [7, 6]}, {"83 83": [7, 7]}, {"83 83": [7, 8]}, {"83 83": [7, 9]}, {"83 83": [7, 10]}, {"83 83": [7, 11]}, {"83 83": [7, 12]}, {"83 83": [7, 13]}, {"83 83": [7, 14]}, {"83 83": [7, 15]}, {"83 83": [7, 16]}, {"83 83": [7, 17]}, {"83 83": [7, 18]}, {"83 83": [8, 0]}, {"83 83": [8, 1]}, {"83 83": [8, 2]}, {"83 83": [8, 3]}, {"83 83": [8, 4]}, {"83 83": [8, 5]}, {"83 83": [8, 6]}, {"83 83": [8, 7]}, {"83 83": [8, 8]}, {"83 83": [8, 9]}, {"83 83": [8, 10]}, {"83 83": [8, 11]}, {"83 83": [8, 12]}, {"83 83": [8, 13]}, {"83 83": [8, 14]}, {"83 83": [8, 15]}, {"83 83": [8, 16]}, {"83 83": [8, 17]}, {"83 83": [8, 18]}, {"83 83": [9, 0]}, {"83 83": [9, 1]}, {"83 83": [9, 2]}, {"83 83": [9, 3]}, {"83 83": [9, 4]}, {"83 83": [9, 5]}, {"83 83": [9, 6]}, {"83 83": [9, 7]}, {"83 83": [9, 8]}, {"83 83": [9, 9]}, {"83 83": [9, 10]}, {"83 83": [9, 11]}, {"83 83": [9, 12]}, {"83 83": [9, 13]}, {"83 83": [9, 14]}, {"83 83": [9, 15]}, {"83 83": [9, 16]}, {"83 83": [9, 17]}, {"83 83": [9, 18]}, {"83 83": [10, 0]}, {"83 83": [10, 1]}, {"83 83": [10, 2]}, {"83 83": [10, 3]}, {"83 83": [10, 4]}, {"83 83": [10, 5]}, {"83 83": [10, 6]}, {"83 83": [10, 7]}, {"83 83": [10, 8]}, {"83 83": [10, 9]}, {"83 83": [10, 10]}, {"83 83": [10, 11]}, {"83 83": [10, 12]}, {"83 83": [10, 13]}, {"83 83 ...
# o_component=H
# energy_component=summation
# max_element=-1
# statistics=False
# normalizer=False
# boxcox=False
#
# [graph]
# radius=-1.0
# max_num_nbr=0
# create_from_dft=True
# if_lcmp_graph=True
# separate_onsite=False
# new_sp=False
#
# [train]
# epochs=2
# pretrained=
# resume=
# train_ratio=0.6
# val_ratio=0.2
# test_ratio=0.2
# early_stopping_loss=0.0
# early_stopping_loss_epoch=[0.000000, 500]
# revert_then_decay=True
# revert_threshold=30
# revert_decay_epoch=[250, 2500]
# revert_decay_gamma=[0.2, 0.5]
# clip_grad=True
# clip_grad_value=4.2
# switch_sgd=False
# switch_sgd_lr=1e-4
# switch_sgd_epoch=-1
#
# [hyperparameter]
# batch_size=1
# dtype=float32
# optimizer=adam
# learning_rate=0.001
# lr_scheduler=
# lr_milestones=[]
# momentum=0.9
# weight_decay=0
# criterion=MaskMSELoss
# retain_edge_fea=True
# lambda_eij=0.0
# lambda_ei=0.1
# lambda_etot=0.0
#
# [network]
# atom_fea_len=64
# edge_fea_len=128
# gauss_stop=8.5
# num_l=5
# aggr=add
# distance_expansion=GaussianBasis
# if_exp=True
# if_multiplelinear=False
# if_edge_update=True
# if_lcmp=True
# normalization=LayerNorm
# atom_update_net=CGConv
# trainable_gaussians=False
# type_affine=False
#
# Graph data file: HGraph-h5-Bi_soc-5l-FromDFT.pkl
# Use existing graph data file
# Atomic types: [83]
# Finish loading the processed 82 structures (spinful: True, the number of atomic types: 1), cost 1 seconds

# %%
model_kwargs = dict(
    n_elements=num_species,
    num_species=num_species,
    in_atom_fea_len=config.getint('network', 'atom_fea_len'),
    in_vfeats=config.getint('network', 'atom_fea_len'),
    in_edge_fea_len=config.getint('network', 'edge_fea_len'),
    in_efeats=config.getint('network', 'edge_fea_len'),
    out_edge_fea_len=out_fea_len,
    out_efeats=out_fea_len,
    num_orbital=out_fea_len,
    distance_expansion=config.get('network', 'distance_expansion'),
    gauss_stop=config.getfloat('network', 'gauss_stop'),
    cutoff=config.getfloat('network', 'gauss_stop'),
    if_exp=config.getboolean('network', 'if_exp'),
    if_MultipleLinear=config.getboolean('network', 'if_MultipleLinear'),
    if_edge_update=config.getboolean('network', 'if_edge_update'),
    if_lcmp=if_lcmp,
    normalization=config.get('network', 'normalization'),
    atom_update_net=config.get('network', 'atom_update_net', fallback='CGConv'),
    separate_onsite=separate_onsite,
    num_l=config.getint('network', 'num_l'),
    trainable_gaussians=config.getboolean('network', 'trainable_gaussians', fallback=False),
    type_affine=config.getboolean('network', 'type_affine', fallback=False),
    if_fc_out=False,
)
parameter_list = list(signature(HGNN.__init__).parameters.keys())
current_parameter_list = list(model_kwargs.keys())
for k in current_parameter_list:
    if k not in parameter_list:
        model_kwargs.pop(k)
if 'num_elements' in parameter_list:
    model_kwargs['num_elements'] = config.getint('basic', 'max_element') + 1
model = HGNN(**model_kwargs)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print("The model you built has: %d parameters" % params)

# %%
device = torch.device(config.get('basic', 'device') if torch.cuda.is_available() else 'cpu')
model.to(device)
# torch.cuda.is_available()
# Out:
# number of train set: 49
# number of val set: 16
# number of test set: 16
# {'normalizer': False, 'boxcox': False}
# DeepH 2888
# DOS 999
# The model you built has: 2621025 parameters
# 80
# Data(
#   x=[36],
#   edge_index=[2, 1472],
#   edge_attr=[1472, 10],
#   stru_id='0',
#   term_mask=[1472],
#   term_real=[1472, 19, 19, 8],
#   atom_num_orbital=[36],
#   subgraph_dict={
#     subgraph_atom_idx=[121080, 2],
#     subgraph_edge_idx=[121080],
#     subgraph_edge_ang=[121080, 25],
#     subgraph_index=[121080],
#   },
#   spinful=[1]
# )
# Epoch 2: New best model saved with loss 2.7163
# Epoch 2: Average Loss = 2.7163
# Epoch 3: New best model saved with loss 0.4150
# Epoch 3: Average Loss = 0.4150
# Epoch 4: New best model saved with loss 0.4142
# Epoch 4: Average Loss = 0.4142
# Epoch 5: Average Loss = 0.4282
# Epoch 6: New best model saved with loss 0.3974
# Epoch 6: Average Loss = 0.3974
# Epoch 7: New best model saved with loss 0.3936
# Epoch 7: Average Loss = 0.3936
# Epoch 8: Average Loss = 0.4033
# Epoch 9: New best model saved with loss 0.3918
# Epoch 9: Average Loss = 0.3918
# Epoch 10: Average Loss = 0.4046
# Epoch 11: Average Loss = 0.4036
# Epoch 12: Average Loss = 0.4061
# Epoch 13: Average Loss = 0.3924
# Epoch 14: New best model saved with loss 0.3894
# Epoch 14: Average Loss = 0.3894
# Epoch 15: Average Loss = 0.3896
# Epoch 16: New best model saved with loss 0.3858
# Epoch 16: Average Loss = 0.3858
# Epoch 17: New best model saved with loss 0.3823
# Epoch 17: Average Loss = 0.3823
# Epoch 18: Average Loss = 0.4084
# Epoch 19: Average Loss = 0.3837
# Epoch 20: Average Loss = 0.3837
# Epoch 21: New best model saved with loss 0.3798
# Epoch 21: Average Loss = 0.3798
# Epoch 22: Average Loss = 0.3836
# Epoch 23: New best model saved with loss 0.3768
# Epoch 23: Average Loss = 0.3768
# Epoch 24: New best model saved with loss 0.3755
# Epoch 24: Average Loss = 0.3755
# Epoch 25: Average Loss = 0.3868
# Epoch 26: New best model saved with loss 0.3698
# Epoch 26: Average Loss = 0.3698
# Epoch 27: Average Loss = 0.3914
# Epoch 28: New best model saved with loss 0.3682
# Epoch 28: Average Loss = 0.3682
# Epoch 29: Average Loss = 0.3733
# Epoch 30: New best model saved with loss 0.3643
# Epoch 30: Average Loss = 0.3643
# Epoch 31: Average Loss = 0.3684
# Epoch 32: Average Loss = 0.3657
# Epoch 33: New best model saved with loss 0.3605
# Epoch 33: Average Loss = 0.3605
# Epoch 34: New best model saved with loss 0.3605
# Epoch 34: Average Loss = 0.3605
# Epoch 35: New best model saved with loss 0.3461
# Epoch 35: Average Loss = 0.3461
# Epoch 36: New best model saved with loss 0.3379
# Epoch 36: Average Loss = 0.3379
# Epoch 37: New best model saved with loss 0.3204
# Epoch 37: Average Loss = 0.3204
# Epoch 38: Average Loss = 0.3279
# Epoch 39: New best model saved with loss 0.3174
# Epoch 39: Average Loss = 0.3174
# Epoch 40: Average Loss = 0.3231
# Epoch 41: Average Loss = 0.3218
# Epoch 42: New best model saved with loss 0.3040
# Epoch 42: Average Loss = 0.3040
# Epoch 43: Average Loss = 0.3113
# Epoch 44: Average Loss = 0.3212
# Epoch 45: New best model saved with loss 0.2967
# Epoch 45: Average Loss = 0.2967
# Epoch 46: Average Loss = 0.3045
# Epoch 47: Average Loss = 0.3051
# Epoch 48: New best model saved with loss 0.2921
# Epoch 48: Average Loss = 0.2921
# Epoch 49: New best model saved with loss 0.2867
# Epoch 49: Average Loss = 0.2867
# Epoch 50: Average Loss = 0.2884
# Epoch 51: Average Loss = 0.2903
# Epoch 52: Average Loss = 0.2916
# Epoch 53: Average Loss = 0.2880
# Epoch 54: New best model saved with loss 0.2551
# Epoch 54: Average Loss = 0.2551
# Epoch 55: Average Loss = 0.2637
# Epoch 56: Average Loss = 0.2801
# Epoch 57: New best model saved with loss 0.2532
# Epoch 57: Average Loss = 0.2532
# Epoch 58: Average Loss = 0.2680
# Epoch 59: Average Loss = 0.2541
# Epoch 60: Average Loss = 0.2557
# Epoch 61: New best model saved with loss 0.2441
# Epoch 61: Average Loss = 0.2441
# Epoch 62: New best model saved with loss 0.2374
# Epoch 62: Average Loss = 0.2374
# Epoch 63: Average Loss = 0.2455
# Epoch 64: Average Loss = 0.2493
# Epoch 65: Average Loss = 0.2474
# Epoch 66: Average Loss = 0.2415
# Epoch 67: New best model saved with loss 0.2298
# Epoch 67: Average Loss = 0.2298
# Epoch 68: New best model saved with loss 0.2234
# Epoch 68: Average Loss = 0.2234
# Epoch 69: Average Loss = 0.2235
# Epoch 70: Average Loss = 0.2332
# Epoch 71: Average Loss = 0.2309
# Epoch 72: Average Loss = 0.2281
# Epoch 73: New best model saved with loss 0.2199
# Epoch 73: Average Loss = 0.2199
# Epoch 74: New best model saved with loss 0.2174
# Epoch 74: Average Loss = 0.2174
# Epoch 75: Average Loss = 0.2207
# Epoch 76: New best model saved with loss 0.2138
# Epoch 76: Average Loss = 0.2138
# Epoch 77: Average Loss = 0.2141
# Epoch 78: Average Loss = 0.2232
# Epoch 79: New best model saved with loss 0.2113
# Epoch 79: Average Loss = 0.2113
# Epoch 80: New best model saved with loss 0.2102
# Epoch 80: Average Loss = 0.2102
# Epoch 81: New best model saved with loss 0.2044
# Epoch 81: Average Loss = 0.2044
# Epoch 82: New best model saved with loss 0.2023
# Epoch 82: Average Loss = 0.2023
# Epoch 83: New best model saved with loss 0.1957
# Epoch 83: Average Loss = 0.1957
# Epoch 84: Average Loss = 0.2077
# Epoch 85: New best model saved with loss 0.1956
# Epoch 85: Average Loss = 0.1956
# Epoch 86: New best model saved with loss 0.1874
# Epoch 86: Average Loss = 0.1874
# Epoch 87: Average Loss = 0.2000
# Epoch 88: New best model saved with loss 0.1870
# Epoch 88: Average Loss = 0.1870
# Epoch 89: New best model saved with loss 0.1828
# Epoch 89: Average Loss = 0.1828
# Epoch 90: New best model saved with loss 0.1783
# Epoch 90: Average Loss = 0.1783
# Epoch 91: New best model saved with loss 0.1692
# Epoch 91: Average Loss = 0.1692
# Epoch 92: Average Loss = 0.1787
# Epoch 93: Average Loss = 0.1899
# Epoch 94: Average Loss = 0.1773
# Epoch 95: New best model saved with loss 0.1691
# Epoch 95: Average Loss = 0.1691
# Epoch 96: Average Loss = 0.1693
# Epoch 97: New best model saved with loss 0.1658
# Epoch 97: Average Loss = 0.1658
# Epoch 98: Average Loss = 0.1747
# Epoch 99: Average Loss = 0.1773
# Epoch 100: Average Loss = 0.1701
# Epoch 101: Average Loss = 0.1725
# Epoch 102: Average Loss = 0.1772
# Epoch 103: New best model saved with loss 0.1580
# Epoch 103: Average Loss = 0.1580
# Epoch 104: Average Loss = 0.1672
# Epoch 105: New best model saved with loss 0.1556
# Epoch 105: Average Loss = 0.1556
# Epoch 106: New best model saved with loss 0.1443
# Epoch 106: Average Loss = 0.1443
# Epoch 107: New best model saved with loss 0.1432
# Epoch 107: Average Loss = 0.1432
# Epoch 108: New best model saved with loss 0.1377
# Epoch 108: Average Loss = 0.1377
# Epoch 109: New best model saved with loss 0.1344
# Epoch 109: Average Loss = 0.1344
# Epoch 110: Average Loss = 0.1400
# Epoch 111: Average Loss = 0.1393
# Epoch 112: New best model saved with loss 0.1269
# Epoch 112: Average Loss = 0.1269
# Epoch 113: Average Loss = 0.1313
# Epoch 114: Average Loss = 0.1380
# Epoch 115: Average Loss = 0.1366
# Epoch 116: Average Loss = 0.1284
# Epoch 117: New best model saved with loss 0.1239
# Epoch 117: Average Loss = 0.1239
# Epoch 118: New best model saved with loss 0.1229
# Epoch 118: Average Loss = 0.1229
# Epoch 119: New best model saved with loss 0.1210
# Epoch 119: Average Loss = 0.1210
# Epoch 120: New best model saved with loss 0.1199
# Epoch 120: Average Loss = 0.1199
# Epoch 121: Average Loss = 0.1260
# Epoch 122: Average Loss = 0.1288
# Epoch 123: Average Loss = 0.1602
# Epoch 124: Average Loss = 0.1335
# Epoch 125: Average Loss = 0.1315
# Epoch 126: New best model saved with loss 0.1185
# Epoch 126: Average Loss = 0.1185
# Epoch 127: New best model saved with loss 0.1175
# Epoch 127: Average Loss = 0.1175
# Epoch 128: Average Loss = 0.1235
# Epoch 129: New best model saved with loss 0.1170
# Epoch 129: Average Loss = 0.1170
# Epoch 130: New best model saved with loss 0.1145
# Epoch 130: Average Loss = 0.1145
# Epoch 131: New best model saved with loss 0.1096
# Epoch 131: Average Loss = 0.1096
# Epoch 132: New best model saved with loss 0.1081
# Epoch 132: Average Loss = 0.1081
# Epoch 133: Average Loss = 0.1261
# Epoch 134: New best model saved with loss 0.1034
# Epoch 134: Average Loss = 0.1034
# Epoch 135: Average Loss = 0.1234
# Epoch 136: Average Loss = 0.1126
# Epoch 137: Average Loss = 0.1055
# Epoch 138: New best model saved with loss 0.1016
# Epoch 138: Average Loss = 0.1016
# Epoch 139: New best model saved with loss 0.1004
# Epoch 139: Average Loss = 0.1004
# Epoch 140: Average Loss = 0.1175
# Epoch 141: New best model saved with loss 0.0976
# Epoch 141: Average Loss = 0.0976
# Epoch 142: New best model saved with loss 0.0962
# Epoch 142: Average Loss = 0.0962
# Epoch 143: Average Loss = 0.1068
# Epoch 144: Average Loss = 0.1078
# Epoch 145: Average Loss = 0.1164
# Epoch 146: Average Loss = 0.0999
# Epoch 147: New best model saved with loss 0.0915
# Epoch 147: Average Loss = 0.0915
# Epoch 148: Average Loss = 0.0930
# Epoch 149: Average Loss = 0.0950
# Epoch 150: Average Loss = 0.1001
# Epoch 151: Average Loss = 0.1132
# Epoch 152: Average Loss = 0.1053
# Epoch 153: Average Loss = 0.1023
# Epoch 154: New best model saved with loss 0.0904
# Epoch 154: Average Loss = 0.0904
# Epoch 155: New best model saved with loss 0.0842
# Epoch 155: Average Loss = 0.0842
# Epoch 156: Average Loss = 0.0916
# Epoch 157: Average Loss = 0.1264
# Epoch 158: Average Loss = 0.1022
# Epoch 159: Average Loss = 0.0919
# Epoch 160: Average Loss = 0.0898
# Epoch 161: Average Loss = 0.0941
# Epoch 162: Average Loss = 0.0852
# Epoch 163: Average Loss = 0.0857
# Epoch 164: New best model saved with loss 0.0798
# Epoch 164: Average Loss = 0.0798
# Epoch 165: New best model saved with loss 0.0767
# Epoch 165: Average Loss = 0.0767
# Epoch 166: New best model saved with loss 0.0756
# Epoch 166: Average Loss = 0.0756
# Epoch 167: New best model saved with loss 0.0675
# Epoch 167: Average Loss = 0.0675
# Epoch 168: Average Loss = 0.0687
# Epoch 169: New best model saved with loss 0.0632
# Epoch 169: Average Loss = 0.0632
# Epoch 170: Average Loss = 0.0732
# Epoch 171: Average Loss = 0.0699
# Epoch 172: Average Loss = 0.0812
# Epoch 173: Average Loss = 0.0866
# Epoch 174: Average Loss = 0.0833
# Epoch 175: Average Loss = 0.0806
# Epoch 176: Average Loss = 0.0670
# Epoch 177: Average Loss = 0.0672
# Epoch 178: Average Loss = 0.0696
# Epoch 179: Average Loss = 0.0640
# Epoch 180: Average Loss = 0.0909
# Epoch 181: Average Loss = 0.0677
# Epoch 182: Average Loss = 0.0798
# Epoch 183: Average Loss = 0.1077
# Epoch 184: Average Loss = 0.0965
# Epoch 185: Average Loss = 0.0864
# Epoch 186: Average Loss = 0.0736
# Epoch 187: Average Loss = 0.0649
# Epoch 188: Average Loss = 0.0672
# Epoch 189: Average Loss = 0.0648
# Epoch 190: New best model saved with loss 0.0586
# Epoch 190: Average Loss = 0.0586
# Epoch 191: New best model saved with loss 0.0564
# Epoch 191: Average Loss = 0.0564
# Epoch 192: Average Loss = 0.0566
# Epoch 193: New best model saved with loss 0.0556
# Epoch 193: Average Loss = 0.0556
# Epoch 194: Average Loss = 0.0671
# Epoch 195: Average Loss = 0.0780
# Epoch 196: Average Loss = 0.0768
# Epoch 197: Average Loss = 0.0661
# Epoch 198: Average Loss = 0.0654
# Epoch 199: Average Loss = 0.0574
# Epoch 200: Average Loss = 0.0560
# Epoch 201: New best model saved with loss 0.0508
# Epoch 201: Average Loss = 0.0508
# Training complete. Best model saved as 'best_model.pth'.
# /tmp/ipykernel_7465/2723026121.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=12)
# HGNN(
#   (embed): Embedding(6, 64)
#   (distance_expansion): GaussianBasis()
#   (mp1): MPLayer(
#     (cgconv): GAT_Crystal()
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp2): MPLayer(
#     (cgconv): GAT_Crystal()
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp3): MPLayer(
#     (cgconv): GAT_Crystal()
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp4): MPLayer(
#     (cgconv): GAT_Crystal()
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp5): MPLayer(
#     (cgconv): GAT_Crystal()
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=103, bias=True)
#       (3): SiLU()
#     )
#   )
#   (lcmp): LCMPLayer(
#     (lin_f): Linear(in_features=256, out_features=64, bias=True)
#     (lin_s): Linear(in_features=256, out_features=64, bias=True)
#     (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (e_lin): Sequential(
#       (0): Linear(in_features=231, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=999, bias=True)
#     )
#     (final_linear): Linear(in_features=999, out_features=999, bias=True)
#     (attention_net): Linear(in_features=999, out_features=999, bias=True)
#   )
# )

# %%
def make_mask(dataset):
    spinful = True
    target = 'hamiltonian'
    num_orbital = kernel.num_orbital
    dataset_mask = []
    for i, data in enumerate(dataset):
        # filename = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(i)
        # aux = np.loadtxt(filename)

        # dos = torch.tensor(aux[:,1], dtype=torch.float32)  # Convert to tensor if not already
        # dos = dos.view(-1)
        Oij_value = data.term_real
        if data.term_real is not None:
            if_only_rc = False

        if spinful:
            out_fea_len = num_orbital * 8
            # out_fea_len = 999
            
        mask = torch.zeros(data.edge_attr.shape[0], out_fea_len, dtype=torch.int8)
        label = torch.zeros(data.edge_attr.shape[0], out_fea_len, dtype=torch.get_default_dtype())
        y = torch.zeros(data.edge_attr.shape[0], 999, dtype=torch.get_default_dtype())

        atomic_number_edge_i = kernel.index_to_Z[data.x[data.edge_index[0]]]
        atomic_number_edge_j = kernel.index_to_Z[data.x[data.edge_index[1]]]

        for index_out, orbital_dict in enumerate(kernel.orbital):
            for N_M_str, a_b in orbital_dict.items():
                # N_M, a_b means: H_{ia, jb} when the atomic number of atom i is N and the atomic number of atom j is M
                condition_atomic_number_i, condition_atomic_number_j = map(lambda x: int(x), N_M_str.split())
                condition_orbital_i, condition_orbital_j = a_b

                if spinful:
                    if target == 'phiVdphi':
                        raise NotImplementedError("Not yet have support for phiVdphi")
                    else:
                        mask[:, 8 * index_out:8 * (index_out + 1)] = torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )[:, None].repeat(1, 8)
                else:
                    if target == 'phiVdphi':
                        mask[:, 3 * index_out:3 * (index_out + 1)] += torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )[:, None].repeat(1, 3)
                    else:
                        mask[:, index_out] += torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )

                if if_only_rc == False:
                    if spinful:
                        if target == 'phiVdphi':
                            raise NotImplementedError
                        else:
                            label[:, 8 * index_out:8 * (index_out + 1)] = torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j].t(),
                                torch.zeros(8, data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            ).t()


                    else:
                        if target == 'phiVdphi':
                            label[:, 3 * index_out:3 * (index_out + 1)] = torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j].t(),
                                torch.zeros(3, data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            ).t()
                        else:
                            label[:, index_out] += torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j],
                                torch.zeros(data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            )
        assert len(torch.where((mask != 1) & (mask != 0))[0]) == 0
        mask = mask.bool()
        data.mask = mask
        del data.term_mask
        if if_only_rc == False:
            data.label = label
            data.y = y
            if target == 'hamiltonian' or target == 'density_matrix':
                del data.term_real
        dataset_mask.append(data)
    return dataset_mask

# %%
dataset_size = len(dataset)
print(dataset_size)
print(dataset[0])
dataset = make_mask(dataset)
# Iterating over the 81 graph.
# for i in range(len(dataset)):
#     print(i)
#     filename = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(i)
#     aux = np.loadtxt(filename)

#     # Extract the first and second columns
#     energy = aux[:, 0]
#     # dos = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())

#     # # aux2 = dataset[i].label[:,:len(dos)]
#     # dataset[i].y = dos.expand((dataset[i].label.shape[0]), -1)
#     dataset[i].y = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())
    

for i, data in enumerate(dataset):
    stru_id = int(data.stru_id)
    dir_path = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(stru_id)
    aux = np.loadtxt(dir_path)

    # Extract the first and second columns
    energy = aux[:, 0]
    # dos = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())

    # # aux2 = dataset[i].label[:,:len(dos)]
    # dataset[i].y = dos.expand((dataset[i].label.shape[0]), -1)
    dataset[i].y = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())

# %%
dataset[:]
# Out:
# [Data(
#    x=[36],
#    edge_index=[2, 1472],
#    edge_attr=[1472, 10],
#    stru_id='0',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121080, 2],
#      subgraph_edge_idx=[121080],
#      subgraph_edge_ang=[121080, 25],
#      subgraph_index=[121080],
#    },
#    spinful=[1],
#    mask=[1472, 2888],
#    label=[1472, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1462],
#    edge_attr=[1462, 10],
#    stru_id='1',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[119580, 2],
#      subgraph_edge_idx=[119580],
#      subgraph_edge_ang=[119580, 25],
#      subgraph_index=[119580],
#    },
#    spinful=[1],
#    mask=[1462, 2888],
#    label=[1462, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1456],
#    edge_attr=[1456, 10],
#    stru_id='10',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118688, 2],
#      subgraph_edge_idx=[118688],
#      subgraph_edge_ang=[118688, 25],
#      subgraph_index=[118688],
#    },
#    spinful=[1],
#    mask=[1456, 2888],
#    label=[1456, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1490],
#    edge_attr=[1490, 10],
#    stru_id='11',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124228, 2],
#      subgraph_edge_idx=[124228],
#      subgraph_edge_ang=[124228, 25],
#      subgraph_index=[124228],
#    },
#    spinful=[1],
#    mask=[1490, 2888],
#    label=[1490, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='12',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128756, 2],
#      subgraph_edge_idx=[128756],
#      subgraph_edge_ang=[128756, 25],
#      subgraph_index=[128756],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1546],
#    edge_attr=[1546, 10],
#    stru_id='13',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[133460, 2],
#      subgraph_edge_idx=[133460],
#      subgraph_edge_ang=[133460, 25],
#      subgraph_index=[133460],
#    },
#    spinful=[1],
#    mask=[1546, 2888],
#    label=[1546, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1598],
#    edge_attr=[1598, 10],
#    stru_id='14',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[142364, 2],
#      subgraph_edge_idx=[142364],
#      subgraph_edge_ang=[142364, 25],
#      subgraph_index=[142364],
#    },
#    spinful=[1],
#    mask=[1598, 2888],
#    label=[1598, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='15',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='16',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128796, 2],
#      subgraph_edge_idx=[128796],
#      subgraph_edge_ang=[128796, 25],
#      subgraph_index=[128796],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1492],
#    edge_attr=[1492, 10],
#    stru_id='17',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124556, 2],
#      subgraph_edge_idx=[124556],
#      subgraph_edge_ang=[124556, 25],
#      subgraph_index=[124556],
#    },
#    spinful=[1],
#    mask=[1492, 2888],
#    label=[1492, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='18',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129984, 2],
#      subgraph_edge_idx=[129984],
#      subgraph_edge_ang=[129984, 25],
#      subgraph_index=[129984],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1476],
#    edge_attr=[1476, 10],
#    stru_id='19',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[122184, 2],
#      subgraph_edge_idx=[122184],
#      subgraph_edge_ang=[122184, 25],
#      subgraph_index=[122184],
#    },
#    spinful=[1],
#    mask=[1476, 2888],
#    label=[1476, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='2',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128952, 2],
#      subgraph_edge_idx=[128952],
#      subgraph_edge_ang=[128952, 25],
#      subgraph_index=[128952],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='20',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129320, 2],
#      subgraph_edge_idx=[129320],
#      subgraph_edge_ang=[129320, 25],
#      subgraph_index=[129320],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='21',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130984, 2],
#      subgraph_edge_idx=[130984],
#      subgraph_edge_ang=[130984, 25],
#      subgraph_index=[130984],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1564],
#    edge_attr=[1564, 10],
#    stru_id='22',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[136512, 2],
#      subgraph_edge_idx=[136512],
#      subgraph_edge_ang=[136512, 25],
#      subgraph_index=[136512],
#    },
#    spinful=[1],
#    mask=[1564, 2888],
#    label=[1564, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1586],
#    edge_attr=[1586, 10],
#    stru_id='23',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140212, 2],
#      subgraph_edge_idx=[140212],
#      subgraph_edge_ang=[140212, 25],
#      subgraph_index=[140212],
#    },
#    spinful=[1],
#    mask=[1586, 2888],
#    label=[1586, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1604],
#    edge_attr=[1604, 10],
#    stru_id='24',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[143408, 2],
#      subgraph_edge_idx=[143408],
#      subgraph_edge_ang=[143408, 25],
#      subgraph_index=[143408],
#    },
#    spinful=[1],
#    mask=[1604, 2888],
#    label=[1604, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1558],
#    edge_attr=[1558, 10],
#    stru_id='25',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135504, 2],
#      subgraph_edge_idx=[135504],
#      subgraph_edge_ang=[135504, 25],
#      subgraph_index=[135504],
#    },
#    spinful=[1],
#    mask=[1558, 2888],
#    label=[1558, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1526],
#    edge_attr=[1526, 10],
#    stru_id='26',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130232, 2],
#      subgraph_edge_idx=[130232],
#      subgraph_edge_ang=[130232, 25],
#      subgraph_index=[130232],
#    },
#    spinful=[1],
#    mask=[1526, 2888],
#    label=[1526, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1538],
#    edge_attr=[1538, 10],
#    stru_id='27',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132204, 2],
#      subgraph_edge_idx=[132204],
#      subgraph_edge_ang=[132204, 25],
#      subgraph_index=[132204],
#    },
#    spinful=[1],
#    mask=[1538, 2888],
#    label=[1538, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='28',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125084, 2],
#      subgraph_edge_idx=[125084],
#      subgraph_edge_ang=[125084, 25],
#      subgraph_index=[125084],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1498],
#    edge_attr=[1498, 10],
#    stru_id='29',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125712, 2],
#      subgraph_edge_idx=[125712],
#      subgraph_edge_ang=[125712, 25],
#      subgraph_index=[125712],
#    },
#    spinful=[1],
#    mask=[1498, 2888],
#    label=[1498, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1528],
#    edge_attr=[1528, 10],
#    stru_id='3',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130484, 2],
#      subgraph_edge_idx=[130484],
#      subgraph_edge_ang=[130484, 25],
#      subgraph_index=[130484],
#    },
#    spinful=[1],
#    mask=[1528, 2888],
#    label=[1528, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='30',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129288, 2],
#      subgraph_edge_idx=[129288],
#      subgraph_edge_ang=[129288, 25],
#      subgraph_index=[129288],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='31',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1586],
#    edge_attr=[1586, 10],
#    stru_id='32',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140216, 2],
#      subgraph_edge_idx=[140216],
#      subgraph_edge_ang=[140216, 25],
#      subgraph_index=[140216],
#    },
#    spinful=[1],
#    mask=[1586, 2888],
#    label=[1586, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1674],
#    edge_attr=[1674, 10],
#    stru_id='33',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[156132, 2],
#      subgraph_edge_idx=[156132],
#      subgraph_edge_ang=[156132, 25],
#      subgraph_index=[156132],
#    },
#    spinful=[1],
#    mask=[1674, 2888],
#    label=[1674, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='34',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141636, 2],
#      subgraph_edge_idx=[141636],
#      subgraph_edge_ang=[141636, 25],
#      subgraph_index=[141636],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='35',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135124, 2],
#      subgraph_edge_idx=[135124],
#      subgraph_edge_ang=[135124, 25],
#      subgraph_index=[135124],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1552],
#    edge_attr=[1552, 10],
#    stru_id='36',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134612, 2],
#      subgraph_edge_idx=[134612],
#      subgraph_edge_ang=[134612, 25],
#      subgraph_index=[134612],
#    },
#    spinful=[1],
#    mask=[1552, 2888],
#    label=[1552, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='37',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129820, 2],
#      subgraph_edge_idx=[129820],
#      subgraph_edge_ang=[129820, 25],
#      subgraph_index=[129820],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='38',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124752, 2],
#      subgraph_edge_idx=[124752],
#      subgraph_edge_ang=[124752, 25],
#      subgraph_index=[124752],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1526],
#    edge_attr=[1526, 10],
#    stru_id='39',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130296, 2],
#      subgraph_edge_idx=[130296],
#      subgraph_edge_ang=[130296, 25],
#      subgraph_index=[130296],
#    },
#    spinful=[1],
#    mask=[1526, 2888],
#    label=[1526, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1550],
#    edge_attr=[1550, 10],
#    stru_id='4',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134144, 2],
#      subgraph_edge_idx=[134144],
#      subgraph_edge_ang=[134144, 25],
#      subgraph_index=[134144],
#    },
#    spinful=[1],
#    mask=[1550, 2888],
#    label=[1550, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='40',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134964, 2],
#      subgraph_edge_idx=[134964],
#      subgraph_edge_ang=[134964, 25],
#      subgraph_index=[134964],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1596],
#    edge_attr=[1596, 10],
#    stru_id='41',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[142036, 2],
#      subgraph_edge_idx=[142036],
#      subgraph_edge_ang=[142036, 25],
#      subgraph_index=[142036],
#    },
#    spinful=[1],
#    mask=[1596, 2888],
#    label=[1596, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='42',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141628, 2],
#      subgraph_edge_idx=[141628],
#      subgraph_edge_ang=[141628, 25],
#      subgraph_index=[141628],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1590],
#    edge_attr=[1590, 10],
#    stru_id='43',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140924, 2],
#      subgraph_edge_idx=[140924],
#      subgraph_edge_ang=[140924, 25],
#      subgraph_index=[140924],
#    },
#    spinful=[1],
#    mask=[1590, 2888],
#    label=[1590, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='44',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141700, 2],
#      subgraph_edge_idx=[141700],
#      subgraph_edge_ang=[141700, 25],
#      subgraph_index=[141700],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1560],
#    edge_attr=[1560, 10],
#    stru_id='45',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135992, 2],
#      subgraph_edge_idx=[135992],
#      subgraph_edge_ang=[135992, 25],
#      subgraph_index=[135992],
#    },
#    spinful=[1],
#    mask=[1560, 2888],
#    label=[1560, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1532],
#    edge_attr=[1532, 10],
#    stru_id='46',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130864, 2],
#      subgraph_edge_idx=[130864],
#      subgraph_edge_ang=[130864, 25],
#      subgraph_index=[130864],
#    },
#    spinful=[1],
#    mask=[1532, 2888],
#    label=[1532, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1536],
#    edge_attr=[1536, 10],
#    stru_id='47',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[131824, 2],
#      subgraph_edge_idx=[131824],
#      subgraph_edge_ang=[131824, 25],
#      subgraph_index=[131824],
#    },
#    spinful=[1],
#    mask=[1536, 2888],
#    label=[1536, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1538],
#    edge_attr=[1538, 10],
#    stru_id='48',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132140, 2],
#      subgraph_edge_idx=[132140],
#      subgraph_edge_ang=[132140, 25],
#      subgraph_index=[132140],
#    },
#    spinful=[1],
#    mask=[1538, 2888],
#    label=[1538, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1532],
#    edge_attr=[1532, 10],
#    stru_id='49',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130864, 2],
#      subgraph_edge_idx=[130864],
#      subgraph_edge_ang=[130864, 25],
#      subgraph_index=[130864],
#    },
#    spinful=[1],
#    mask=[1532, 2888],
#    label=[1532, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1552],
#    edge_attr=[1552, 10],
#    stru_id='5',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134556, 2],
#      subgraph_edge_idx=[134556],
#      subgraph_edge_ang=[134556, 25],
#      subgraph_index=[134556],
#    },
#    spinful=[1],
#    mask=[1552, 2888],
#    label=[1552, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='50',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135280, 2],
#      subgraph_edge_idx=[135280],
#      subgraph_edge_ang=[135280, 25],
#      subgraph_index=[135280],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='51',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135100, 2],
#      subgraph_edge_idx=[135100],
#      subgraph_edge_ang=[135100, 25],
#      subgraph_index=[135100],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1560],
#    edge_attr=[1560, 10],
#    stru_id='52',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135780, 2],
#      subgraph_edge_idx=[135780],
#      subgraph_edge_ang=[135780, 25],
#      subgraph_index=[135780],
#    },
#    spinful=[1],
#    mask=[1560, 2888],
#    label=[1560, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='53',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='54',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129496, 2],
#      subgraph_edge_idx=[129496],
#      subgraph_edge_ang=[129496, 25],
#      subgraph_index=[129496],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='55',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129392, 2],
#      subgraph_edge_idx=[129392],
#      subgraph_edge_ang=[129392, 25],
#      subgraph_index=[129392],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1542],
#    edge_attr=[1542, 10],
#    stru_id='56',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132768, 2],
#      subgraph_edge_idx=[132768],
#      subgraph_edge_ang=[132768, 25],
#      subgraph_index=[132768],
#    },
#    spinful=[1],
#    mask=[1542, 2888],
#    label=[1542, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1670],
#    edge_attr=[1670, 10],
#    stru_id='57',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[155856, 2],
#      subgraph_edge_idx=[155856],
#      subgraph_edge_ang=[155856, 25],
#      subgraph_index=[155856],
#    },
#    spinful=[1],
#    mask=[1670, 2888],
#    label=[1670, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1542],
#    edge_attr=[1542, 10],
#    stru_id='58',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132764, 2],
#      subgraph_edge_idx=[132764],
#      subgraph_edge_ang=[132764, 25],
#      subgraph_index=[132764],
#    },
#    spinful=[1],
#    mask=[1542, 2888],
#    label=[1542, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='59',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129896, 2],
#      subgraph_edge_idx=[129896],
#      subgraph_edge_ang=[129896, 25],
#      subgraph_index=[129896],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='6',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129656, 2],
#      subgraph_edge_idx=[129656],
#      subgraph_edge_ang=[129656, 25],
#      subgraph_index=[129656],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='60',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129652, 2],
#      subgraph_edge_idx=[129652],
#      subgraph_edge_ang=[129652, 25],
#      subgraph_index=[129652],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='61',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128120, 2],
#      subgraph_edge_idx=[128120],
#      subgraph_edge_ang=[128120, 25],
#      subgraph_index=[128120],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='62',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129100, 2],
#      subgraph_edge_idx=[129100],
#      subgraph_edge_ang=[129100, 25],
#      subgraph_index=[129100],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='63',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128372, 2],
#      subgraph_edge_idx=[128372],
#      subgraph_edge_ang=[128372, 25],
#      subgraph_index=[128372],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1502],
#    edge_attr=[1502, 10],
#    stru_id='64',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[126444, 2],
#      subgraph_edge_idx=[126444],
#      subgraph_edge_ang=[126444, 25],
#      subgraph_index=[126444],
#    },
#    spinful=[1],
#    mask=[1502, 2888],
#    label=[1502, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1478],
#    edge_attr=[1478, 10],
#    stru_id='65',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[122072, 2],
#      subgraph_edge_idx=[122072],
#      subgraph_edge_ang=[122072, 25],
#      subgraph_index=[122072],
#    },
#    spinful=[1],
#    mask=[1478, 2888],
#    label=[1478, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1536],
#    edge_attr=[1536, 10],
#    stru_id='66',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[131768, 2],
#      subgraph_edge_idx=[131768],
#      subgraph_edge_ang=[131768, 25],
#      subgraph_index=[131768],
#    },
#    spinful=[1],
#    mask=[1536, 2888],
#    label=[1536, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1548],
#    edge_attr=[1548, 10],
#    stru_id='67',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[133932, 2],
#      subgraph_edge_idx=[133932],
#      subgraph_edge_ang=[133932, 25],
#      subgraph_index=[133932],
#    },
#    spinful=[1],
#    mask=[1548, 2888],
#    label=[1548, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1470],
#    edge_attr=[1470, 10],
#    stru_id='68',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[120716, 2],
#      subgraph_edge_idx=[120716],
#      subgraph_edge_ang=[120716, 25],
#      subgraph_index=[120716],
#    },
#    spinful=[1],
#    mask=[1470, 2888],
#    label=[1470, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1496],
#    edge_attr=[1496, 10],
#    stru_id='69',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125384, 2],
#      subgraph_edge_idx=[125384],
#      subgraph_edge_ang=[125384, 25],
#      subgraph_index=[125384],
#    },
#    spinful=[1],
#    mask=[1496, 2888],
#    label=[1496, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='7',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129648, 2],
#      subgraph_edge_idx=[129648],
#      subgraph_edge_ang=[129648, 25],
#      subgraph_index=[129648],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='70',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128984, 2],
#      subgraph_edge_idx=[128984],
#      subgraph_edge_ang=[128984, 25],
#      subgraph_index=[128984],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1490],
#    edge_attr=[1490, 10],
#    stru_id='71',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124228, 2],
#      subgraph_edge_idx=[124228],
#      subgraph_edge_ang=[124228, 25],
#      subgraph_index=[124228],
#    },
#    spinful=[1],
#    mask=[1490, 2888],
#    label=[1490, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1454],
#    edge_attr=[1454, 10],
#    stru_id='72',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118396, 2],
#      subgraph_edge_idx=[118396],
#      subgraph_edge_ang=[118396, 25],
#      subgraph_index=[118396],
#    },
#    spinful=[1],
#    mask=[1454, 2888],
#    label=[1454, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1474],
#    edge_attr=[1474, 10],
#    stru_id='73',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121860, 2],
#      subgraph_edge_idx=[121860],
#      subgraph_edge_ang=[121860, 25],
#      subgraph_index=[121860],
#    },
#    spinful=[1],
#    mask=[1474, 2888],
#    label=[1474, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='74',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125052, 2],
#      subgraph_edge_idx=[125052],
#      subgraph_edge_ang=[125052, 25],
#      subgraph_index=[125052],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='75',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128244, 2],
#      subgraph_edge_idx=[128244],
#      subgraph_edge_ang=[128244, 25],
#      subgraph_index=[128244],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='76',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130500, 2],
#      subgraph_edge_idx=[130500],
#      subgraph_edge_ang=[130500, 25],
#      subgraph_index=[130500],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='77',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130944, 2],
#      subgraph_edge_idx=[130944],
#      subgraph_edge_ang=[130944, 25],
#      subgraph_index=[130944],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1506],
#    edge_attr=[1506, 10],
#    stru_id='78',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[127132, 2],
#      subgraph_edge_idx=[127132],
#      subgraph_edge_ang=[127132, 25],
#      subgraph_index=[127132],
#    },
#    spinful=[1],
#    mask=[1506, 2888],
#    label=[1506, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1474],
#    edge_attr=[1474, 10],
#    stru_id='79',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121860, 2],
#      subgraph_edge_idx=[121860],
#      subgraph_edge_ang=[121860, 25],
#      subgraph_index=[121860],
#    },
#    spinful=[1],
#    mask=[1474, 2888],
#    label=[1474, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1456],
#    edge_attr=[1456, 10],
#    stru_id='8',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118688, 2],
#      subgraph_edge_idx=[118688],
#      subgraph_edge_ang=[118688, 25],
#      subgraph_index=[118688],
#    },
#    spinful=[1],
#    mask=[1456, 2888],
#    label=[1456, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1458],
#    edge_attr=[1458, 10],
#    stru_id='9',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118988, 2],
#      subgraph_edge_idx=[118988],
#      subgraph_edge_ang=[118988, 25],
#      subgraph_index=[118988],
#    },
#    spinful=[1],
#    mask=[1458, 2888],
#    label=[1458, 2888],
#    y=[999]
#  )]

# %%
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2
train_size = int(train_ratio * dataset_size)
val_size = int(val_ratio * dataset_size)
test_size = int(test_ratio * dataset_size)
indices = list(range(dataset_size))
np.random.shuffle(indices)
train_sampler = SubsetRandomSampler(indices[:train_size])
val_sampler = SubsetRandomSampler(indices[train_size:train_size + val_size])
test_sampler = SubsetRandomSampler(indices[train_size + val_size:train_size + val_size + test_size])
from deeph.graph import Collater

train_loader = DataLoader(dataset, batch_size=1,
                            shuffle=False, sampler=train_sampler,
                            collate_fn=Collater(True))
val_loader = DataLoader(dataset, batch_size=1,
                        shuffle=False, sampler=val_sampler,
                        collate_fn=Collater(True))
test_loader = DataLoader(dataset, batch_size=1,
                            shuffle=False, sampler=test_sampler,
                            collate_fn=Collater(True))

# %%
learning_rate = 1e-3
weight_decay = 0
criterion = nn.SmoothL1Loss()  # Example loss function
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
# optimizer = optim.SGD(model_parameters, lr=learning_rate, weight_decay=weight_decay)
optimizer = optim.Adam(model_parameters, lr=learning_rate, betas=(0.9, 0.999))
best_loss = float('inf')
best_model_path =  '/home/t.hsu/deeph_dev/DOS_best_model.pth'


epochs = np.arange(1, 201)
losses = []
for e in epochs:
    model.train()
    epoch_loss = 0
    num_batches = 0
    for step, batch_tuple in enumerate(train_loader):
        if if_lcmp:
            batch, subgraph = batch_tuple
            sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index = subgraph
            output = model(
                batch.x.to(device),
                batch.edge_index.to(device),
                batch.edge_attr.to(device),
                batch.batch.to(device),
                sub_atom_idx.to(device),
                sub_edge_idx.to(device),
                sub_edge_ang.to(device),
                sub_index.to(device)
                    )
            target_labels = batch.y.to(device)
            loss = criterion(output, target_labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            num_batches += 1
            
    avg_epoch_loss = epoch_loss / num_batches
    losses.append(avg_epoch_loss)
    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss  # Update the best loss
        torch.save(model.state_dict(), best_model_path)  # Save the model with the best loss
        print(f"Epoch {e+1}: New best model saved with loss {best_loss:.4f}")

    print(f"Epoch {e+1}: Average Loss = {avg_epoch_loss:.4f}")

print("Training complete. Best model saved as 'best_model.pth'.")

# %%
output.shape
# Out:
# torch.Size([999])

# %%
target_labels.shape
loss = criterion(output, target_labels)
loss
# Out:
# tensor(0.04666635, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)

# %%
losses
# Out:
# [2.7163446998844543,
#  0.4149796689550082,
#  0.4142487921441595,
#  0.4282303238287568,
#  0.3974336008541286,
#  0.3935735148067276,
#  0.4032631201359133,
#  0.39184436450401944,
#  0.4046144229359925,
#  0.4035702037314574,
#  0.40605482428024214,
#  0.3923948307832082,
#  0.38937394476185244,
#  0.3896496162439386,
#  0.38581701352571446,
#  0.38231184395651024,
#  0.4084209455177188,
#  0.3837452265433967,
#  0.38368058390915394,
#  0.37984364945441484,
#  0.3836341508043309,
#  0.376758045827349,
#  0.37545369332656264,
#  0.38684932126974064,
#  0.36982552831371623,
#  0.3914248049259186,
#  0.36816705980648595,
#  0.3732955992842714,
#  0.36430613106737536,
#  0.36843118413041037,
#  0.3656526197058459,
#  0.3604913935996592,
#  0.36046588125949103,
#  0.3460593440880378,
#  0.3379251975566149,
#  0.32041892704243463,
#  0.3278802928204338,
#  0.3173542146881421,
#  0.32313553740580875,
#  0.3218315869259338,
#  0.3039887448151906,
#  0.31132186731944483,
#  0.32118582477172214,
#  0.2967420811764896,
#  0.3044619522988796,
#  0.30509093031287193,
#  0.292057656062146,
#  0.28670088620856404,
#  0.28835513908416033,
#  0.2902606266240279,
#  0.2915755705907941,
#  0.2880275696516037,
#  0.2551442502687375,
#  0.2637223149649799,
#  0.2801284408196807,
#  0.25317113660275936,
#  0.2679531713947654,
#  0.2540749933881064,
#  0.2557106198122104,
#  0.24411956251909336,
#  0.23744061247756085,
#  0.2455204416376849,
#  0.24927659037833413,
#  0.24743172759190202,
#  0.2414588190925618,
#  0.2297673442711433,
#  0.2234213037105898,
#  0.22349843056872487,
#  0.233202508961161,
#  0.23088411195203662,
#  0.22814973148827752,
#  0.2198724925207595,
#  0.2173823524887363,
#  0.22069544655581316,
#  0.21380139297495285,
#  0.21410268420974413,
#  0.22316894649217525,
#  0.2113448167219758,
#  0.21021514758467674,
#  0.20441039356713495,
#  0.20233588137974343,
#  0.1957294267291824,
#  0.20769693531716862,
#  0.19562321342527866,
#  0.18744616179416576,
#  0.19998039460430542,
#  0.1870128515486916,
#  0.18275660431633392,
#  0.17834693131347498,
#  0.16916038220127425,
#  0.17869776099299392,
#  0.189917400944978,
#  0.17730558617040515,
#  0.1691448592270414,
#  0.16928555785367885,
#  0.16575647161031762,
#  0.17469253096108636,
#  0.17726385096708933,
#  0.1701234985763828,
#  0.17251280788332224,
#  0.17720217956230044,
#  0.1580486985233923,
#  0.16719966242089868,
#  0.15561353539427122,
#  0.14428587521736821,
#  0.14315025756756464,
#  0.13773952843621373,
#  0.1344270658058425,
#  0.1399702139509221,
#  0.13934442781222364,
#  0.126869174807022,
#  0.131301274523139,
#  0.1379526131786406,
#  0.13658611577314636,
#  0.12843224251021942,
#  0.12388174748048186,
#  0.12290626717731357,
#  0.12101118351953725,
#  0.11993819327714543,
#  0.12597826697553197,
#  0.12878139573149383,
#  0.16015741787850857,
#  0.13345712454368672,
#  0.1315306986992558,
#  0.11852950664858024,
#  0.11750153529768188,
#  0.12346794184607764,
#  0.1170215926443537,
#  0.11446961131878197,
#  0.1095671357276539,
#  0.10814433987252414,
#  0.12608900394601127,
#  0.10336838390988608,
#  0.12339238535302381,
#  0.11256178220113118,
#  0.10550284300309916,
#  0.10160122415982187,
#  0.10041306586936116,
#  0.11752575480689605,
#  0.09757785281787316,
#  0.09624181416196127,
#  0.10675420534486572,
#  0.10780075650351743,
#  0.11644807807169855,
#  0.09989632278059919,
#  0.09149793108614783,
#  0.09303930688959856,
#  0.09497617743909359,
#  0.10009069500180583,
#  0.11318229651078582,
#  0.10527686697120468,
#  0.102327299847578,
#  0.09040957394366463,
#  0.08424879245770474,
#  0.09158115678777297,
#  0.1263995134892563,
#  0.10224347716818254,
#  0.09187852855150898,
#  0.08979901415295899,
#  0.09405453844616811,
#  0.08517940101834635,
#  0.08569701062515378,
#  0.07983819589329262,
#  0.07673647270227472,
#  0.07555778487585485,
#  0.06750648856783907,
#  0.06874302014087637,
#  0.06316994041359673,
#  0.07319135311990976,
#  0.06988890546684463,
#  0.0812442513803641,
#  0.0866293568784992,
#  0.08327703216734032,
#  0.08063740741151075,
#  0.06699045984229694,
#  0.06716672350497295,
#  0.06957000439676146,
#  0.06401676575963695,
#  0.09093743298823635,
#  0.06765480052369337,
#  0.07982940242315333,
#  0.10773595919211705,
#  0.09652803038867812,
#  0.08641182530360918,
#  0.0735956304318582,
#  0.06490451485539477,
#  0.06718268299785753,
#  0.06479714123997837,
#  0.05858751370881995,
#  0.05640763754490763,
#  0.056565655511803925,
#  0.05557872203644365,
#  0.06714027258567512,
#  0.07801810426947971,
#  0.07675466663204134,
#  0.06614257026618968,
#  0.06544207634093861,
#  0.0573504933854565,
#  0.055969200640295945,
#  0.05081427240899453]

# %%
import matplotlib.pyplot as plt
plt.plot(epochs,losses)

plt.title('Training Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)

plt.grid(True)

# Ticks and limits
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim([1, 201])
plt.ylim([min(losses) - 0.0001, max(losses) + 0.0001])

# Adding legend
plt.legend(fontsize=12)
plt.show()

# %%
target_labels.cpu().detach().numpy().shape
# Out:
# (999,)

# %%
x = np.linspace(-20, 20, 999) 
plt.figure(figsize=(10, 6))
plt.plot(x, target_labels.cpu().detach().numpy(),color='black', label = 'Target labels')
plt.plot(x, output.cpu().detach().numpy(),color='red', linestyle= '--', label = 'Model output')
plt.xlabel('Energy')
plt.ylabel('DOS')
plt.title('Density of States vs. Energy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.load_state_dict(torch.load(best_model_path))
model.eval()
difference = []

with torch.no_grad():
    for step, batch_tuple in enumerate(test_loader):
        if if_lcmp:
            batch, subgraph = batch_tuple
            sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index = subgraph
            prediction = model(
                batch.x.to(device),
                batch.edge_index.to(device),
                batch.edge_attr.to(device),
                batch.batch.to(device),
                sub_atom_idx.to(device),
                sub_edge_idx.to(device),
                sub_edge_ang.to(device),
                sub_index.to(device)
                    )
            target_labels = batch.y.to(device)
        difference_aux = sum(output.cpu().detach().numpy() - batch.y.cpu().detach().numpy())
        difference.append(difference_aux)
        

        x = np.linspace(-20, 20, 999) 
        plt.figure(figsize=(10, 6))
        plt.plot(x, batch.y.cpu().detach().numpy(),color='black', label = 'Target labels')
        plt.plot(x, output.cpu().detach().numpy(),color='red', linestyle= '--', label = 'Model output')
        plt.xlabel('Energy')
        plt.ylabel('DOS')
        plt.title('Density of States vs. Energy, Diff ={}'.format(difference_aux))
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
difference
sum(difference)
# Out:
# -605.0134224304929
