# %%
import os
from typing import Union, Tuple
from math import ceil, sqrt
from torch.utils.data import SubsetRandomSampler, DataLoader

import torch
from torch import nn
import torch.nn.functional as F
from torch import package
from torch.nn import MSELoss, L1Loss, SmoothL1Loss
import torch.optim as optim
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.norm import LayerNorm, PairNorm, InstanceNorm
from torch_geometric.typing import PairTensor, Adj, OptTensor, Size
from torch_geometric.nn.inits import glorot, zeros
from torch_geometric.utils import softmax
from torch_geometric.nn.models.dimenet import BesselBasisLayer
from torch_scatter import scatter_add, scatter
import numpy as np
from scipy.special import comb
from deeph.data import HData

from deeph.from_se3_transformer import SphericalHarmonics
from deeph.from_schnetpack import GaussianBasis
from deeph.from_PyG_future import GraphNorm, DiffGroupNorm
from deeph.from_HermNet import RBF, cosine_cutoff, ShiftedSoftplus, _eps
from inspect import signature

from deeph.utils import LossRecord

# %%
class CGConv(MessagePassing):
    def __init__(self, channels: Union[int, Tuple[int, int]], dim: int = 0,
                 aggr: str = 'add', normalization: str = None,
                 bias: bool = True, if_exp: bool = False, **kwargs):
        super(CGConv, self).__init__(aggr=aggr, flow="source_to_target", **kwargs)
        self.channels = channels
        self.dim = dim
        self.normalization = normalization
        self.if_exp = if_exp

        if isinstance(channels, int):
            channels = (channels, channels)

        self.lin_f = nn.Linear(sum(channels) + dim, channels[1], bias=bias)
        self.lin_s = nn.Linear(sum(channels) + dim, channels[1], bias=bias)
        if self.normalization == 'BatchNorm':
            self.bn = nn.BatchNorm1d(channels[1], track_running_stats=True)
        elif self.normalization == 'LayerNorm':
            self.ln = LayerNorm(channels[1])
        elif self.normalization == 'PairNorm':
            self.pn = PairNorm(channels[1])
        elif self.normalization == 'InstanceNorm':
            self.instance_norm = InstanceNorm(channels[1])
        elif self.normalization == 'GraphNorm':
            self.gn = GraphNorm(channels[1])
        elif self.normalization == 'DiffGroupNorm':
            self.group_norm = DiffGroupNorm(channels[1], 128)
        elif self.normalization is None:
            pass
        else:
            raise ValueError('Unknown normalization function: {}'.format(normalization))

        self.reset_parameters()

    def reset_parameters(self):
        self.lin_f.reset_parameters()
        self.lin_s.reset_parameters()
        if self.normalization == 'BatchNorm':
            self.bn.reset_parameters()

    def forward(self, x: Union[torch.Tensor, PairTensor], edge_index: Adj,
                edge_attr: OptTensor, batch, distance, size: Size = None) -> torch.Tensor:
        """"""
        if isinstance(x, torch.Tensor):
            x: PairTensor = (x, x)

        # propagate_type: (x: PairTensor, edge_attr: OptTensor)
        out = self.propagate(edge_index, x=x, edge_attr=edge_attr, distance=distance, size=size)
        if self.normalization == 'BatchNorm':
            out = self.bn(out)
        elif self.normalization == 'LayerNorm':
            out = self.ln(out, batch)
        elif self.normalization == 'PairNorm':
            out = self.pn(out, batch)
        elif self.normalization == 'InstanceNorm':
            out = self.instance_norm(out, batch)
        elif self.normalization == 'GraphNorm':
            out = self.gn(out, batch)
        elif self.normalization == 'DiffGroupNorm':
            out = self.group_norm(out)
        out += x[1]
        return out

    def message(self, x_i, x_j, edge_attr: OptTensor, distance) -> torch.Tensor:
        z = torch.cat([x_i, x_j, edge_attr], dim=-1)
        out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))
        if self.if_exp: # Very specific section. The message is scaled exponentially with the distance.
            sigma = 3
            n = 2
            out = out * torch.exp(-distance ** n / sigma ** n / 2).view(-1, 1)
        return out

    def __repr__(self):
        return '{}({}, dim={})'.format(self.__class__.__name__, self.channels, self.dim)

# %%
class MPLayer(nn.Module):
    def __init__(self, in_atom_fea_len, in_edge_fea_len, out_edge_fea_len, if_exp, if_edge_update, normalization,
                 atom_update_net, gauss_stop, output_layer=False):
        super(MPLayer, self).__init__()
        if atom_update_net == 'CGConv':
            self.cgconv = CGConv(channels=in_atom_fea_len,
                                 dim=in_edge_fea_len,
                                 aggr='add',
                                 normalization=normalization,
                                 if_exp=if_exp)

        self.if_edge_update = if_edge_update
        self.atom_update_net = atom_update_net
        if if_edge_update:
            if output_layer:
                self.e_lin = nn.Sequential(nn.Linear(in_edge_fea_len + in_atom_fea_len * 2, 128),
                                           nn.SiLU(),
                                           nn.Linear(128, out_edge_fea_len),
                                           )
            else:
                self.e_lin = nn.Sequential(nn.Linear(in_edge_fea_len + in_atom_fea_len * 2, 128),
                                           nn.SiLU(),
                                           nn.Linear(128, out_edge_fea_len),
                                           nn.SiLU(),
                                           )

    def forward(self, atom_fea, edge_idx, edge_fea, batch, distance, edge_vec):
        atom_fea = self.cgconv(atom_fea, edge_idx, edge_fea, batch, distance)
        atom_fea_s = atom_fea
        if self.if_edge_update:
            row, col = edge_idx
            edge_fea = self.e_lin(torch.cat([atom_fea_s[row], atom_fea_s[col], edge_fea], dim=-1))
            return atom_fea, edge_fea
        else:
            return atom_fea

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
from torch_scatter import scatter_add
from math import ceil

class LCMPLayer(nn.Module):
    def __init__(self, in_atom_fea_len, in_edge_fea_len, out_edge_fea_len, num_l,
                 normalization: str = None, bias: bool = True, if_exp: bool = False):
        super(LCMPLayer, self).__init__()
        self.in_atom_fea_len = in_atom_fea_len
        self.normalization = normalization
        self.if_exp = if_exp

        self.lin_f = nn.Linear(in_atom_fea_len * 2 + in_edge_fea_len, in_atom_fea_len, bias=bias)
        self.lin_s = nn.Linear(in_atom_fea_len * 2 + in_edge_fea_len, in_atom_fea_len, bias=bias)
        self.bn = nn.BatchNorm1d(in_atom_fea_len, track_running_stats=True)

        self.e_lin = nn.Sequential(
            nn.Linear(in_edge_fea_len + in_atom_fea_len * 2 - num_l ** 2, 128),
            nn.SiLU(),
            nn.Linear(128, out_edge_fea_len)
        )
        

        self.reset_parameters()

    def reset_parameters(self):
        self.lin_f.reset_parameters()
        self.lin_s.reset_parameters()
        if self.normalization == 'BatchNorm':
            self.bn.reset_parameters()

    def forward(self, atom_fea, edge_fea, sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index, distance,
                huge_structure, output_final_layer_neuron):
        if huge_structure:
            sub_graph_batch_num = 8

            sub_graph_num = sub_atom_idx.shape[0]
            sub_graph_batch_size = ceil(sub_graph_num / sub_graph_batch_num)

            num_edge = edge_fea.shape[0]
            vf_update = torch.zeros((num_edge * 2, self.in_atom_fea_len)).type(torch.get_default_dtype()).to(atom_fea.device)
            for sub_graph_batch_index in range(sub_graph_batch_num):
                if sub_graph_batch_index == sub_graph_batch_num - 1:
                    sub_graph_idx = slice(sub_graph_batch_size * sub_graph_batch_index, sub_graph_num)
                else:
                    sub_graph_idx = slice(sub_graph_batch_size * sub_graph_batch_index,
                                          sub_graph_batch_size * (sub_graph_batch_index + 1))

                sub_atom_idx_batch = sub_atom_idx[sub_graph_idx]
                sub_edge_idx_batch = sub_edge_idx[sub_graph_idx]
                sub_edge_ang_batch = sub_edge_ang[sub_graph_idx]
                sub_index_batch = sub_index[sub_graph_idx]

                z = torch.cat([atom_fea[sub_atom_idx_batch][:, 0, :], atom_fea[sub_atom_idx_batch][:, 1, :],
                               edge_fea[sub_edge_idx_batch], sub_edge_ang_batch], dim=-1)
                out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))

                if self.if_exp:
                    sigma = 3
                    n = 2
                    out = out * torch.exp(-distance[sub_edge_idx_batch] ** n / sigma ** n / 2).view(-1, 1)

                vf_update += scatter_add(out, sub_index_batch, dim=0, dim_size=num_edge * 2)

            if self.normalization == 'BatchNorm':
                vf_update = self.bn(vf_update)
            vf_update = vf_update.reshape(num_edge, 2, -1)
            if output_final_layer_neuron != '':
                final_layer_neuron = torch.cat([vf_update[:, 0, :], vf_update[:, 1, :], edge_fea],
                                               dim=-1).detach().cpu().numpy()
                np.save(os.path.join(output_final_layer_neuron, 'final_layer_neuron.npy'), final_layer_neuron)
            out = self.e_lin(torch.cat([vf_update[:, 0, :], vf_update[:, 1, :], edge_fea], dim=-1))
            return out

        num_edge = edge_fea.shape[0]
        z = torch.cat(
            [atom_fea[sub_atom_idx][:, 0, :], atom_fea[sub_atom_idx][:, 1, :], edge_fea[sub_edge_idx], sub_edge_ang],
            dim=-1)
        out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))

        if self.if_exp:
            sigma = 3
            n = 2
            out = out * torch.exp(-distance[sub_edge_idx] ** n / sigma ** n / 2).view(-1, 1)

        out = scatter_add(out, sub_index, dim=0)
        if self.normalization == 'BatchNorm':
            out = self.bn(out)
        out = out.reshape(num_edge, 2, -1)
        if output_final_layer_neuron != '':
            final_layer_neuron = torch.cat([out[:, 0, :], out[:, 1, :], edge_fea], dim=-1).detach().cpu().numpy()
            np.save(os.path.join(output_final_layer_neuron, 'final_layer_neuron.npy'), final_layer_neuron)
        out = self.e_lin(torch.cat([out[:, 0, :], out[:, 1, :], edge_fea], dim=-1))
        return out

# %%
class MultipleLinear(nn.Module):
    def __init__(self, num_linear: int, in_fea_len: int, out_fea_len: int, bias: bool = True) -> None:
        super(MultipleLinear, self).__init__()
        self.num_linear = num_linear
        self.out_fea_len = out_fea_len
        self.weight = nn.Parameter(torch.Tensor(num_linear, in_fea_len, out_fea_len))
        if bias:
            self.bias = nn.Parameter(torch.Tensor(num_linear, out_fea_len))
        else:
            self.register_parameter('bias', None)
        # self.ln = LayerNorm(num_linear * out_fea_len)
        # self.gn = GraphNorm(out_fea_len)
        self.reset_parameters()

    def reset_parameters(self) -> None:
        nn.init.kaiming_uniform_(self.weight, a=sqrt(5))
        if self.bias is not None:
            fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.weight)
            bound = 1 / sqrt(fan_in)
            nn.init.uniform_(self.bias, -bound, bound)

    def forward(self, input: torch.Tensor, batch_edge: torch.Tensor) -> torch.Tensor:
        output = torch.matmul(input, self.weight)

        if self.bias is not None:
            output += self.bias[:, None, :]
        return output

# %%
import torch
import torch.nn as nn

class HGNN(nn.Module):
    def __init__(self, num_species, in_atom_fea_len, in_edge_fea_len, num_orbital,
                 distance_expansion, gauss_stop, if_exp, if_MultipleLinear, if_edge_update, if_lcmp,
                 normalization, atom_update_net, separate_onsite,
                 trainable_gaussians, type_affine, num_l=5):
        super(HGNN, self).__init__()
        self.num_species = num_species
        self.embed = nn.Embedding(num_species + 5, in_atom_fea_len)

        # pair-type aware affine
        if type_affine:
            self.type_affine = nn.Embedding(
                num_species ** 2, 2,
                _weight=torch.stack([torch.ones(num_species ** 2), torch.zeros(num_species ** 2)], dim=-1)
            )
        else:
            self.type_affine = None

        if if_edge_update or (if_edge_update is False and if_lcmp is False):
            distance_expansion_len = in_edge_fea_len
        else:
            distance_expansion_len = in_edge_fea_len - num_l ** 2
        if distance_expansion == 'GaussianBasis':
            self.distance_expansion = GaussianBasis(
                0.0, gauss_stop, distance_expansion_len, trainable=trainable_gaussians
            )

        self.if_MultipleLinear = if_MultipleLinear
        self.if_edge_update = if_edge_update
        self.if_lcmp = if_lcmp
        self.atom_update_net = atom_update_net
        self.separate_onsite = separate_onsite
        if if_lcmp == True:
            mp_output_edge_fea_len = in_edge_fea_len - num_l ** 2

        if if_edge_update == True:
            self.mp1 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp2 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp3 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp4 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp5 = MPLayer(in_atom_fea_len, in_edge_fea_len, mp_output_edge_fea_len, if_exp, if_edge_update,
                               normalization, atom_update_net, gauss_stop)

        if if_lcmp == True:
            if self.if_MultipleLinear == True:
                self.lcmp = LCMPLayer(in_atom_fea_len, in_edge_fea_len, 32, num_l, if_exp=if_exp)
                self.multiple_linear1 = MultipleLinear(num_orbital, 32, 16)
                self.multiple_linear2 = MultipleLinear(num_orbital, 16, 1)
            else:
                self.lcmp = LCMPLayer(in_atom_fea_len, in_edge_fea_len, num_orbital, num_l, if_exp=if_exp)

        else:
            self.mp_output = MPLayer(in_atom_fea_len, in_edge_fea_len, num_orbital, if_exp, if_edge_update=True,
                                     normalization=normalization, atom_update_net=atom_update_net,
                                     gauss_stop=gauss_stop, output_layer=True)

        # Define the DOS prediction network with an initial placeholder input size
        self.dos_fc1 = nn.Linear(0, 512)  # Placeholder size, will be adjusted in forward
        self.dos_fc2 = nn.Linear(512, 256)
        self.dos_fc3 = nn.Linear(256, 128)
        self.dos_fc4 = nn.Linear(128, 999)

    def forward(self, atom_attr, edge_idx, edge_attr, batch,
                sub_atom_idx=None, sub_edge_idx=None, sub_edge_ang=None, sub_index=None,
                huge_structure=False, output_final_layer_neuron=''):
        device = atom_attr.device  # Get the device of the input tensor

        batch_edge = batch[edge_idx[0]]
        atom_fea0 = self.embed(atom_attr)
        distance = edge_attr[:, 0]
        edge_vec = edge_attr[:, 1:4] - edge_attr[:, 4:7]

        if self.type_affine is None:
            edge_fea0 = self.distance_expansion(distance)
        else:
            affine_coeff = self.type_affine(self.num_species * atom_attr[edge_idx[0]] + atom_attr[edge_idx[1]])
            edge_fea0 = self.distance_expansion(distance * affine_coeff[:, 0] + affine_coeff[:, 1])

        if self.if_edge_update == True:
            atom_fea, edge_fea = self.mp1(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea, edge_fea = self.mp2(atom_fea, edge_idx, edge_fea, batch, distance, edge_vec)
            atom_fea0, edge_fea0 = atom_fea0 + atom_fea, edge_fea0 + edge_fea
            atom_fea, edge_fea = self.mp3(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea, edge_fea = self.mp4(atom_fea, edge_idx, edge_fea, batch, distance, edge_vec)
            atom_fea0, edge_fea0 = atom_fea0 + atom_fea, edge_fea0 + edge_fea
            atom_fea, edge_fea = self.mp5(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)

            if self.if_lcmp == True:
                atom_fea_s = atom_fea
                out = self.lcmp(atom_fea_s, edge_fea, sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index, distance,
                                huge_structure, output_final_layer_neuron)

        # Ensure all tensors are on the same device
        edge_fea_aggregated = torch.zeros((atom_fea.shape[0], edge_fea.shape[1]), device=device)
        edge_fea_aggregated.index_add_(0, edge_idx[0].to(device), edge_fea.to(device))

        # Combine atom and edge features
        combined_fea = torch.cat([atom_fea, edge_fea_aggregated], dim=1)

        # Dynamically adjust the first fully connected layer
        if self.dos_fc1.in_features != combined_fea.shape[1]:
            self.dos_fc1 = nn.Linear(combined_fea.shape[1], 512).to(device)

        dos_pred = torch.relu(self.dos_fc1(combined_fea))
        dos_pred = torch.relu(self.dos_fc2(dos_pred))
        dos_pred = torch.relu(self.dos_fc3(dos_pred))
        dos_pred = self.dos_fc4(dos_pred)
        
        dos_pred = dos_pred.sum(dim=0)  # Shape will be [999]

        return out, dos_pred

# %%
dataset = HData(
    raw_data_dir='/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/processed',
    graph_dir='/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/graph',
    interface='h5',
    target='hamiltonian',
    dataset_name='Bi_soc',
    multiprocessing=0,
    radius='-1.0',
    max_num_nbr=0,
    num_l='5',
    max_element='-1',
    create_from_DFT='True',
    if_lcmp_graph='True',
    separate_onsite='False',
    new_sp=False,
    default_dtype_torch=torch.get_default_dtype(),
)
# Out:
# Graph data file: HGraph-h5-Bi_soc-5l-FromDFT.pkl
# Use existing graph data file
# Atomic types: [83]
# Finish loading the processed 80 structures (spinful: True, the number of atomic types: 1), cost 1 seconds

# %%
import configparser
import json
from deeph.kernel import DeepHKernel
# Initialize the ConfigParser
config = configparser.ConfigParser()

# Read the configuration file
config.read('/home/t.hsu/deeph_dev/default.ini')

config.read('/home/t.hsu/deeph_dev/train.ini')  # Replace 'config.ini' with your actual file name
kernel = DeepHKernel(config)
_, _, _, _ = kernel.get_dataset()
num_species = len(dataset.info["index_to_Z"])
orbital = json.loads(config.get('basic', 'orbital'))
num_orbital = len(orbital)
spinful = True
if_lcmp = True
separate_onsite = False
if spinful:
    out_fea_len = num_orbital * 8
else:
    out_fea_len = num_orbital
print('DeepH', out_fea_len)
# Out:
# /home/t.hsu/miniconda3/envs/gpu_test/lib/python3.10/site-packages/deeph/kernel.py:53: UserWarning: Unable to copy scripts
#   warnings.warn("Unable to copy scripts")
# ====== CONFIG ======
# [basic]
# graph_dir=/home/t.hsu/example2/work_dir/dataset/graph
# save_dir=/home/t.hsu/example2/work_dir/trained_model
# raw_dir=/home/t.hsu/example2/work_dir/dataset/processed
# dataset_name=Bi_soc
# only_get_graph=False
# interface=h5
# target=hamiltonian
# disable_cuda=False
# device=cuda:0
# num_threads=64
# save_to_time_folder=False
# save_csv=False
# tb_writer=True
# seed=42
# multiprocessing=0
# orbital=[{"83 83": [0, 0]}, {"83 83": [0, 1]}, {"83 83": [0, 2]}, {"83 83": [0, 3]}, {"83 83": [0, 4]}, {"83 83": [0, 5]}, {"83 83": [0, 6]}, {"83 83": [0, 7]}, {"83 83": [0, 8]}, {"83 83": [0, 9]}, {"83 83": [0, 10]}, {"83 83": [0, 11]}, {"83 83": [0, 12]}, {"83 83": [0, 13]}, {"83 83": [0, 14]}, {"83 83": [0, 15]}, {"83 83": [0, 16]}, {"83 83": [0, 17]}, {"83 83": [0, 18]}, {"83 83": [1, 0]}, {"83 83": [1, 1]}, {"83 83": [1, 2]}, {"83 83": [1, 3]}, {"83 83": [1, 4]}, {"83 83": [1, 5]}, {"83 83": [1, 6]}, {"83 83": [1, 7]}, {"83 83": [1, 8]}, {"83 83": [1, 9]}, {"83 83": [1, 10]}, {"83 83": [1, 11]}, {"83 83": [1, 12]}, {"83 83": [1, 13]}, {"83 83": [1, 14]}, {"83 83": [1, 15]}, {"83 83": [1, 16]}, {"83 83": [1, 17]}, {"83 83": [1, 18]}, {"83 83": [2, 0]}, {"83 83": [2, 1]}, {"83 83": [2, 2]}, {"83 83": [2, 3]}, {"83 83": [2, 4]}, {"83 83": [2, 5]}, {"83 83": [2, 6]}, {"83 83": [2, 7]}, {"83 83": [2, 8]}, {"83 83": [2, 9]}, {"83 83": [2, 10]}, {"83 83": [2, 11]}, {"83 83": [2, 12]}, {"83 83": [2, 13]}, {"83 83": [2, 14]}, {"83 83": [2, 15]}, {"83 83": [2, 16]}, {"83 83": [2, 17]}, {"83 83": [2, 18]}, {"83 83": [3, 0]}, {"83 83": [3, 1]}, {"83 83": [3, 2]}, {"83 83": [3, 3]}, {"83 83": [3, 4]}, {"83 83": [3, 5]}, {"83 83": [3, 6]}, {"83 83": [3, 7]}, {"83 83": [3, 8]}, {"83 83": [3, 9]}, {"83 83": [3, 10]}, {"83 83": [3, 11]}, {"83 83": [3, 12]}, {"83 83": [3, 13]}, {"83 83": [3, 14]}, {"83 83": [3, 15]}, {"83 83": [3, 16]}, {"83 83": [3, 17]}, {"83 83": [3, 18]}, {"83 83": [4, 0]}, {"83 83": [4, 1]}, {"83 83": [4, 2]}, {"83 83": [4, 3]}, {"83 83": [4, 4]}, {"83 83": [4, 5]}, {"83 83": [4, 6]}, {"83 83": [4, 7]}, {"83 83": [4, 8]}, {"83 83": [4, 9]}, {"83 83": [4, 10]}, {"83 83": [4, 11]}, {"83 83": [4, 12]}, {"83 83": [4, 13]}, {"83 83": [4, 14]}, {"83 83": [4, 15]}, {"83 83": [4, 16]}, {"83 83": [4, 17]}, {"83 83": [4, 18]}, {"83 83": [5, 0]}, {"83 83": [5, 1]}, {"83 83": [5, 2]}, {"83 83": [5, 3]}, {"83 83": [5, 4]}, {"83 83": [5, 5]}, {"83 83": [5, 6]}, {"83 83": [5, 7]}, {"83 83": [5, 8]}, {"83 83": [5, 9]}, {"83 83": [5, 10]}, {"83 83": [5, 11]}, {"83 83": [5, 12]}, {"83 83": [5, 13]}, {"83 83": [5, 14]}, {"83 83": [5, 15]}, {"83 83": [5, 16]}, {"83 83": [5, 17]}, {"83 83": [5, 18]}, {"83 83": [6, 0]}, {"83 83": [6, 1]}, {"83 83": [6, 2]}, {"83 83": [6, 3]}, {"83 83": [6, 4]}, {"83 83": [6, 5]}, {"83 83": [6, 6]}, {"83 83": [6, 7]}, {"83 83": [6, 8]}, {"83 83": [6, 9]}, {"83 83": [6, 10]}, {"83 83": [6, 11]}, {"83 83": [6, 12]}, {"83 83": [6, 13]}, {"83 83": [6, 14]}, {"83 83": [6, 15]}, {"83 83": [6, 16]}, {"83 83": [6, 17]}, {"83 83": [6, 18]}, {"83 83": [7, 0]}, {"83 83": [7, 1]}, {"83 83": [7, 2]}, {"83 83": [7, 3]}, {"83 83": [7, 4]}, {"83 83": [7, 5]}, {"83 83": [7, 6]}, {"83 83": [7, 7]}, {"83 83": [7, 8]}, {"83 83": [7, 9]}, {"83 83": [7, 10]}, {"83 83": [7, 11]}, {"83 83": [7, 12]}, {"83 83": [7, 13]}, {"83 83": [7, 14]}, {"83 83": [7, 15]}, {"83 83": [7, 16]}, {"83 83": [7, 17]}, {"83 83": [7, 18]}, {"83 83": [8, 0]}, {"83 83": [8, 1]}, {"83 83": [8, 2]}, {"83 83": [8, 3]}, {"83 83": [8, 4]}, {"83 83": [8, 5]}, {"83 83": [8, 6]}, {"83 83": [8, 7]}, {"83 83": [8, 8]}, {"83 83": [8, 9]}, {"83 83": [8, 10]}, {"83 83": [8, 11]}, {"83 83": [8, 12]}, {"83 83": [8, 13]}, {"83 83": [8, 14]}, {"83 83": [8, 15]}, {"83 83": [8, 16]}, {"83 83": [8, 17]}, {"83 83": [8, 18]}, {"83 83": [9, 0]}, {"83 83": [9, 1]}, {"83 83": [9, 2]}, {"83 83": [9, 3]}, {"83 83": [9, 4]}, {"83 83": [9, 5]}, {"83 83": [9, 6]}, {"83 83": [9, 7]}, {"83 83": [9, 8]}, {"83 83": [9, 9]}, {"83 83": [9, 10]}, {"83 83": [9, 11]}, {"83 83": [9, 12]}, {"83 83": [9, 13]}, {"83 83": [9, 14]}, {"83 83": [9, 15]}, {"83 83": [9, 16]}, {"83 83": [9, 17]}, {"83 83": [9, 18]}, {"83 83": [10, 0]}, {"83 83": [10, 1]}, {"83 83": [10, 2]}, {"83 83": [10, 3]}, {"83 83": [10, 4]}, {"83 83": [10, 5]}, {"83 83": [10, 6]}, {"83 83": [10, 7]}, {"83 83": [10, 8]}, {"83 83": [10, 9]}, {"83 83": [10, 10]}, {"83 83": [10, 11]}, {"83 83": [10, 12]}, {"83 83": [10, 13]}, {"83 83 ...
# o_component=H
# energy_component=summation
# max_element=-1
# statistics=False
# normalizer=False
# boxcox=False
#
# [graph]
# radius=-1.0
# max_num_nbr=0
# create_from_dft=True
# if_lcmp_graph=True
# separate_onsite=False
# new_sp=False
#
# [train]
# epochs=2
# pretrained=
# resume=
# train_ratio=0.6
# val_ratio=0.2
# test_ratio=0.2
# early_stopping_loss=0.0
# early_stopping_loss_epoch=[0.000000, 500]
# revert_then_decay=True
# revert_threshold=30
# revert_decay_epoch=[250, 2500]
# revert_decay_gamma=[0.2, 0.5]
# clip_grad=True
# clip_grad_value=4.2
# switch_sgd=False
# switch_sgd_lr=1e-4
# switch_sgd_epoch=-1
#
# [hyperparameter]
# batch_size=1
# dtype=float32
# optimizer=adam
# learning_rate=0.001
# lr_scheduler=
# lr_milestones=[]
# momentum=0.9
# weight_decay=0
# criterion=MaskMSELoss
# retain_edge_fea=True
# lambda_eij=0.0
# lambda_ei=0.1
# lambda_etot=0.0
#
# [network]
# atom_fea_len=64
# edge_fea_len=128
# gauss_stop=8.5
# num_l=5
# aggr=add
# distance_expansion=GaussianBasis
# if_exp=True
# if_multiplelinear=False
# if_edge_update=True
# if_lcmp=True
# normalization=LayerNorm
# atom_update_net=CGConv
# trainable_gaussians=False
# type_affine=False
#
# Graph data file: HGraph-h5-Bi_soc-5l-FromDFT.pkl
# Use existing graph data file
# Atomic types: [83]
# Finish loading the processed 82 structures (spinful: True, the number of atomic types: 1), cost 1 seconds

# %%
model_kwargs = dict(
    n_elements=num_species,
    num_species=num_species,
    in_atom_fea_len=config.getint('network', 'atom_fea_len'),
    in_vfeats=config.getint('network', 'atom_fea_len'),
    in_edge_fea_len=config.getint('network', 'edge_fea_len'),
    in_efeats=config.getint('network', 'edge_fea_len'),
    out_edge_fea_len=out_fea_len,
    out_efeats=out_fea_len,
    num_orbital=out_fea_len,
    distance_expansion=config.get('network', 'distance_expansion'),
    gauss_stop=config.getfloat('network', 'gauss_stop'),
    cutoff=config.getfloat('network', 'gauss_stop'),
    if_exp=config.getboolean('network', 'if_exp'),
    if_MultipleLinear=config.getboolean('network', 'if_MultipleLinear'),
    if_edge_update=config.getboolean('network', 'if_edge_update'),
    if_lcmp=if_lcmp,
    normalization=config.get('network', 'normalization'),
    atom_update_net=config.get('network', 'atom_update_net', fallback='CGConv'),
    separate_onsite=separate_onsite,
    num_l=config.getint('network', 'num_l'),
    trainable_gaussians=config.getboolean('network', 'trainable_gaussians', fallback=False),
    type_affine=config.getboolean('network', 'type_affine', fallback=False),
    if_fc_out=False,
)
parameter_list = list(signature(HGNN.__init__).parameters.keys())
current_parameter_list = list(model_kwargs.keys())
for k in current_parameter_list:
    if k not in parameter_list:
        model_kwargs.pop(k)
if 'num_elements' in parameter_list:
    model_kwargs['num_elements'] = config.getint('basic', 'max_element') + 1
model = HGNN(**model_kwargs)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print("The model you built has: %d parameters" % params)

# %%
device = torch.device(config.get('basic', 'device') if torch.cuda.is_available() else 'cpu')
model.to(device)
# torch.cuda.is_available()
# Out:
# number of train set: 49
# number of val set: 16
# number of test set: 16
# {'normalizer': False, 'boxcox': False}
# DeepH 2888
# /home/t.hsu/miniconda3/envs/gpu_test/lib/python3.10/site-packages/torch/nn/init.py:412: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# The model you built has: 1138198 parameters
# 80
# Data(
#   x=[36],
#   edge_index=[2, 1472],
#   edge_attr=[1472, 10],
#   stru_id='0',
#   term_mask=[1472],
#   term_real=[1472, 19, 19, 8],
#   atom_num_orbital=[36],
#   subgraph_dict={
#     subgraph_atom_idx=[121080, 2],
#     subgraph_edge_idx=[121080],
#     subgraph_edge_ang=[121080, 25],
#     subgraph_index=[121080],
#   },
#   spinful=[1]
# )
# Epoch 2: New best model saved with loss 3.6212
# Epoch 2: Average Loss = 3.6212
# Epoch 3: New best model saved with loss 0.6115
# Epoch 3: Average Loss = 0.6115
# Epoch 4: New best model saved with loss 0.5593
# Epoch 4: Average Loss = 0.5593
# Epoch 5: Average Loss = 0.5669
# Epoch 6: Average Loss = 0.6217
# Epoch 7: New best model saved with loss 0.5414
# Epoch 7: Average Loss = 0.5414
# Epoch 8: Average Loss = 0.5926
# Epoch 9: New best model saved with loss 0.5225
# Epoch 9: Average Loss = 0.5225
# Epoch 10: Average Loss = 0.5370
# Epoch 11: New best model saved with loss 0.5070
# Epoch 11: Average Loss = 0.5070
# Epoch 12: New best model saved with loss 0.4872
# Epoch 12: Average Loss = 0.4872
# Epoch 13: New best model saved with loss 0.4752
# Epoch 13: Average Loss = 0.4752
# Epoch 14: Average Loss = 0.4927
# Epoch 15: New best model saved with loss 0.4642
# Epoch 15: Average Loss = 0.4642
# Epoch 16: New best model saved with loss 0.4617
# Epoch 16: Average Loss = 0.4617
# Epoch 17: New best model saved with loss 0.4414
# Epoch 17: Average Loss = 0.4414
# Epoch 18: Average Loss = 0.4563
# Epoch 19: Average Loss = 0.4615
# Epoch 20: Average Loss = 0.4421
# Epoch 21: New best model saved with loss 0.4293
# Epoch 21: Average Loss = 0.4293
# Epoch 22: New best model saved with loss 0.4238
# Epoch 22: Average Loss = 0.4238
# Epoch 23: New best model saved with loss 0.4144
# Epoch 23: Average Loss = 0.4144
# Epoch 24: New best model saved with loss 0.4013
# Epoch 24: Average Loss = 0.4013
# Epoch 25: Average Loss = 0.4014
# Epoch 26: Average Loss = 0.4084
# Epoch 27: New best model saved with loss 0.4011
# Epoch 27: Average Loss = 0.4011
# Epoch 28: New best model saved with loss 0.3826
# Epoch 28: Average Loss = 0.3826
# Epoch 29: Average Loss = 0.3874
# Epoch 30: Average Loss = 0.3853
# Epoch 31: Average Loss = 0.3865
# Epoch 32: Average Loss = 0.3830
# Epoch 33: Average Loss = 0.3880
# Epoch 34: Average Loss = 0.3851
# Epoch 35: Average Loss = 0.4061
# Epoch 36: Average Loss = 0.4160
# Epoch 37: Average Loss = 0.3999
# Epoch 38: Average Loss = 0.4003
# Epoch 39: New best model saved with loss 0.3794
# Epoch 39: Average Loss = 0.3794
# Epoch 40: Average Loss = 0.4189
# Epoch 41: Average Loss = 0.3923
# Epoch 42: New best model saved with loss 0.3677
# Epoch 42: Average Loss = 0.3677
# Epoch 43: Average Loss = 0.3931
# Epoch 44: Average Loss = 0.3849
# Epoch 45: Average Loss = 0.3926
# Epoch 46: Average Loss = 0.3760
# Epoch 47: Average Loss = 0.3765
# Epoch 48: New best model saved with loss 0.3670
# Epoch 48: Average Loss = 0.3670
# Epoch 49: Average Loss = 0.3751
# Epoch 50: Average Loss = 0.4070
# Epoch 51: Average Loss = 0.3852
# Epoch 52: Average Loss = 0.3735
# Epoch 53: Average Loss = 0.3771
# Epoch 54: Average Loss = 0.3778
# Epoch 55: New best model saved with loss 0.3652
# Epoch 55: Average Loss = 0.3652
# Epoch 56: Average Loss = 0.4504
# Epoch 57: Average Loss = 0.4190
# Epoch 58: Average Loss = 0.3827
# Epoch 59: Average Loss = 0.3734
# Epoch 60: Average Loss = 0.4068
# Epoch 61: Average Loss = 0.3769
# Epoch 62: New best model saved with loss 0.3616
# Epoch 62: Average Loss = 0.3616
# Epoch 63: Average Loss = 0.3647
# Epoch 64: Average Loss = 0.3800
# Epoch 65: Average Loss = 0.3676
# Epoch 66: Average Loss = 0.3637
# Epoch 67: Average Loss = 0.4051
# Epoch 68: New best model saved with loss 0.3486
# Epoch 68: Average Loss = 0.3486
# Epoch 69: Average Loss = 0.3612
# Epoch 70: New best model saved with loss 0.3380
# Epoch 70: Average Loss = 0.3380
# Epoch 71: Average Loss = 0.3926
# Epoch 72: Average Loss = 0.3572
# Epoch 73: Average Loss = 0.3726
# Epoch 74: Average Loss = 0.3468
# Epoch 75: New best model saved with loss 0.3009
# Epoch 75: Average Loss = 0.3009
# Epoch 76: Average Loss = 0.3519
# Epoch 77: Average Loss = 0.3076
# Epoch 78: Average Loss = 0.3098
# Epoch 79: New best model saved with loss 0.2670
# Epoch 79: Average Loss = 0.2670
# Epoch 80: Average Loss = 0.2933
# Epoch 81: Average Loss = 0.3006
# Epoch 82: Average Loss = 0.2846
# Epoch 83: Average Loss = 0.2897
# Epoch 84: Average Loss = 0.2876
# Epoch 85: Average Loss = 0.2941
# Epoch 86: Average Loss = 0.2775
# Epoch 87: Average Loss = 0.3185
# Epoch 88: Average Loss = 0.3356
# Epoch 89: Average Loss = 0.2896
# Epoch 90: Average Loss = 0.2832
# Epoch 91: Average Loss = 0.2790
# Epoch 92: New best model saved with loss 0.1976
# Epoch 92: Average Loss = 0.1976
# Epoch 93: Average Loss = 0.2023
# Epoch 94: Average Loss = 0.3035
# Epoch 95: Average Loss = 0.2155
# Epoch 96: Average Loss = 0.2210
# Epoch 97: New best model saved with loss 0.1865
# Epoch 97: Average Loss = 0.1865
# Epoch 98: Average Loss = 0.1929
# Epoch 99: New best model saved with loss 0.1636
# Epoch 99: Average Loss = 0.1636
# Epoch 100: New best model saved with loss 0.1580
# Epoch 100: Average Loss = 0.1580
# Epoch 101: New best model saved with loss 0.1560
# Epoch 101: Average Loss = 0.1560
# Epoch 102: New best model saved with loss 0.1518
# Epoch 102: Average Loss = 0.1518
# Epoch 103: New best model saved with loss 0.1207
# Epoch 103: Average Loss = 0.1207
# Epoch 104: New best model saved with loss 0.1148
# Epoch 104: Average Loss = 0.1148
# Epoch 105: Average Loss = 0.1322
# Epoch 106: New best model saved with loss 0.1112
# Epoch 106: Average Loss = 0.1112
# Epoch 107: New best model saved with loss 0.1021
# Epoch 107: Average Loss = 0.1021
# Epoch 108: Average Loss = 0.1043
# Epoch 109: New best model saved with loss 0.1014
# Epoch 109: Average Loss = 0.1014
# Epoch 110: New best model saved with loss 0.0947
# Epoch 110: Average Loss = 0.0947
# Epoch 111: Average Loss = 0.1002
# Epoch 112: New best model saved with loss 0.0925
# Epoch 112: Average Loss = 0.0925
# Epoch 113: Average Loss = 0.0940
# Epoch 114: Average Loss = 0.0945
# Epoch 115: Average Loss = 0.1188
# Epoch 116: Average Loss = 0.0966
# Epoch 117: Average Loss = 0.1175
# Epoch 118: Average Loss = 0.0978
# Epoch 119: New best model saved with loss 0.0889
# Epoch 119: Average Loss = 0.0889
# Epoch 120: Average Loss = 0.1072
# Epoch 121: New best model saved with loss 0.0836
# Epoch 121: Average Loss = 0.0836
# Epoch 122: Average Loss = 0.0844
# Epoch 123: New best model saved with loss 0.0789
# Epoch 123: Average Loss = 0.0789
# Epoch 124: New best model saved with loss 0.0722
# Epoch 124: Average Loss = 0.0722
# Epoch 125: Average Loss = 0.0999
# Epoch 126: Average Loss = 0.1697
# Epoch 127: Average Loss = 0.1207
# Epoch 128: Average Loss = 0.1131
# Epoch 129: Average Loss = 0.0917
# Epoch 130: Average Loss = 0.1009
# Epoch 131: Average Loss = 0.0965
# Epoch 132: Average Loss = 0.1113
# Epoch 133: Average Loss = 0.1019
# Epoch 134: Average Loss = 0.1124
# Epoch 135: Average Loss = 0.1666
# Epoch 136: Average Loss = 0.1600
# Epoch 137: Average Loss = 0.1417
# Epoch 138: Average Loss = 0.0801
# Epoch 139: Average Loss = 0.0815
# Epoch 140: Average Loss = 0.0797
# Epoch 141: Average Loss = 0.0838
# Epoch 142: Average Loss = 0.0783
# Epoch 143: Average Loss = 0.1364
# Epoch 144: Average Loss = 0.0824
# Epoch 145: New best model saved with loss 0.0665
# Epoch 145: Average Loss = 0.0665
# Epoch 146: New best model saved with loss 0.0648
# Epoch 146: Average Loss = 0.0648
# Epoch 147: Average Loss = 0.0677
# Epoch 148: Average Loss = 0.0732
# Epoch 149: New best model saved with loss 0.0624
# Epoch 149: Average Loss = 0.0624
# Epoch 150: Average Loss = 0.0657
# Epoch 151: Average Loss = 0.0966
# Epoch 152: Average Loss = 0.0852
# Epoch 153: Average Loss = 0.0774
# Epoch 154: Average Loss = 0.0894
# Epoch 155: Average Loss = 0.0832
# Epoch 156: Average Loss = 0.0773
# Epoch 157: Average Loss = 0.0941
# Epoch 158: Average Loss = 0.0777
# Epoch 159: Average Loss = 0.0721
# Epoch 160: Average Loss = 0.0632
# Epoch 161: New best model saved with loss 0.0598
# Epoch 161: Average Loss = 0.0598
# Epoch 162: Average Loss = 0.0764
# Epoch 163: Average Loss = 0.0699
# Epoch 164: Average Loss = 0.0722
# Epoch 165: Average Loss = 0.0754
# Epoch 166: Average Loss = 0.0851
# Epoch 167: New best model saved with loss 0.0582
# Epoch 167: Average Loss = 0.0582
# Epoch 168: Average Loss = 0.0687
# Epoch 169: Average Loss = 0.0695
# Epoch 170: Average Loss = 0.0606
# Epoch 171: Average Loss = 0.0601
# Epoch 172: Average Loss = 0.0729
# Epoch 173: Average Loss = 0.0733
# Epoch 174: Average Loss = 0.0626
# Epoch 175: Average Loss = 0.0632
# Epoch 176: Average Loss = 0.0959
# Epoch 177: Average Loss = 0.0891
# Epoch 178: Average Loss = 0.0755
# Epoch 179: Average Loss = 0.0717
# Epoch 180: Average Loss = 0.0655
# Epoch 181: Average Loss = 0.0895
# Epoch 182: Average Loss = 0.0678
# Epoch 183: Average Loss = 0.0615
# Epoch 184: Average Loss = 0.0699
# Epoch 185: Average Loss = 0.0700
# Epoch 186: Average Loss = 0.0711
# Epoch 187: New best model saved with loss 0.0529
# Epoch 187: Average Loss = 0.0529
# Epoch 188: New best model saved with loss 0.0491
# Epoch 188: Average Loss = 0.0491
# Epoch 189: New best model saved with loss 0.0485
# Epoch 189: Average Loss = 0.0485
# Epoch 190: Average Loss = 0.0493
# Epoch 191: Average Loss = 0.0501
# Epoch 192: Average Loss = 0.0521
# Epoch 193: Average Loss = 0.0600
# Epoch 194: Average Loss = 0.0934
# Epoch 195: Average Loss = 0.1144
# Epoch 196: Average Loss = 0.0728
# Epoch 197: Average Loss = 0.0613
# Epoch 198: Average Loss = 0.0518
# Epoch 199: New best model saved with loss 0.0426
# Epoch 199: Average Loss = 0.0426
# Epoch 200: Average Loss = 0.0496
# Epoch 201: Average Loss = 0.0465
# Training complete. Best model saved as 'best_model.pth'.
# /tmp/ipykernel_7223/2398458011.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=12)
# HGNN(
#   (embed): Embedding(6, 64)
#   (distance_expansion): GaussianBasis()
#   (mp1): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp2): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp3): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp4): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp5): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=103, bias=True)
#       (3): SiLU()
#     )
#   )
#   (lcmp): LCMPLayer(
#     (lin_f): Linear(in_features=256, out_features=64, bias=True)
#     (lin_s): Linear(in_features=256, out_features=64, bias=True)
#     (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (e_lin): Sequential(
#       (0): Linear(in_features=231, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=2888, bias=True)
#     )
#   )
#   (dos_fc1): Linear(in_features=0, out_features=512, bias=True)
#   (dos_fc2): Linear(in_features=512, out_features=256, bias=True)
#   (dos_fc3): Linear(in_features=256, out_features=128, bias=True)
#   (dos_fc4): Linear(in_features=128, out_features=999, bias=True)
# )

# %%
def make_mask(dataset):
    spinful = True
    target = 'hamiltonian'
    num_orbital = kernel.num_orbital
    dataset_mask = []
    for i, data in enumerate(dataset):
        # filename = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(i)
        # aux = np.loadtxt(filename)

        # dos = torch.tensor(aux[:,1], dtype=torch.float32)  # Convert to tensor if not already
        # dos = dos.view(-1)
        Oij_value = data.term_real
        if data.term_real is not None:
            if_only_rc = False

        if spinful:
            out_fea_len = num_orbital * 8
            # out_fea_len = 999
            
        mask = torch.zeros(data.edge_attr.shape[0], out_fea_len, dtype=torch.int8)
        label = torch.zeros(data.edge_attr.shape[0], out_fea_len, dtype=torch.get_default_dtype())
        y = torch.zeros(data.edge_attr.shape[0], 999, dtype=torch.get_default_dtype())

        atomic_number_edge_i = kernel.index_to_Z[data.x[data.edge_index[0]]]
        atomic_number_edge_j = kernel.index_to_Z[data.x[data.edge_index[1]]]

        for index_out, orbital_dict in enumerate(kernel.orbital):
            for N_M_str, a_b in orbital_dict.items():
                # N_M, a_b means: H_{ia, jb} when the atomic number of atom i is N and the atomic number of atom j is M
                condition_atomic_number_i, condition_atomic_number_j = map(lambda x: int(x), N_M_str.split())
                condition_orbital_i, condition_orbital_j = a_b

                if spinful:
                    if target == 'phiVdphi':
                        raise NotImplementedError("Not yet have support for phiVdphi")
                    else:
                        mask[:, 8 * index_out:8 * (index_out + 1)] = torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )[:, None].repeat(1, 8)
                else:
                    if target == 'phiVdphi':
                        mask[:, 3 * index_out:3 * (index_out + 1)] += torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )[:, None].repeat(1, 3)
                    else:
                        mask[:, index_out] += torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )

                if if_only_rc == False:
                    if spinful:
                        if target == 'phiVdphi':
                            raise NotImplementedError
                        else:
                            label[:, 8 * index_out:8 * (index_out + 1)] = torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j].t(),
                                torch.zeros(8, data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            ).t()


                    else:
                        if target == 'phiVdphi':
                            label[:, 3 * index_out:3 * (index_out + 1)] = torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j].t(),
                                torch.zeros(3, data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            ).t()
                        else:
                            label[:, index_out] += torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j],
                                torch.zeros(data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            )
        assert len(torch.where((mask != 1) & (mask != 0))[0]) == 0
        mask = mask.bool()
        data.mask = mask
        del data.term_mask
        if if_only_rc == False:
            data.label = label
            data.y = y
            if target == 'hamiltonian' or target == 'density_matrix':
                del data.term_real
        dataset_mask.append(data)
    return dataset_mask

# %%
dataset_size = len(dataset)
print(dataset_size)
print(dataset[0])
dataset = make_mask(dataset)
# Iterating over the 81 graph.
# for i in range(len(dataset)):
#     print(i)
#     filename = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(i)
#     aux = np.loadtxt(filename)

#     # Extract the first and second columns
#     energy = aux[:, 0]
#     # dos = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())

#     # # aux2 = dataset[i].label[:,:len(dos)]
#     # dataset[i].y = dos.expand((dataset[i].label.shape[0]), -1)
#     dataset[i].y = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())
    

for i, data in enumerate(dataset):
    stru_id = int(data.stru_id)
    dir_path = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(stru_id)
    aux = np.loadtxt(dir_path)

    # Extract the first and second columns
    energy = aux[:, 0]
    # dos = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())

    # # aux2 = dataset[i].label[:,:len(dos)]
    # dataset[i].y = dos.expand((dataset[i].label.shape[0]), -1)
    dataset[i].y = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())

# %%
dataset[:]
# Out:
# [Data(
#    x=[36],
#    edge_index=[2, 1472],
#    edge_attr=[1472, 10],
#    stru_id='0',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121080, 2],
#      subgraph_edge_idx=[121080],
#      subgraph_edge_ang=[121080, 25],
#      subgraph_index=[121080],
#    },
#    spinful=[1],
#    mask=[1472, 2888],
#    label=[1472, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1462],
#    edge_attr=[1462, 10],
#    stru_id='1',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[119580, 2],
#      subgraph_edge_idx=[119580],
#      subgraph_edge_ang=[119580, 25],
#      subgraph_index=[119580],
#    },
#    spinful=[1],
#    mask=[1462, 2888],
#    label=[1462, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1456],
#    edge_attr=[1456, 10],
#    stru_id='10',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118688, 2],
#      subgraph_edge_idx=[118688],
#      subgraph_edge_ang=[118688, 25],
#      subgraph_index=[118688],
#    },
#    spinful=[1],
#    mask=[1456, 2888],
#    label=[1456, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1490],
#    edge_attr=[1490, 10],
#    stru_id='11',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124228, 2],
#      subgraph_edge_idx=[124228],
#      subgraph_edge_ang=[124228, 25],
#      subgraph_index=[124228],
#    },
#    spinful=[1],
#    mask=[1490, 2888],
#    label=[1490, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='12',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128756, 2],
#      subgraph_edge_idx=[128756],
#      subgraph_edge_ang=[128756, 25],
#      subgraph_index=[128756],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1546],
#    edge_attr=[1546, 10],
#    stru_id='13',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[133460, 2],
#      subgraph_edge_idx=[133460],
#      subgraph_edge_ang=[133460, 25],
#      subgraph_index=[133460],
#    },
#    spinful=[1],
#    mask=[1546, 2888],
#    label=[1546, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1598],
#    edge_attr=[1598, 10],
#    stru_id='14',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[142364, 2],
#      subgraph_edge_idx=[142364],
#      subgraph_edge_ang=[142364, 25],
#      subgraph_index=[142364],
#    },
#    spinful=[1],
#    mask=[1598, 2888],
#    label=[1598, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='15',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='16',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128796, 2],
#      subgraph_edge_idx=[128796],
#      subgraph_edge_ang=[128796, 25],
#      subgraph_index=[128796],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1492],
#    edge_attr=[1492, 10],
#    stru_id='17',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124556, 2],
#      subgraph_edge_idx=[124556],
#      subgraph_edge_ang=[124556, 25],
#      subgraph_index=[124556],
#    },
#    spinful=[1],
#    mask=[1492, 2888],
#    label=[1492, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='18',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129984, 2],
#      subgraph_edge_idx=[129984],
#      subgraph_edge_ang=[129984, 25],
#      subgraph_index=[129984],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1476],
#    edge_attr=[1476, 10],
#    stru_id='19',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[122184, 2],
#      subgraph_edge_idx=[122184],
#      subgraph_edge_ang=[122184, 25],
#      subgraph_index=[122184],
#    },
#    spinful=[1],
#    mask=[1476, 2888],
#    label=[1476, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='2',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128952, 2],
#      subgraph_edge_idx=[128952],
#      subgraph_edge_ang=[128952, 25],
#      subgraph_index=[128952],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='20',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129320, 2],
#      subgraph_edge_idx=[129320],
#      subgraph_edge_ang=[129320, 25],
#      subgraph_index=[129320],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='21',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130984, 2],
#      subgraph_edge_idx=[130984],
#      subgraph_edge_ang=[130984, 25],
#      subgraph_index=[130984],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1564],
#    edge_attr=[1564, 10],
#    stru_id='22',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[136512, 2],
#      subgraph_edge_idx=[136512],
#      subgraph_edge_ang=[136512, 25],
#      subgraph_index=[136512],
#    },
#    spinful=[1],
#    mask=[1564, 2888],
#    label=[1564, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1586],
#    edge_attr=[1586, 10],
#    stru_id='23',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140212, 2],
#      subgraph_edge_idx=[140212],
#      subgraph_edge_ang=[140212, 25],
#      subgraph_index=[140212],
#    },
#    spinful=[1],
#    mask=[1586, 2888],
#    label=[1586, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1604],
#    edge_attr=[1604, 10],
#    stru_id='24',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[143408, 2],
#      subgraph_edge_idx=[143408],
#      subgraph_edge_ang=[143408, 25],
#      subgraph_index=[143408],
#    },
#    spinful=[1],
#    mask=[1604, 2888],
#    label=[1604, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1558],
#    edge_attr=[1558, 10],
#    stru_id='25',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135504, 2],
#      subgraph_edge_idx=[135504],
#      subgraph_edge_ang=[135504, 25],
#      subgraph_index=[135504],
#    },
#    spinful=[1],
#    mask=[1558, 2888],
#    label=[1558, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1526],
#    edge_attr=[1526, 10],
#    stru_id='26',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130232, 2],
#      subgraph_edge_idx=[130232],
#      subgraph_edge_ang=[130232, 25],
#      subgraph_index=[130232],
#    },
#    spinful=[1],
#    mask=[1526, 2888],
#    label=[1526, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1538],
#    edge_attr=[1538, 10],
#    stru_id='27',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132204, 2],
#      subgraph_edge_idx=[132204],
#      subgraph_edge_ang=[132204, 25],
#      subgraph_index=[132204],
#    },
#    spinful=[1],
#    mask=[1538, 2888],
#    label=[1538, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='28',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125084, 2],
#      subgraph_edge_idx=[125084],
#      subgraph_edge_ang=[125084, 25],
#      subgraph_index=[125084],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1498],
#    edge_attr=[1498, 10],
#    stru_id='29',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125712, 2],
#      subgraph_edge_idx=[125712],
#      subgraph_edge_ang=[125712, 25],
#      subgraph_index=[125712],
#    },
#    spinful=[1],
#    mask=[1498, 2888],
#    label=[1498, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1528],
#    edge_attr=[1528, 10],
#    stru_id='3',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130484, 2],
#      subgraph_edge_idx=[130484],
#      subgraph_edge_ang=[130484, 25],
#      subgraph_index=[130484],
#    },
#    spinful=[1],
#    mask=[1528, 2888],
#    label=[1528, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='30',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129288, 2],
#      subgraph_edge_idx=[129288],
#      subgraph_edge_ang=[129288, 25],
#      subgraph_index=[129288],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='31',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1586],
#    edge_attr=[1586, 10],
#    stru_id='32',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140216, 2],
#      subgraph_edge_idx=[140216],
#      subgraph_edge_ang=[140216, 25],
#      subgraph_index=[140216],
#    },
#    spinful=[1],
#    mask=[1586, 2888],
#    label=[1586, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1674],
#    edge_attr=[1674, 10],
#    stru_id='33',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[156132, 2],
#      subgraph_edge_idx=[156132],
#      subgraph_edge_ang=[156132, 25],
#      subgraph_index=[156132],
#    },
#    spinful=[1],
#    mask=[1674, 2888],
#    label=[1674, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='34',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141636, 2],
#      subgraph_edge_idx=[141636],
#      subgraph_edge_ang=[141636, 25],
#      subgraph_index=[141636],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='35',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135124, 2],
#      subgraph_edge_idx=[135124],
#      subgraph_edge_ang=[135124, 25],
#      subgraph_index=[135124],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1552],
#    edge_attr=[1552, 10],
#    stru_id='36',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134612, 2],
#      subgraph_edge_idx=[134612],
#      subgraph_edge_ang=[134612, 25],
#      subgraph_index=[134612],
#    },
#    spinful=[1],
#    mask=[1552, 2888],
#    label=[1552, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='37',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129820, 2],
#      subgraph_edge_idx=[129820],
#      subgraph_edge_ang=[129820, 25],
#      subgraph_index=[129820],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='38',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124752, 2],
#      subgraph_edge_idx=[124752],
#      subgraph_edge_ang=[124752, 25],
#      subgraph_index=[124752],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1526],
#    edge_attr=[1526, 10],
#    stru_id='39',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130296, 2],
#      subgraph_edge_idx=[130296],
#      subgraph_edge_ang=[130296, 25],
#      subgraph_index=[130296],
#    },
#    spinful=[1],
#    mask=[1526, 2888],
#    label=[1526, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1550],
#    edge_attr=[1550, 10],
#    stru_id='4',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134144, 2],
#      subgraph_edge_idx=[134144],
#      subgraph_edge_ang=[134144, 25],
#      subgraph_index=[134144],
#    },
#    spinful=[1],
#    mask=[1550, 2888],
#    label=[1550, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='40',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134964, 2],
#      subgraph_edge_idx=[134964],
#      subgraph_edge_ang=[134964, 25],
#      subgraph_index=[134964],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1596],
#    edge_attr=[1596, 10],
#    stru_id='41',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[142036, 2],
#      subgraph_edge_idx=[142036],
#      subgraph_edge_ang=[142036, 25],
#      subgraph_index=[142036],
#    },
#    spinful=[1],
#    mask=[1596, 2888],
#    label=[1596, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='42',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141628, 2],
#      subgraph_edge_idx=[141628],
#      subgraph_edge_ang=[141628, 25],
#      subgraph_index=[141628],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1590],
#    edge_attr=[1590, 10],
#    stru_id='43',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140924, 2],
#      subgraph_edge_idx=[140924],
#      subgraph_edge_ang=[140924, 25],
#      subgraph_index=[140924],
#    },
#    spinful=[1],
#    mask=[1590, 2888],
#    label=[1590, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='44',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141700, 2],
#      subgraph_edge_idx=[141700],
#      subgraph_edge_ang=[141700, 25],
#      subgraph_index=[141700],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1560],
#    edge_attr=[1560, 10],
#    stru_id='45',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135992, 2],
#      subgraph_edge_idx=[135992],
#      subgraph_edge_ang=[135992, 25],
#      subgraph_index=[135992],
#    },
#    spinful=[1],
#    mask=[1560, 2888],
#    label=[1560, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1532],
#    edge_attr=[1532, 10],
#    stru_id='46',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130864, 2],
#      subgraph_edge_idx=[130864],
#      subgraph_edge_ang=[130864, 25],
#      subgraph_index=[130864],
#    },
#    spinful=[1],
#    mask=[1532, 2888],
#    label=[1532, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1536],
#    edge_attr=[1536, 10],
#    stru_id='47',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[131824, 2],
#      subgraph_edge_idx=[131824],
#      subgraph_edge_ang=[131824, 25],
#      subgraph_index=[131824],
#    },
#    spinful=[1],
#    mask=[1536, 2888],
#    label=[1536, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1538],
#    edge_attr=[1538, 10],
#    stru_id='48',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132140, 2],
#      subgraph_edge_idx=[132140],
#      subgraph_edge_ang=[132140, 25],
#      subgraph_index=[132140],
#    },
#    spinful=[1],
#    mask=[1538, 2888],
#    label=[1538, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1532],
#    edge_attr=[1532, 10],
#    stru_id='49',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130864, 2],
#      subgraph_edge_idx=[130864],
#      subgraph_edge_ang=[130864, 25],
#      subgraph_index=[130864],
#    },
#    spinful=[1],
#    mask=[1532, 2888],
#    label=[1532, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1552],
#    edge_attr=[1552, 10],
#    stru_id='5',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134556, 2],
#      subgraph_edge_idx=[134556],
#      subgraph_edge_ang=[134556, 25],
#      subgraph_index=[134556],
#    },
#    spinful=[1],
#    mask=[1552, 2888],
#    label=[1552, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='50',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135280, 2],
#      subgraph_edge_idx=[135280],
#      subgraph_edge_ang=[135280, 25],
#      subgraph_index=[135280],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='51',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135100, 2],
#      subgraph_edge_idx=[135100],
#      subgraph_edge_ang=[135100, 25],
#      subgraph_index=[135100],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1560],
#    edge_attr=[1560, 10],
#    stru_id='52',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135780, 2],
#      subgraph_edge_idx=[135780],
#      subgraph_edge_ang=[135780, 25],
#      subgraph_index=[135780],
#    },
#    spinful=[1],
#    mask=[1560, 2888],
#    label=[1560, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='53',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='54',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129496, 2],
#      subgraph_edge_idx=[129496],
#      subgraph_edge_ang=[129496, 25],
#      subgraph_index=[129496],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='55',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129392, 2],
#      subgraph_edge_idx=[129392],
#      subgraph_edge_ang=[129392, 25],
#      subgraph_index=[129392],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1542],
#    edge_attr=[1542, 10],
#    stru_id='56',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132768, 2],
#      subgraph_edge_idx=[132768],
#      subgraph_edge_ang=[132768, 25],
#      subgraph_index=[132768],
#    },
#    spinful=[1],
#    mask=[1542, 2888],
#    label=[1542, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1670],
#    edge_attr=[1670, 10],
#    stru_id='57',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[155856, 2],
#      subgraph_edge_idx=[155856],
#      subgraph_edge_ang=[155856, 25],
#      subgraph_index=[155856],
#    },
#    spinful=[1],
#    mask=[1670, 2888],
#    label=[1670, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1542],
#    edge_attr=[1542, 10],
#    stru_id='58',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132764, 2],
#      subgraph_edge_idx=[132764],
#      subgraph_edge_ang=[132764, 25],
#      subgraph_index=[132764],
#    },
#    spinful=[1],
#    mask=[1542, 2888],
#    label=[1542, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='59',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129896, 2],
#      subgraph_edge_idx=[129896],
#      subgraph_edge_ang=[129896, 25],
#      subgraph_index=[129896],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='6',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129656, 2],
#      subgraph_edge_idx=[129656],
#      subgraph_edge_ang=[129656, 25],
#      subgraph_index=[129656],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='60',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129652, 2],
#      subgraph_edge_idx=[129652],
#      subgraph_edge_ang=[129652, 25],
#      subgraph_index=[129652],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='61',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128120, 2],
#      subgraph_edge_idx=[128120],
#      subgraph_edge_ang=[128120, 25],
#      subgraph_index=[128120],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='62',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129100, 2],
#      subgraph_edge_idx=[129100],
#      subgraph_edge_ang=[129100, 25],
#      subgraph_index=[129100],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='63',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128372, 2],
#      subgraph_edge_idx=[128372],
#      subgraph_edge_ang=[128372, 25],
#      subgraph_index=[128372],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1502],
#    edge_attr=[1502, 10],
#    stru_id='64',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[126444, 2],
#      subgraph_edge_idx=[126444],
#      subgraph_edge_ang=[126444, 25],
#      subgraph_index=[126444],
#    },
#    spinful=[1],
#    mask=[1502, 2888],
#    label=[1502, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1478],
#    edge_attr=[1478, 10],
#    stru_id='65',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[122072, 2],
#      subgraph_edge_idx=[122072],
#      subgraph_edge_ang=[122072, 25],
#      subgraph_index=[122072],
#    },
#    spinful=[1],
#    mask=[1478, 2888],
#    label=[1478, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1536],
#    edge_attr=[1536, 10],
#    stru_id='66',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[131768, 2],
#      subgraph_edge_idx=[131768],
#      subgraph_edge_ang=[131768, 25],
#      subgraph_index=[131768],
#    },
#    spinful=[1],
#    mask=[1536, 2888],
#    label=[1536, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1548],
#    edge_attr=[1548, 10],
#    stru_id='67',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[133932, 2],
#      subgraph_edge_idx=[133932],
#      subgraph_edge_ang=[133932, 25],
#      subgraph_index=[133932],
#    },
#    spinful=[1],
#    mask=[1548, 2888],
#    label=[1548, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1470],
#    edge_attr=[1470, 10],
#    stru_id='68',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[120716, 2],
#      subgraph_edge_idx=[120716],
#      subgraph_edge_ang=[120716, 25],
#      subgraph_index=[120716],
#    },
#    spinful=[1],
#    mask=[1470, 2888],
#    label=[1470, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1496],
#    edge_attr=[1496, 10],
#    stru_id='69',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125384, 2],
#      subgraph_edge_idx=[125384],
#      subgraph_edge_ang=[125384, 25],
#      subgraph_index=[125384],
#    },
#    spinful=[1],
#    mask=[1496, 2888],
#    label=[1496, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='7',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129648, 2],
#      subgraph_edge_idx=[129648],
#      subgraph_edge_ang=[129648, 25],
#      subgraph_index=[129648],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='70',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128984, 2],
#      subgraph_edge_idx=[128984],
#      subgraph_edge_ang=[128984, 25],
#      subgraph_index=[128984],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1490],
#    edge_attr=[1490, 10],
#    stru_id='71',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124228, 2],
#      subgraph_edge_idx=[124228],
#      subgraph_edge_ang=[124228, 25],
#      subgraph_index=[124228],
#    },
#    spinful=[1],
#    mask=[1490, 2888],
#    label=[1490, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1454],
#    edge_attr=[1454, 10],
#    stru_id='72',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118396, 2],
#      subgraph_edge_idx=[118396],
#      subgraph_edge_ang=[118396, 25],
#      subgraph_index=[118396],
#    },
#    spinful=[1],
#    mask=[1454, 2888],
#    label=[1454, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1474],
#    edge_attr=[1474, 10],
#    stru_id='73',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121860, 2],
#      subgraph_edge_idx=[121860],
#      subgraph_edge_ang=[121860, 25],
#      subgraph_index=[121860],
#    },
#    spinful=[1],
#    mask=[1474, 2888],
#    label=[1474, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='74',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125052, 2],
#      subgraph_edge_idx=[125052],
#      subgraph_edge_ang=[125052, 25],
#      subgraph_index=[125052],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='75',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128244, 2],
#      subgraph_edge_idx=[128244],
#      subgraph_edge_ang=[128244, 25],
#      subgraph_index=[128244],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='76',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130500, 2],
#      subgraph_edge_idx=[130500],
#      subgraph_edge_ang=[130500, 25],
#      subgraph_index=[130500],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='77',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130944, 2],
#      subgraph_edge_idx=[130944],
#      subgraph_edge_ang=[130944, 25],
#      subgraph_index=[130944],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1506],
#    edge_attr=[1506, 10],
#    stru_id='78',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[127132, 2],
#      subgraph_edge_idx=[127132],
#      subgraph_edge_ang=[127132, 25],
#      subgraph_index=[127132],
#    },
#    spinful=[1],
#    mask=[1506, 2888],
#    label=[1506, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1474],
#    edge_attr=[1474, 10],
#    stru_id='79',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121860, 2],
#      subgraph_edge_idx=[121860],
#      subgraph_edge_ang=[121860, 25],
#      subgraph_index=[121860],
#    },
#    spinful=[1],
#    mask=[1474, 2888],
#    label=[1474, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1456],
#    edge_attr=[1456, 10],
#    stru_id='8',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118688, 2],
#      subgraph_edge_idx=[118688],
#      subgraph_edge_ang=[118688, 25],
#      subgraph_index=[118688],
#    },
#    spinful=[1],
#    mask=[1456, 2888],
#    label=[1456, 2888],
#    y=[999]
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1458],
#    edge_attr=[1458, 10],
#    stru_id='9',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118988, 2],
#      subgraph_edge_idx=[118988],
#      subgraph_edge_ang=[118988, 25],
#      subgraph_index=[118988],
#    },
#    spinful=[1],
#    mask=[1458, 2888],
#    label=[1458, 2888],
#    y=[999]
#  )]

# %%
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2
train_size = int(train_ratio * dataset_size)
val_size = int(val_ratio * dataset_size)
test_size = int(test_ratio * dataset_size)
indices = list(range(dataset_size))
np.random.shuffle(indices)
train_sampler = SubsetRandomSampler(indices[:train_size])
val_sampler = SubsetRandomSampler(indices[train_size:train_size + val_size])
test_sampler = SubsetRandomSampler(indices[train_size + val_size:train_size + val_size + test_size])
from deeph.graph import Collater

train_loader = DataLoader(dataset, batch_size=1,
                            shuffle=False, sampler=train_sampler,
                            collate_fn=Collater(True))
val_loader = DataLoader(dataset, batch_size=1,
                        shuffle=False, sampler=val_sampler,
                        collate_fn=Collater(True))
test_loader = DataLoader(dataset, batch_size=1,
                            shuffle=False, sampler=test_sampler,
                            collate_fn=Collater(True))

# %%
lr1 = 1e-3
weight_decay = 0
criterion_hamil= nn.MSELoss()  
criterion_dos = nn.SmoothL1Loss()
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
# optimizer = optim.SGD(model_parameters, lr=learning_rate, weight_decay=weight_decay)
optimizer = optim.Adam(model_parameters, lr=lr1, betas=(0.9, 0.999))
best_loss = float('inf')
best_model_path =  '/home/t.hsu/deeph_dev/DOS_best_multimodal.pth'


epochs = np.arange(1, 201)
losses = []
for e in epochs:
    model.train()
    epoch_loss = 0
    num_batches = 0
    for step, batch_tuple in enumerate(train_loader):
        if if_lcmp:
            batch, subgraph = batch_tuple
            sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index = subgraph
            out_hamil, out_dos = model(
                batch.x.to(device),
                batch.edge_index.to(device),
                batch.edge_attr.to(device),
                batch.batch.to(device),
                sub_atom_idx.to(device),
                sub_edge_idx.to(device),
                sub_edge_ang.to(device),
                sub_index.to(device)
                    )
            
            labels_hamil = batch.label.to(device)
            labels_dos = batch.y.to(device)
            
            loss_hamil = criterion_hamil(out_hamil,labels_hamil)
            loss_dos = criterion_dos(out_dos,labels_dos)
            total_loss = loss_hamil + loss_dos


            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()
            
            epoch_loss += total_loss.item()
            num_batches += 1
            
    avg_epoch_loss = epoch_loss / num_batches
    losses.append(avg_epoch_loss)
    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss  # Update the best loss
        torch.save(model.state_dict(), best_model_path)  # Save the model with the best loss
        print(f"Epoch {e+1}: New best model saved with loss {best_loss:.4f}")

    print(f"Epoch {e+1}: Average Loss = {avg_epoch_loss:.4f}")

print("Training complete. Best model saved as 'best_model.pth'.")

# %%
out_hamil.shape
# Out:
# torch.Size([1560, 2888])

# %%
out_dos.shape
# Out:
# torch.Size([999])

# %%
losses
# Out:
# [3.6212333465615907,
#  0.6114782188087702,
#  0.5592988226562738,
#  0.5669349264353514,
#  0.6217320368935665,
#  0.5413666379948457,
#  0.5926033227394024,
#  0.522522349221011,
#  0.537021412824591,
#  0.5069631027678648,
#  0.4871802603205045,
#  0.4752286998555064,
#  0.4927178568517168,
#  0.46418824574599665,
#  0.4617477323239048,
#  0.44135788455605507,
#  0.45626127409438294,
#  0.46146558535595733,
#  0.44212267206360895,
#  0.4293154754365484,
#  0.4237619712948799,
#  0.4143761418138941,
#  0.40125062006215256,
#  0.40139592594156664,
#  0.40837052557617426,
#  0.4010717899849017,
#  0.3826303188689053,
#  0.38736822673430044,
#  0.3852848845223586,
#  0.3864709908763568,
#  0.3829679104189078,
#  0.38802850898355246,
#  0.38510334010546404,
#  0.40613778059681255,
#  0.4160213101034363,
#  0.39994134039928514,
#  0.4003199826305111,
#  0.37941657689710456,
#  0.4189091147854924,
#  0.39232585051407415,
#  0.36767247583096224,
#  0.3930664860333006,
#  0.3849159236997366,
#  0.3925873606155316,
#  0.3760019834153354,
#  0.3765198409867783,
#  0.3670459156855941,
#  0.37505799656112987,
#  0.40697597541535896,
#  0.3852483695372939,
#  0.37349320234109956,
#  0.37710763653740287,
#  0.37782432045787573,
#  0.3652410727615158,
#  0.4504048718760411,
#  0.41898752997318905,
#  0.3827479253523052,
#  0.37337100645527244,
#  0.4067604358618458,
#  0.3769110964300732,
#  0.3615556180787583,
#  0.36472819838672876,
#  0.3800398920041819,
#  0.3675519432872534,
#  0.3637406782557567,
#  0.4050940653930108,
#  0.3486245636207362,
#  0.3611503780509035,
#  0.3379908778394262,
#  0.3926375994148354,
#  0.3571827883521716,
#  0.37257124576717615,
#  0.3468396913570662,
#  0.3008893462829292,
#  0.3518525715917349,
#  0.30755913024768233,
#  0.3097745600777368,
#  0.2669964813782523,
#  0.2933141109533608,
#  0.3005757359787822,
#  0.28463342304651934,
#  0.28971025922025245,
#  0.2875817279952268,
#  0.2940757748049994,
#  0.2775384696821372,
#  0.31850670541947085,
#  0.33559208425382775,
#  0.28962900349870324,
#  0.28316424290339154,
#  0.2790361052999894,
#  0.19758283207193017,
#  0.20227990252897143,
#  0.3034768363771339,
#  0.21553416612247625,
#  0.22097270330414176,
#  0.18646296548346677,
#  0.19289883210634193,
#  0.16360625865248343,
#  0.15799555531702936,
#  0.1560464974027127,
#  0.15179661327662566,
#  0.12071293126791716,
#  0.11482587464464207,
#  0.13217935509358844,
#  0.11115142183067898,
#  0.10211571018832426,
#  0.10428245381141703,
#  0.10136216521884005,
#  0.09467778467418005,
#  0.10020888907214005,
#  0.09253825852647424,
#  0.09397031522045533,
#  0.09446103226703902,
#  0.11884203537677725,
#  0.09661534568294883,
#  0.11754715691010158,
#  0.09782133352321883,
#  0.08892708244578292,
#  0.10722444121104975,
#  0.08359954925253987,
#  0.08441979034493367,
#  0.07890040260584404,
#  0.07219492527656257,
#  0.09985654312185943,
#  0.16965234248588482,
#  0.12074144145784278,
#  0.11314030721162756,
#  0.09167189147168149,
#  0.10091446355606119,
#  0.0965416250595202,
#  0.11128460189017157,
#  0.10191388335078955,
#  0.11237997538410127,
#  0.1666249541255335,
#  0.160012491280213,
#  0.14172489708289504,
#  0.08007053635083139,
#  0.08153006108477712,
#  0.07970168468697618,
#  0.08382690825965255,
#  0.07825014868285507,
#  0.13635035883635283,
#  0.08243120484985411,
#  0.06647933604350935,
#  0.06481271931746353,
#  0.06771115694815914,
#  0.07317906812143822,
#  0.06236230011563748,
#  0.06570832233410329,
#  0.0965681488936146,
#  0.08521409080519031,
#  0.07744355158259471,
#  0.08939249289687723,
#  0.08316478723039229,
#  0.07728001374440889,
#  0.0941439747499923,
#  0.07768928678706288,
#  0.07211470378873248,
#  0.06316852965392172,
#  0.059843437164090574,
#  0.0764401825144887,
#  0.06987075831663485,
#  0.07224636963413407,
#  0.07538270601071417,
#  0.08506445536234726,
#  0.05823008234923085,
#  0.06867732433602214,
#  0.06953620945569128,
#  0.060626741110657655,
#  0.06011545685275147,
#  0.0729292092534403,
#  0.07334762741811574,
#  0.0625723887545367,
#  0.06324491451960057,
#  0.095907717749166,
#  0.08912241540383548,
#  0.07546175748575479,
#  0.07172478064118575,
#  0.0654618430417031,
#  0.08946170995477587,
#  0.06780199951026589,
#  0.061488653028694294,
#  0.06988683226518333,
#  0.0700410339826097,
#  0.07112771656829864,
#  0.05292202935864528,
#  0.04910737472043062,
#  0.04851749900262803,
#  0.04934134006422634,
#  0.050051669124513865,
#  0.0521055527885134,
#  0.060047585827608906,
#  0.09338534406075875,
#  0.1143784859450534,
#  0.07281653167835127,
#  0.061250883426206805,
#  0.05184748213893423,
#  0.04263426964947333,
#  0.049576178387117885,
#  0.046521463412015386]

# %%
import matplotlib.pyplot as plt
plt.plot(epochs,losses)

plt.title('Training Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)

plt.grid(True)

# Ticks and limits
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim([1, 101])
plt.ylim([min(losses) - 0.0001, max(losses) + 0.0001])

# Adding legend
plt.legend(fontsize=12)
plt.show()

# %%
x = np.linspace(-20, 20, 999) 
plt.figure(figsize=(10, 6))
plt.plot(x, labels_dos.cpu().detach().numpy(),color='black', label = 'Target labels')
plt.plot(x, out_dos.cpu().detach().numpy(),color='red', linestyle= '--', label = 'Model output')
plt.xlabel('Energy')
plt.ylabel('DOS')
plt.title('Density of States vs. Energy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.load_state_dict(torch.load(best_model_path))
model.eval()
difference = []
with torch.no_grad():
    for step, batch_tuple in enumerate(test_loader):
        batch, subgraph = batch_tuple
        sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index = subgraph
        pred_hamil, pred_dos = model(
            batch.x.to(device),
            batch.edge_index.to(device),
            batch.edge_attr.to(device),
            batch.batch.to(device),
            sub_atom_idx.to(device),
            sub_edge_idx.to(device),
            sub_edge_ang.to(device),
            sub_index.to(device)
                )
            
        labels_hamil = batch.label.to(device)
        labels_dos = batch.y.to(device)
        difference_aux = sum(pred_dos.cpu().detach().numpy() - labels_dos.cpu().detach().numpy())
        difference.append(difference_aux)
        
        x = np.linspace(-20, 20, 999) 
        plt.figure(figsize=(10, 6))
        plt.plot(x, labels_dos.cpu().detach().numpy(),color='black', label = 'Target labels')
        plt.plot(x, pred_dos.cpu().detach().numpy(),color='red', linestyle= '--', label = 'Model output')
        plt.xlabel('Energy')
        plt.ylabel('DOS')
        plt.title('Density of States vs. Energy, Diff ={}'.format(difference_aux))
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
sum(difference)
# Out:
# -333.11863106757664
