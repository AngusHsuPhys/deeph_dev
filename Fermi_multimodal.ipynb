# %%
import os
from typing import Union, Tuple
from math import ceil, sqrt
from torch.utils.data import SubsetRandomSampler, DataLoader

import torch
from torch import nn
import torch.nn.functional as F
from torch import package
from torch.nn import MSELoss, L1Loss, SmoothL1Loss
import torch.optim as optim
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.norm import LayerNorm, PairNorm, InstanceNorm
from torch_geometric.typing import PairTensor, Adj, OptTensor, Size
from torch_geometric.nn.inits import glorot, zeros
from torch_geometric.utils import softmax
from torch_geometric.nn.models.dimenet import BesselBasisLayer
from torch_scatter import scatter_add, scatter
import numpy as np
from scipy.special import comb
from deeph.data import HData

from deeph.from_se3_transformer import SphericalHarmonics
from deeph.from_schnetpack import GaussianBasis
from deeph.from_PyG_future import GraphNorm, DiffGroupNorm
from deeph.from_HermNet import RBF, cosine_cutoff, ShiftedSoftplus, _eps
from inspect import signature
from deeph.utils import LossRecord

# %%
class CGConv(MessagePassing):
    def __init__(self, channels: Union[int, Tuple[int, int]], dim: int = 0,
                 aggr: str = 'add', normalization: str = None,
                 bias: bool = True, if_exp: bool = False, **kwargs):
        super(CGConv, self).__init__(aggr=aggr, flow="source_to_target", **kwargs)
        self.channels = channels
        self.dim = dim
        self.normalization = normalization
        self.if_exp = if_exp

        if isinstance(channels, int):
            channels = (channels, channels)

        self.lin_f = nn.Linear(sum(channels) + dim, channels[1], bias=bias)
        self.lin_s = nn.Linear(sum(channels) + dim, channels[1], bias=bias)
        if self.normalization == 'BatchNorm':
            self.bn = nn.BatchNorm1d(channels[1], track_running_stats=True)
        elif self.normalization == 'LayerNorm':
            self.ln = LayerNorm(channels[1])
        elif self.normalization == 'PairNorm':
            self.pn = PairNorm(channels[1])
        elif self.normalization == 'InstanceNorm':
            self.instance_norm = InstanceNorm(channels[1])
        elif self.normalization == 'GraphNorm':
            self.gn = GraphNorm(channels[1])
        elif self.normalization == 'DiffGroupNorm':
            self.group_norm = DiffGroupNorm(channels[1], 128)
        elif self.normalization is None:
            pass
        else:
            raise ValueError('Unknown normalization function: {}'.format(normalization))

        self.reset_parameters()

    def reset_parameters(self):
        self.lin_f.reset_parameters()
        self.lin_s.reset_parameters()
        if self.normalization == 'BatchNorm':
            self.bn.reset_parameters()

    def forward(self, x: Union[torch.Tensor, PairTensor], edge_index: Adj,
                edge_attr: OptTensor, batch, distance, size: Size = None) -> torch.Tensor:
        """"""
        if isinstance(x, torch.Tensor):
            x: PairTensor = (x, x)

        # propagate_type: (x: PairTensor, edge_attr: OptTensor)
        out = self.propagate(edge_index, x=x, edge_attr=edge_attr, distance=distance, size=size)
        if self.normalization == 'BatchNorm':
            out = self.bn(out)
        elif self.normalization == 'LayerNorm':
            out = self.ln(out, batch)
        elif self.normalization == 'PairNorm':
            out = self.pn(out, batch)
        elif self.normalization == 'InstanceNorm':
            out = self.instance_norm(out, batch)
        elif self.normalization == 'GraphNorm':
            out = self.gn(out, batch)
        elif self.normalization == 'DiffGroupNorm':
            out = self.group_norm(out)
        out += x[1]
        return out

    def message(self, x_i, x_j, edge_attr: OptTensor, distance) -> torch.Tensor:
        z = torch.cat([x_i, x_j, edge_attr], dim=-1)
        out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))
        if self.if_exp: # Very specific section. The message is scaled exponentially with the distance.
            sigma = 3
            n = 2
            out = out * torch.exp(-distance ** n / sigma ** n / 2).view(-1, 1)
        return out

    def __repr__(self):
        return '{}({}, dim={})'.format(self.__class__.__name__, self.channels, self.dim)

# %%
class MPLayer(nn.Module):
    def __init__(self, in_atom_fea_len, in_edge_fea_len, out_edge_fea_len, if_exp, if_edge_update, normalization,
                 atom_update_net, gauss_stop, output_layer=False):
        super(MPLayer, self).__init__()
        if atom_update_net == 'CGConv':
            self.cgconv = CGConv(channels=in_atom_fea_len,
                                 dim=in_edge_fea_len,
                                 aggr='add',
                                 normalization=normalization,
                                 if_exp=if_exp)

        self.if_edge_update = if_edge_update
        self.atom_update_net = atom_update_net
        if if_edge_update:
            if output_layer:
                self.e_lin = nn.Sequential(nn.Linear(in_edge_fea_len + in_atom_fea_len * 2, 128),
                                           nn.SiLU(),
                                           nn.Linear(128, out_edge_fea_len),
                                           )
            else:
                self.e_lin = nn.Sequential(nn.Linear(in_edge_fea_len + in_atom_fea_len * 2, 128),
                                           nn.SiLU(),
                                           nn.Linear(128, out_edge_fea_len),
                                           nn.SiLU(),
                                           )

    def forward(self, atom_fea, edge_idx, edge_fea, batch, distance, edge_vec):
        atom_fea = self.cgconv(atom_fea, edge_idx, edge_fea, batch, distance)
        atom_fea_s = atom_fea
        if self.if_edge_update:
            row, col = edge_idx
            edge_fea = self.e_lin(torch.cat([atom_fea_s[row], atom_fea_s[col], edge_fea], dim=-1))
            return atom_fea, edge_fea
        else:
            return atom_fea

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
from torch_scatter import scatter_add
from math import ceil

class LCMPLayer(nn.Module):
    def __init__(self, in_atom_fea_len, in_edge_fea_len, out_edge_fea_len, num_l,
                 normalization: str = None, bias: bool = True, if_exp: bool = False):
        super(LCMPLayer, self).__init__()
        self.in_atom_fea_len = in_atom_fea_len
        self.normalization = normalization
        self.if_exp = if_exp

        self.lin_f = nn.Linear(in_atom_fea_len * 2 + in_edge_fea_len, in_atom_fea_len, bias=bias)
        self.lin_s = nn.Linear(in_atom_fea_len * 2 + in_edge_fea_len, in_atom_fea_len, bias=bias)
        self.bn = nn.BatchNorm1d(in_atom_fea_len, track_running_stats=True)

        self.e_lin = nn.Sequential(
            nn.Linear(in_edge_fea_len + in_atom_fea_len * 2 - num_l ** 2, 128),
            nn.SiLU(),
            nn.Linear(128, out_edge_fea_len)
        )
        

        self.reset_parameters()

    def reset_parameters(self):
        self.lin_f.reset_parameters()
        self.lin_s.reset_parameters()
        if self.normalization == 'BatchNorm':
            self.bn.reset_parameters()

    def forward(self, atom_fea, edge_fea, sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index, distance,
                huge_structure, output_final_layer_neuron):
        if huge_structure:
            sub_graph_batch_num = 8

            sub_graph_num = sub_atom_idx.shape[0]
            sub_graph_batch_size = ceil(sub_graph_num / sub_graph_batch_num)

            num_edge = edge_fea.shape[0]
            vf_update = torch.zeros((num_edge * 2, self.in_atom_fea_len)).type(torch.get_default_dtype()).to(atom_fea.device)
            for sub_graph_batch_index in range(sub_graph_batch_num):
                if sub_graph_batch_index == sub_graph_batch_num - 1:
                    sub_graph_idx = slice(sub_graph_batch_size * sub_graph_batch_index, sub_graph_num)
                else:
                    sub_graph_idx = slice(sub_graph_batch_size * sub_graph_batch_index,
                                          sub_graph_batch_size * (sub_graph_batch_index + 1))

                sub_atom_idx_batch = sub_atom_idx[sub_graph_idx]
                sub_edge_idx_batch = sub_edge_idx[sub_graph_idx]
                sub_edge_ang_batch = sub_edge_ang[sub_graph_idx]
                sub_index_batch = sub_index[sub_graph_idx]

                z = torch.cat([atom_fea[sub_atom_idx_batch][:, 0, :], atom_fea[sub_atom_idx_batch][:, 1, :],
                               edge_fea[sub_edge_idx_batch], sub_edge_ang_batch], dim=-1)
                out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))

                if self.if_exp:
                    sigma = 3
                    n = 2
                    out = out * torch.exp(-distance[sub_edge_idx_batch] ** n / sigma ** n / 2).view(-1, 1)

                vf_update += scatter_add(out, sub_index_batch, dim=0, dim_size=num_edge * 2)

            if self.normalization == 'BatchNorm':
                vf_update = self.bn(vf_update)
            vf_update = vf_update.reshape(num_edge, 2, -1)
            if output_final_layer_neuron != '':
                final_layer_neuron = torch.cat([vf_update[:, 0, :], vf_update[:, 1, :], edge_fea],
                                               dim=-1).detach().cpu().numpy()
                np.save(os.path.join(output_final_layer_neuron, 'final_layer_neuron.npy'), final_layer_neuron)
            out = self.e_lin(torch.cat([vf_update[:, 0, :], vf_update[:, 1, :], edge_fea], dim=-1))
            return out

        num_edge = edge_fea.shape[0]
        z = torch.cat(
            [atom_fea[sub_atom_idx][:, 0, :], atom_fea[sub_atom_idx][:, 1, :], edge_fea[sub_edge_idx], sub_edge_ang],
            dim=-1)
        out = self.lin_f(z).sigmoid() * F.softplus(self.lin_s(z))

        if self.if_exp:
            sigma = 3
            n = 2
            out = out * torch.exp(-distance[sub_edge_idx] ** n / sigma ** n / 2).view(-1, 1)

        out = scatter_add(out, sub_index, dim=0)
        if self.normalization == 'BatchNorm':
            out = self.bn(out)
        out = out.reshape(num_edge, 2, -1)
        if output_final_layer_neuron != '':
            final_layer_neuron = torch.cat([out[:, 0, :], out[:, 1, :], edge_fea], dim=-1).detach().cpu().numpy()
            np.save(os.path.join(output_final_layer_neuron, 'final_layer_neuron.npy'), final_layer_neuron)
        out = self.e_lin(torch.cat([out[:, 0, :], out[:, 1, :], edge_fea], dim=-1))
        return out

# %%
class MultipleLinear(nn.Module):
    def __init__(self, num_linear: int, in_fea_len: int, out_fea_len: int, bias: bool = True) -> None:
        super(MultipleLinear, self).__init__()
        self.num_linear = num_linear
        self.out_fea_len = out_fea_len
        self.weight = nn.Parameter(torch.Tensor(num_linear, in_fea_len, out_fea_len))
        if bias:
            self.bias = nn.Parameter(torch.Tensor(num_linear, out_fea_len))
        else:
            self.register_parameter('bias', None)
        # self.ln = LayerNorm(num_linear * out_fea_len)
        # self.gn = GraphNorm(out_fea_len)
        self.reset_parameters()

    def reset_parameters(self) -> None:
        nn.init.kaiming_uniform_(self.weight, a=sqrt(5))
        if self.bias is not None:
            fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.weight)
            bound = 1 / sqrt(fan_in)
            nn.init.uniform_(self.bias, -bound, bound)

    def forward(self, input: torch.Tensor, batch_edge: torch.Tensor) -> torch.Tensor:
        output = torch.matmul(input, self.weight)

        if self.bias is not None:
            output += self.bias[:, None, :]
        return output

# %%
import torch
import torch.nn as nn

class HGNN(nn.Module):
    def __init__(self, num_species, in_atom_fea_len, in_edge_fea_len, num_orbital,
                 distance_expansion, gauss_stop, if_exp, if_MultipleLinear, if_edge_update, if_lcmp,
                 normalization, atom_update_net, separate_onsite,
                 trainable_gaussians, type_affine, num_l=5):
        super(HGNN, self).__init__()
        self.num_species = num_species
        self.embed = nn.Embedding(num_species + 5, in_atom_fea_len)

        # pair-type aware affine
        if type_affine:
            self.type_affine = nn.Embedding(
                num_species ** 2, 2,
                _weight=torch.stack([torch.ones(num_species ** 2), torch.zeros(num_species ** 2)], dim=-1)
            )
        else:
            self.type_affine = None

        if if_edge_update or (if_edge_update is False and if_lcmp is False):
            distance_expansion_len = in_edge_fea_len
        else:
            distance_expansion_len = in_edge_fea_len - num_l ** 2
        if distance_expansion == 'GaussianBasis':
            self.distance_expansion = GaussianBasis(
                0.0, gauss_stop, distance_expansion_len, trainable=trainable_gaussians
            )

        self.if_MultipleLinear = if_MultipleLinear
        self.if_edge_update = if_edge_update
        self.if_lcmp = if_lcmp
        self.atom_update_net = atom_update_net
        self.separate_onsite = separate_onsite
        if if_lcmp == True:
            mp_output_edge_fea_len = in_edge_fea_len - num_l ** 2

        if if_edge_update == True:
            self.mp1 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp2 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp3 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp4 = MPLayer(in_atom_fea_len, in_edge_fea_len, in_edge_fea_len, if_exp, if_edge_update, normalization,
                               atom_update_net, gauss_stop)
            self.mp5 = MPLayer(in_atom_fea_len, in_edge_fea_len, mp_output_edge_fea_len, if_exp, if_edge_update,
                               normalization, atom_update_net, gauss_stop)

        if if_lcmp == True:
            if self.if_MultipleLinear == True:
                self.lcmp = LCMPLayer(in_atom_fea_len, in_edge_fea_len, 32, num_l, if_exp=if_exp)
                self.multiple_linear1 = MultipleLinear(num_orbital, 32, 16)
                self.multiple_linear2 = MultipleLinear(num_orbital, 16, 1)
            else:
                self.lcmp = LCMPLayer(in_atom_fea_len, in_edge_fea_len, num_orbital, num_l, if_exp=if_exp)

        else:
            self.mp_output = MPLayer(in_atom_fea_len, in_edge_fea_len, num_orbital, if_exp, if_edge_update=True,
                                     normalization=normalization, atom_update_net=atom_update_net,
                                     gauss_stop=gauss_stop, output_layer=True)

        # Define the DOS prediction network with an initial placeholder input size
        self.fermi_fc1 = nn.Linear(0, 512)  # Placeholder size, will be adjusted in forward
        self.fermi_fc2 = nn.Linear(512, 256)
        self.fermi_fc3 = nn.Linear(256, 128)
        self.fermi_fc4 = nn.Linear(128, 1)

    def forward(self, atom_attr, edge_idx, edge_attr, batch,
                sub_atom_idx=None, sub_edge_idx=None, sub_edge_ang=None, sub_index=None,
                huge_structure=False, output_final_layer_neuron=''):
        device = atom_attr.device  # Get the device of the input tensor

        batch_edge = batch[edge_idx[0]]
        atom_fea0 = self.embed(atom_attr)
        distance = edge_attr[:, 0]
        edge_vec = edge_attr[:, 1:4] - edge_attr[:, 4:7]

        if self.type_affine is None:
            edge_fea0 = self.distance_expansion(distance)
        else:
            affine_coeff = self.type_affine(self.num_species * atom_attr[edge_idx[0]] + atom_attr[edge_idx[1]])
            edge_fea0 = self.distance_expansion(distance * affine_coeff[:, 0] + affine_coeff[:, 1])

        if self.if_edge_update == True:
            atom_fea, edge_fea = self.mp1(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea, edge_fea = self.mp2(atom_fea, edge_idx, edge_fea, batch, distance, edge_vec)
            atom_fea0, edge_fea0 = atom_fea0 + atom_fea, edge_fea0 + edge_fea
            atom_fea, edge_fea = self.mp3(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)
            atom_fea, edge_fea = self.mp4(atom_fea, edge_idx, edge_fea, batch, distance, edge_vec)
            atom_fea0, edge_fea0 = atom_fea0 + atom_fea, edge_fea0 + edge_fea
            atom_fea, edge_fea = self.mp5(atom_fea0, edge_idx, edge_fea0, batch, distance, edge_vec)

            if self.if_lcmp == True:
                atom_fea_s = atom_fea
                out = self.lcmp(atom_fea_s, edge_fea, sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index, distance,
                                huge_structure, output_final_layer_neuron)

        # Ensure all tensors are on the same device
        edge_fea_aggregated = torch.zeros((atom_fea.shape[0], edge_fea.shape[1]), device=device)
        edge_fea_aggregated.index_add_(0, edge_idx[0].to(device), edge_fea.to(device))

        # Combine atom and edge features
        combined_fea = torch.cat([atom_fea, edge_fea_aggregated], dim=1)

        # Dynamically adjust the first fully connected layer
        if self.fermi_fc1.in_features != combined_fea.shape[1]:
            self.fermi_fc1 = nn.Linear(combined_fea.shape[1], 512).to(device)

        fermi_pred = torch.relu(self.fermi_fc1(combined_fea))
        fermi_pred = torch.relu(self.fermi_fc2(fermi_pred))
        fermi_pred = torch.relu(self.fermi_fc3(fermi_pred))
        fermi_pred = self.fermi_fc4(fermi_pred)
        
        fermi_pred = fermi_pred.sum(dim=0)  # Shape will be [999]

        return out, fermi_pred

# %%
dataset = HData(
    raw_data_dir='/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/processed',
    graph_dir='/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/graph',
    interface='h5',
    target='hamiltonian',
    dataset_name='Bi_soc',
    multiprocessing=0,
    radius='-1.0',
    max_num_nbr=0,
    num_l='5',
    max_element='-1',
    create_from_DFT='True',
    if_lcmp_graph='True',
    separate_onsite='False',
    new_sp=False,
    default_dtype_torch=torch.get_default_dtype(),
)

# %%
import configparser
import json
from deeph.kernel import DeepHKernel
# Initialize the ConfigParser
config = configparser.ConfigParser()

# Read the configuration file
config.read('/home/t.hsu/deeph_dev/default.ini')

config.read('/home/t.hsu/deeph_dev/train.ini')  # Replace 'config.ini' with your actual file name
kernel = DeepHKernel(config)
_, _, _, _ = kernel.get_dataset()
num_species = len(dataset.info["index_to_Z"])
orbital = json.loads(config.get('basic', 'orbital'))
num_orbital = len(orbital)
spinful = True
if_lcmp = True
separate_onsite = False
if spinful:
    out_fea_len = num_orbital * 8
else:
    out_fea_len = num_orbital
print('DeepH', out_fea_len)

# %%
model_kwargs = dict(
    n_elements=num_species,
    num_species=num_species,
    in_atom_fea_len=config.getint('network', 'atom_fea_len'),
    in_vfeats=config.getint('network', 'atom_fea_len'),
    in_edge_fea_len=config.getint('network', 'edge_fea_len'),
    in_efeats=config.getint('network', 'edge_fea_len'),
    out_edge_fea_len=out_fea_len,
    out_efeats=out_fea_len,
    num_orbital=out_fea_len,
    distance_expansion=config.get('network', 'distance_expansion'),
    gauss_stop=config.getfloat('network', 'gauss_stop'),
    cutoff=config.getfloat('network', 'gauss_stop'),
    if_exp=config.getboolean('network', 'if_exp'),
    if_MultipleLinear=config.getboolean('network', 'if_MultipleLinear'),
    if_edge_update=config.getboolean('network', 'if_edge_update'),
    if_lcmp=if_lcmp,
    normalization=config.get('network', 'normalization'),
    atom_update_net=config.get('network', 'atom_update_net', fallback='CGConv'),
    separate_onsite=separate_onsite,
    num_l=config.getint('network', 'num_l'),
    trainable_gaussians=config.getboolean('network', 'trainable_gaussians', fallback=False),
    type_affine=config.getboolean('network', 'type_affine', fallback=False),
    if_fc_out=False,
)
parameter_list = list(signature(HGNN.__init__).parameters.keys())
current_parameter_list = list(model_kwargs.keys())
for k in current_parameter_list:
    if k not in parameter_list:
        model_kwargs.pop(k)
if 'num_elements' in parameter_list:
    model_kwargs['num_elements'] = config.getint('basic', 'max_element') + 1
model = HGNN(**model_kwargs)

# %%
# model_parameters = filter(lambda p: p.requires_grad, model.parameters())
# params = sum([np.prod(p.size()) for p in model_parameters])
# print("The model you built has: %d parameters" % params)

# from torchviz import make_dot
# dot = make_dot(model, params=dict(model.named_parameters()))
# dot.format = 'png'
# dot.render('./deeph_dev/model_visualization')

# %%
device = torch.device(config.get('basic', 'device') if torch.cuda.is_available() else 'cpu')
model.to(device)
# torch.cuda.is_available()
# Out:
# HGNN(
#   (embed): Embedding(6, 64)
#   (distance_expansion): GaussianBasis()
#   (mp1): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp2): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp3): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp4): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): SiLU()
#     )
#   )
#   (mp5): MPLayer(
#     (cgconv): CGConv(64, dim=128)
#     (e_lin): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=103, bias=True)
#       (3): SiLU()
#     )
#   )
#   (lcmp): LCMPLayer(
#     (lin_f): Linear(in_features=256, out_features=64, bias=True)
#     (lin_s): Linear(in_features=256, out_features=64, bias=True)
#     (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (e_lin): Sequential(
#       (0): Linear(in_features=231, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=2888, bias=True)
#     )
#   )
#   (fermi_fc1): Linear(in_features=0, out_features=512, bias=True)
#   (fermi_fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fermi_fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fermi_fc4): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
def make_mask(dataset):
    spinful = True
    target = 'hamiltonian'
    num_orbital = kernel.num_orbital
    dataset_mask = []
    for i, data in enumerate(dataset):
        # filename = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(i)
        # aux = np.loadtxt(filename)

        # dos = torch.tensor(aux[:,1], dtype=torch.float32)  # Convert to tensor if not already
        # dos = dos.view(-1)
        Oij_value = data.term_real
        if data.term_real is not None:
            if_only_rc = False

        if spinful:
            out_fea_len = num_orbital * 8
            # out_fea_len = 999
            
        mask = torch.zeros(data.edge_attr.shape[0], out_fea_len, dtype=torch.int8)
        label = torch.zeros(data.edge_attr.shape[0], out_fea_len, dtype=torch.get_default_dtype())
        y = torch.zeros(data.edge_attr.shape[0], 1, dtype=torch.get_default_dtype())

        atomic_number_edge_i = kernel.index_to_Z[data.x[data.edge_index[0]]]
        atomic_number_edge_j = kernel.index_to_Z[data.x[data.edge_index[1]]]

        for index_out, orbital_dict in enumerate(kernel.orbital):
            for N_M_str, a_b in orbital_dict.items():
                # N_M, a_b means: H_{ia, jb} when the atomic number of atom i is N and the atomic number of atom j is M
                condition_atomic_number_i, condition_atomic_number_j = map(lambda x: int(x), N_M_str.split())
                condition_orbital_i, condition_orbital_j = a_b

                if spinful:
                    if target == 'phiVdphi':
                        raise NotImplementedError("Not yet have support for phiVdphi")
                    else:
                        mask[:, 8 * index_out:8 * (index_out + 1)] = torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )[:, None].repeat(1, 8)
                else:
                    if target == 'phiVdphi':
                        mask[:, 3 * index_out:3 * (index_out + 1)] += torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )[:, None].repeat(1, 3)
                    else:
                        mask[:, index_out] += torch.where(
                            (atomic_number_edge_i == condition_atomic_number_i)
                            & (atomic_number_edge_j == condition_atomic_number_j),
                            1,
                            0
                        )

                if if_only_rc == False:
                    if spinful:
                        if target == 'phiVdphi':
                            raise NotImplementedError
                        else:
                            label[:, 8 * index_out:8 * (index_out + 1)] = torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j].t(),
                                torch.zeros(8, data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            ).t()


                    else:
                        if target == 'phiVdphi':
                            label[:, 3 * index_out:3 * (index_out + 1)] = torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j].t(),
                                torch.zeros(3, data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            ).t()
                        else:
                            label[:, index_out] += torch.where(
                                (atomic_number_edge_i == condition_atomic_number_i)
                                & (atomic_number_edge_j == condition_atomic_number_j),
                                Oij_value[:, condition_orbital_i, condition_orbital_j],
                                torch.zeros(data.edge_attr.shape[0], dtype=torch.get_default_dtype())
                            )
        assert len(torch.where((mask != 1) & (mask != 0))[0]) == 0
        mask = mask.bool()
        data.mask = mask
        del data.term_mask
        if if_only_rc == False:
            data.label = label
            data.y = y
            if target == 'hamiltonian' or target == 'density_matrix':
                del data.term_real
        dataset_mask.append(data)
    return dataset_mask

# %%
dataset_size = len(dataset)
print(dataset_size)
print(dataset[0])
dataset = make_mask(dataset)
# Iterating over the 81 graph.
# for i in range(len(dataset)-1):
#     filename = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/raw/{}/openmx.DOS.Gaussian'.format(i)
#     aux = np.loadtxt(filename)

#     # Extract the first and second columns
#     energy = aux[:, 0]
#     dos = torch.tensor(aux[:, 1],dtype=torch.get_default_dtype())

#     # aux2 = dataset[i].label[:,:len(dos)]
#     dataset[i].y = dos.expand((dataset[i].label.shape[0]), -1)

# %%
import os
import json
# Path to the parent directory containing the 80 directories
parent_directory = '/home/t.hsu/example2/work_dir/dataset/processed'

# Initialize a list to store the fermi_level values
fermi_levels = []

# Loop through each directory
for i, directory in enumerate(os.listdir(parent_directory)):
    print(i)
    dir_path = os.path.join(parent_directory, directory)

    # Check if the current path is a directory
    if os.path.isdir(dir_path):
        # Path to the info.json file
        info_path = os.path.join(dir_path, 'info.json')
        
        # Check if the info.json file exists
        if os.path.isfile(info_path):
            with open(info_path, 'r') as f:
                data = json.load(f)
                # Extract the fermi_level and store it in the list
                fermi_level = data.get('fermi_level')
                # if fermi_level is not None:
                    # fermi_level_tensor= torch.tensor([fermi_level], dtype=torch.get_default_dtype())
                    # dataset[i].y = fermi_level_tensor.expand((dataset[i].label.shape[0]), -1)
                    
                dataset[i-1].y = torch.tensor(fermi_level, dtype=torch.get_default_dtype())

# %%
fermi_level_check = []
for i, data in enumerate(dataset):
    stru_id = int(data.stru_id)
    dir_path = '/home/t.hsu/DeepRFnet/DeepDOS/work_dir/dataset/processed/{}'.format(stru_id)
    info_path = os.path.join(dir_path, 'info.json')
    if os.path.isfile(info_path):
        with open(info_path, 'r') as f:
            jsonfile = json.load(f)
            fermi_level = jsonfile.get('fermi_level')
            dataset[i].y = torch.tensor(fermi_level, dtype=torch.get_default_dtype()) # note that my fermi_level is in float64, but dtype of torch is float32, this will cause the difference in number after 5 or 6 digits

# %%
dataset[:]
# Out:
# [Data(
#    x=[36],
#    edge_index=[2, 1472],
#    edge_attr=[1472, 10],
#    stru_id='0',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121080, 2],
#      subgraph_edge_idx=[121080],
#      subgraph_edge_ang=[121080, 25],
#      subgraph_index=[121080],
#    },
#    spinful=[1],
#    mask=[1472, 2888],
#    label=[1472, 2888],
#    y=-3.6709020137786865
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1462],
#    edge_attr=[1462, 10],
#    stru_id='1',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[119580, 2],
#      subgraph_edge_idx=[119580],
#      subgraph_edge_ang=[119580, 25],
#      subgraph_index=[119580],
#    },
#    spinful=[1],
#    mask=[1462, 2888],
#    label=[1462, 2888],
#    y=-3.669212818145752
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1456],
#    edge_attr=[1456, 10],
#    stru_id='10',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118688, 2],
#      subgraph_edge_idx=[118688],
#      subgraph_edge_ang=[118688, 25],
#      subgraph_index=[118688],
#    },
#    spinful=[1],
#    mask=[1456, 2888],
#    label=[1456, 2888],
#    y=-3.6689257621765137
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1490],
#    edge_attr=[1490, 10],
#    stru_id='11',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124228, 2],
#      subgraph_edge_idx=[124228],
#      subgraph_edge_ang=[124228, 25],
#      subgraph_index=[124228],
#    },
#    spinful=[1],
#    mask=[1490, 2888],
#    label=[1490, 2888],
#    y=-3.668487071990967
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='12',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128756, 2],
#      subgraph_edge_idx=[128756],
#      subgraph_edge_ang=[128756, 25],
#      subgraph_index=[128756],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=-3.6585097312927246
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1546],
#    edge_attr=[1546, 10],
#    stru_id='13',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[133460, 2],
#      subgraph_edge_idx=[133460],
#      subgraph_edge_ang=[133460, 25],
#      subgraph_index=[133460],
#    },
#    spinful=[1],
#    mask=[1546, 2888],
#    label=[1546, 2888],
#    y=-3.6449341773986816
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1598],
#    edge_attr=[1598, 10],
#    stru_id='14',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[142364, 2],
#      subgraph_edge_idx=[142364],
#      subgraph_edge_ang=[142364, 25],
#      subgraph_index=[142364],
#    },
#    spinful=[1],
#    mask=[1598, 2888],
#    label=[1598, 2888],
#    y=-3.6538543701171875
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='15',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=-3.6400585174560547
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='16',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128796, 2],
#      subgraph_edge_idx=[128796],
#      subgraph_edge_ang=[128796, 25],
#      subgraph_index=[128796],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=-3.6587040424346924
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1492],
#    edge_attr=[1492, 10],
#    stru_id='17',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124556, 2],
#      subgraph_edge_idx=[124556],
#      subgraph_edge_ang=[124556, 25],
#      subgraph_index=[124556],
#    },
#    spinful=[1],
#    mask=[1492, 2888],
#    label=[1492, 2888],
#    y=-3.657855987548828
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='18',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129984, 2],
#      subgraph_edge_idx=[129984],
#      subgraph_edge_ang=[129984, 25],
#      subgraph_index=[129984],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=-3.658745050430298
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1476],
#    edge_attr=[1476, 10],
#    stru_id='19',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[122184, 2],
#      subgraph_edge_idx=[122184],
#      subgraph_edge_ang=[122184, 25],
#      subgraph_index=[122184],
#    },
#    spinful=[1],
#    mask=[1476, 2888],
#    label=[1476, 2888],
#    y=-3.664860486984253
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='2',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128952, 2],
#      subgraph_edge_idx=[128952],
#      subgraph_edge_ang=[128952, 25],
#      subgraph_index=[128952],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=-3.655410051345825
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='20',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129320, 2],
#      subgraph_edge_idx=[129320],
#      subgraph_edge_ang=[129320, 25],
#      subgraph_index=[129320],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=-3.6563706398010254
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='21',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130984, 2],
#      subgraph_edge_idx=[130984],
#      subgraph_edge_ang=[130984, 25],
#      subgraph_index=[130984],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=-3.6555206775665283
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1564],
#    edge_attr=[1564, 10],
#    stru_id='22',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[136512, 2],
#      subgraph_edge_idx=[136512],
#      subgraph_edge_ang=[136512, 25],
#      subgraph_index=[136512],
#    },
#    spinful=[1],
#    mask=[1564, 2888],
#    label=[1564, 2888],
#    y=-3.650672674179077
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1586],
#    edge_attr=[1586, 10],
#    stru_id='23',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140212, 2],
#      subgraph_edge_idx=[140212],
#      subgraph_edge_ang=[140212, 25],
#      subgraph_index=[140212],
#    },
#    spinful=[1],
#    mask=[1586, 2888],
#    label=[1586, 2888],
#    y=-3.647646427154541
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1604],
#    edge_attr=[1604, 10],
#    stru_id='24',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[143408, 2],
#      subgraph_edge_idx=[143408],
#      subgraph_edge_ang=[143408, 25],
#      subgraph_index=[143408],
#    },
#    spinful=[1],
#    mask=[1604, 2888],
#    label=[1604, 2888],
#    y=-3.6469333171844482
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1558],
#    edge_attr=[1558, 10],
#    stru_id='25',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135504, 2],
#      subgraph_edge_idx=[135504],
#      subgraph_edge_ang=[135504, 25],
#      subgraph_index=[135504],
#    },
#    spinful=[1],
#    mask=[1558, 2888],
#    label=[1558, 2888],
#    y=-3.6598236560821533
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1526],
#    edge_attr=[1526, 10],
#    stru_id='26',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130232, 2],
#      subgraph_edge_idx=[130232],
#      subgraph_edge_ang=[130232, 25],
#      subgraph_index=[130232],
#    },
#    spinful=[1],
#    mask=[1526, 2888],
#    label=[1526, 2888],
#    y=-3.647432565689087
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1538],
#    edge_attr=[1538, 10],
#    stru_id='27',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132204, 2],
#      subgraph_edge_idx=[132204],
#      subgraph_edge_ang=[132204, 25],
#      subgraph_index=[132204],
#    },
#    spinful=[1],
#    mask=[1538, 2888],
#    label=[1538, 2888],
#    y=-3.6409342288970947
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='28',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125084, 2],
#      subgraph_edge_idx=[125084],
#      subgraph_edge_ang=[125084, 25],
#      subgraph_index=[125084],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=-3.650705337524414
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1498],
#    edge_attr=[1498, 10],
#    stru_id='29',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125712, 2],
#      subgraph_edge_idx=[125712],
#      subgraph_edge_ang=[125712, 25],
#      subgraph_index=[125712],
#    },
#    spinful=[1],
#    mask=[1498, 2888],
#    label=[1498, 2888],
#    y=-3.6456410884857178
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1528],
#    edge_attr=[1528, 10],
#    stru_id='3',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130484, 2],
#      subgraph_edge_idx=[130484],
#      subgraph_edge_ang=[130484, 25],
#      subgraph_index=[130484],
#    },
#    spinful=[1],
#    mask=[1528, 2888],
#    label=[1528, 2888],
#    y=-3.6494762897491455
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='30',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129288, 2],
#      subgraph_edge_idx=[129288],
#      subgraph_edge_ang=[129288, 25],
#      subgraph_index=[129288],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=-3.653611898422241
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='31',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=-3.6588079929351807
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1586],
#    edge_attr=[1586, 10],
#    stru_id='32',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140216, 2],
#      subgraph_edge_idx=[140216],
#      subgraph_edge_ang=[140216, 25],
#      subgraph_index=[140216],
#    },
#    spinful=[1],
#    mask=[1586, 2888],
#    label=[1586, 2888],
#    y=-3.6506950855255127
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1674],
#    edge_attr=[1674, 10],
#    stru_id='33',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[156132, 2],
#      subgraph_edge_idx=[156132],
#      subgraph_edge_ang=[156132, 25],
#      subgraph_index=[156132],
#    },
#    spinful=[1],
#    mask=[1674, 2888],
#    label=[1674, 2888],
#    y=-3.6471128463745117
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='34',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141636, 2],
#      subgraph_edge_idx=[141636],
#      subgraph_edge_ang=[141636, 25],
#      subgraph_index=[141636],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=-3.6554172039031982
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='35',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135124, 2],
#      subgraph_edge_idx=[135124],
#      subgraph_edge_ang=[135124, 25],
#      subgraph_index=[135124],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=-3.6454241275787354
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1552],
#    edge_attr=[1552, 10],
#    stru_id='36',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134612, 2],
#      subgraph_edge_idx=[134612],
#      subgraph_edge_ang=[134612, 25],
#      subgraph_index=[134612],
#    },
#    spinful=[1],
#    mask=[1552, 2888],
#    label=[1552, 2888],
#    y=-3.640052080154419
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='37',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129820, 2],
#      subgraph_edge_idx=[129820],
#      subgraph_edge_ang=[129820, 25],
#      subgraph_index=[129820],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=-3.639540672302246
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='38',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124752, 2],
#      subgraph_edge_idx=[124752],
#      subgraph_edge_ang=[124752, 25],
#      subgraph_index=[124752],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=-3.6302008628845215
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1526],
#    edge_attr=[1526, 10],
#    stru_id='39',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130296, 2],
#      subgraph_edge_idx=[130296],
#      subgraph_edge_ang=[130296, 25],
#      subgraph_index=[130296],
#    },
#    spinful=[1],
#    mask=[1526, 2888],
#    label=[1526, 2888],
#    y=-3.6380515098571777
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1550],
#    edge_attr=[1550, 10],
#    stru_id='4',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134144, 2],
#      subgraph_edge_idx=[134144],
#      subgraph_edge_ang=[134144, 25],
#      subgraph_index=[134144],
#    },
#    spinful=[1],
#    mask=[1550, 2888],
#    label=[1550, 2888],
#    y=-3.6410257816314697
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='40',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134964, 2],
#      subgraph_edge_idx=[134964],
#      subgraph_edge_ang=[134964, 25],
#      subgraph_index=[134964],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=-3.6405181884765625
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1596],
#    edge_attr=[1596, 10],
#    stru_id='41',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[142036, 2],
#      subgraph_edge_idx=[142036],
#      subgraph_edge_ang=[142036, 25],
#      subgraph_index=[142036],
#    },
#    spinful=[1],
#    mask=[1596, 2888],
#    label=[1596, 2888],
#    y=-3.6492161750793457
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='42',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141628, 2],
#      subgraph_edge_idx=[141628],
#      subgraph_edge_ang=[141628, 25],
#      subgraph_index=[141628],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=-3.6533796787261963
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1590],
#    edge_attr=[1590, 10],
#    stru_id='43',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[140924, 2],
#      subgraph_edge_idx=[140924],
#      subgraph_edge_ang=[140924, 25],
#      subgraph_index=[140924],
#    },
#    spinful=[1],
#    mask=[1590, 2888],
#    label=[1590, 2888],
#    y=-3.6470184326171875
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1594],
#    edge_attr=[1594, 10],
#    stru_id='44',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[141700, 2],
#      subgraph_edge_idx=[141700],
#      subgraph_edge_ang=[141700, 25],
#      subgraph_index=[141700],
#    },
#    spinful=[1],
#    mask=[1594, 2888],
#    label=[1594, 2888],
#    y=-3.6473228931427
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1560],
#    edge_attr=[1560, 10],
#    stru_id='45',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135992, 2],
#      subgraph_edge_idx=[135992],
#      subgraph_edge_ang=[135992, 25],
#      subgraph_index=[135992],
#    },
#    spinful=[1],
#    mask=[1560, 2888],
#    label=[1560, 2888],
#    y=-3.6349713802337646
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1532],
#    edge_attr=[1532, 10],
#    stru_id='46',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130864, 2],
#      subgraph_edge_idx=[130864],
#      subgraph_edge_ang=[130864, 25],
#      subgraph_index=[130864],
#    },
#    spinful=[1],
#    mask=[1532, 2888],
#    label=[1532, 2888],
#    y=-3.626286506652832
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1536],
#    edge_attr=[1536, 10],
#    stru_id='47',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[131824, 2],
#      subgraph_edge_idx=[131824],
#      subgraph_edge_ang=[131824, 25],
#      subgraph_index=[131824],
#    },
#    spinful=[1],
#    mask=[1536, 2888],
#    label=[1536, 2888],
#    y=-3.6234099864959717
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1538],
#    edge_attr=[1538, 10],
#    stru_id='48',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132140, 2],
#      subgraph_edge_idx=[132140],
#      subgraph_edge_ang=[132140, 25],
#      subgraph_index=[132140],
#    },
#    spinful=[1],
#    mask=[1538, 2888],
#    label=[1538, 2888],
#    y=-3.6199419498443604
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1532],
#    edge_attr=[1532, 10],
#    stru_id='49',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130864, 2],
#      subgraph_edge_idx=[130864],
#      subgraph_edge_ang=[130864, 25],
#      subgraph_index=[130864],
#    },
#    spinful=[1],
#    mask=[1532, 2888],
#    label=[1532, 2888],
#    y=-3.628563642501831
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1552],
#    edge_attr=[1552, 10],
#    stru_id='5',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134556, 2],
#      subgraph_edge_idx=[134556],
#      subgraph_edge_ang=[134556, 25],
#      subgraph_index=[134556],
#    },
#    spinful=[1],
#    mask=[1552, 2888],
#    label=[1552, 2888],
#    y=-3.640651226043701
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='50',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135280, 2],
#      subgraph_edge_idx=[135280],
#      subgraph_edge_ang=[135280, 25],
#      subgraph_index=[135280],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=-3.6340644359588623
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1556],
#    edge_attr=[1556, 10],
#    stru_id='51',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135100, 2],
#      subgraph_edge_idx=[135100],
#      subgraph_edge_ang=[135100, 25],
#      subgraph_index=[135100],
#    },
#    spinful=[1],
#    mask=[1556, 2888],
#    label=[1556, 2888],
#    y=-3.646613359451294
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1560],
#    edge_attr=[1560, 10],
#    stru_id='52',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[135780, 2],
#      subgraph_edge_idx=[135780],
#      subgraph_edge_ang=[135780, 25],
#      subgraph_index=[135780],
#    },
#    spinful=[1],
#    mask=[1560, 2888],
#    label=[1560, 2888],
#    y=-3.665513753890991
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1554],
#    edge_attr=[1554, 10],
#    stru_id='53',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[134772, 2],
#      subgraph_edge_idx=[134772],
#      subgraph_edge_ang=[134772, 25],
#      subgraph_index=[134772],
#    },
#    spinful=[1],
#    mask=[1554, 2888],
#    label=[1554, 2888],
#    y=-3.6516566276550293
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='54',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129496, 2],
#      subgraph_edge_idx=[129496],
#      subgraph_edge_ang=[129496, 25],
#      subgraph_index=[129496],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=-3.643178701400757
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='55',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129392, 2],
#      subgraph_edge_idx=[129392],
#      subgraph_edge_ang=[129392, 25],
#      subgraph_index=[129392],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=-3.6326606273651123
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1542],
#    edge_attr=[1542, 10],
#    stru_id='56',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132768, 2],
#      subgraph_edge_idx=[132768],
#      subgraph_edge_ang=[132768, 25],
#      subgraph_index=[132768],
#    },
#    spinful=[1],
#    mask=[1542, 2888],
#    label=[1542, 2888],
#    y=-3.6246426105499268
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1670],
#    edge_attr=[1670, 10],
#    stru_id='57',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[155856, 2],
#      subgraph_edge_idx=[155856],
#      subgraph_edge_ang=[155856, 25],
#      subgraph_index=[155856],
#    },
#    spinful=[1],
#    mask=[1670, 2888],
#    label=[1670, 2888],
#    y=-3.6173927783966064
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1542],
#    edge_attr=[1542, 10],
#    stru_id='58',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[132764, 2],
#      subgraph_edge_idx=[132764],
#      subgraph_edge_ang=[132764, 25],
#      subgraph_index=[132764],
#    },
#    spinful=[1],
#    mask=[1542, 2888],
#    label=[1542, 2888],
#    y=-3.6267776489257812
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1524],
#    edge_attr=[1524, 10],
#    stru_id='59',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129896, 2],
#      subgraph_edge_idx=[129896],
#      subgraph_edge_ang=[129896, 25],
#      subgraph_index=[129896],
#    },
#    spinful=[1],
#    mask=[1524, 2888],
#    label=[1524, 2888],
#    y=-3.646644115447998
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='6',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129656, 2],
#      subgraph_edge_idx=[129656],
#      subgraph_edge_ang=[129656, 25],
#      subgraph_index=[129656],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=-3.6393203735351562
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='60',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129652, 2],
#      subgraph_edge_idx=[129652],
#      subgraph_edge_ang=[129652, 25],
#      subgraph_index=[129652],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=-3.6474695205688477
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='61',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128120, 2],
#      subgraph_edge_idx=[128120],
#      subgraph_edge_ang=[128120, 25],
#      subgraph_index=[128120],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=-3.6474337577819824
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1520],
#    edge_attr=[1520, 10],
#    stru_id='62',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129100, 2],
#      subgraph_edge_idx=[129100],
#      subgraph_edge_ang=[129100, 25],
#      subgraph_index=[129100],
#    },
#    spinful=[1],
#    mask=[1520, 2888],
#    label=[1520, 2888],
#    y=-3.6504836082458496
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='63',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128372, 2],
#      subgraph_edge_idx=[128372],
#      subgraph_edge_ang=[128372, 25],
#      subgraph_index=[128372],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=-3.6674964427948
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1502],
#    edge_attr=[1502, 10],
#    stru_id='64',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[126444, 2],
#      subgraph_edge_idx=[126444],
#      subgraph_edge_ang=[126444, 25],
#      subgraph_index=[126444],
#    },
#    spinful=[1],
#    mask=[1502, 2888],
#    label=[1502, 2888],
#    y=-3.6387689113616943
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1478],
#    edge_attr=[1478, 10],
#    stru_id='65',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[122072, 2],
#      subgraph_edge_idx=[122072],
#      subgraph_edge_ang=[122072, 25],
#      subgraph_index=[122072],
#    },
#    spinful=[1],
#    mask=[1478, 2888],
#    label=[1478, 2888],
#    y=-3.633018970489502
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1536],
#    edge_attr=[1536, 10],
#    stru_id='66',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[131768, 2],
#      subgraph_edge_idx=[131768],
#      subgraph_edge_ang=[131768, 25],
#      subgraph_index=[131768],
#    },
#    spinful=[1],
#    mask=[1536, 2888],
#    label=[1536, 2888],
#    y=-3.6308467388153076
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1548],
#    edge_attr=[1548, 10],
#    stru_id='67',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[133932, 2],
#      subgraph_edge_idx=[133932],
#      subgraph_edge_ang=[133932, 25],
#      subgraph_index=[133932],
#    },
#    spinful=[1],
#    mask=[1548, 2888],
#    label=[1548, 2888],
#    y=-3.6250100135803223
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1470],
#    edge_attr=[1470, 10],
#    stru_id='68',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[120716, 2],
#      subgraph_edge_idx=[120716],
#      subgraph_edge_ang=[120716, 25],
#      subgraph_index=[120716],
#    },
#    spinful=[1],
#    mask=[1470, 2888],
#    label=[1470, 2888],
#    y=-3.6282622814178467
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1496],
#    edge_attr=[1496, 10],
#    stru_id='69',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125384, 2],
#      subgraph_edge_idx=[125384],
#      subgraph_edge_ang=[125384, 25],
#      subgraph_index=[125384],
#    },
#    spinful=[1],
#    mask=[1496, 2888],
#    label=[1496, 2888],
#    y=-3.6543257236480713
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1522],
#    edge_attr=[1522, 10],
#    stru_id='7',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[129648, 2],
#      subgraph_edge_idx=[129648],
#      subgraph_edge_ang=[129648, 25],
#      subgraph_index=[129648],
#    },
#    spinful=[1],
#    mask=[1522, 2888],
#    label=[1522, 2888],
#    y=-3.651806116104126
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1518],
#    edge_attr=[1518, 10],
#    stru_id='70',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128984, 2],
#      subgraph_edge_idx=[128984],
#      subgraph_edge_ang=[128984, 25],
#      subgraph_index=[128984],
#    },
#    spinful=[1],
#    mask=[1518, 2888],
#    label=[1518, 2888],
#    y=-3.649738073348999
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1490],
#    edge_attr=[1490, 10],
#    stru_id='71',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[124228, 2],
#      subgraph_edge_idx=[124228],
#      subgraph_edge_ang=[124228, 25],
#      subgraph_index=[124228],
#    },
#    spinful=[1],
#    mask=[1490, 2888],
#    label=[1490, 2888],
#    y=-3.653738021850586
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1454],
#    edge_attr=[1454, 10],
#    stru_id='72',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118396, 2],
#      subgraph_edge_idx=[118396],
#      subgraph_edge_ang=[118396, 25],
#      subgraph_index=[118396],
#    },
#    spinful=[1],
#    mask=[1454, 2888],
#    label=[1454, 2888],
#    y=-3.6654746532440186
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1474],
#    edge_attr=[1474, 10],
#    stru_id='73',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121860, 2],
#      subgraph_edge_idx=[121860],
#      subgraph_edge_ang=[121860, 25],
#      subgraph_index=[121860],
#    },
#    spinful=[1],
#    mask=[1474, 2888],
#    label=[1474, 2888],
#    y=-3.6572670936584473
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1494],
#    edge_attr=[1494, 10],
#    stru_id='74',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[125052, 2],
#      subgraph_edge_idx=[125052],
#      subgraph_edge_ang=[125052, 25],
#      subgraph_index=[125052],
#    },
#    spinful=[1],
#    mask=[1494, 2888],
#    label=[1494, 2888],
#    y=-3.6488308906555176
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1514],
#    edge_attr=[1514, 10],
#    stru_id='75',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[128244, 2],
#      subgraph_edge_idx=[128244],
#      subgraph_edge_ang=[128244, 25],
#      subgraph_index=[128244],
#    },
#    spinful=[1],
#    mask=[1514, 2888],
#    label=[1514, 2888],
#    y=-3.635315418243408
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='76',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130500, 2],
#      subgraph_edge_idx=[130500],
#      subgraph_edge_ang=[130500, 25],
#      subgraph_index=[130500],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=-3.6294050216674805
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1530],
#    edge_attr=[1530, 10],
#    stru_id='77',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[130944, 2],
#      subgraph_edge_idx=[130944],
#      subgraph_edge_ang=[130944, 25],
#      subgraph_index=[130944],
#    },
#    spinful=[1],
#    mask=[1530, 2888],
#    label=[1530, 2888],
#    y=-3.6299986839294434
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1506],
#    edge_attr=[1506, 10],
#    stru_id='78',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[127132, 2],
#      subgraph_edge_idx=[127132],
#      subgraph_edge_ang=[127132, 25],
#      subgraph_index=[127132],
#    },
#    spinful=[1],
#    mask=[1506, 2888],
#    label=[1506, 2888],
#    y=-3.654440402984619
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1474],
#    edge_attr=[1474, 10],
#    stru_id='79',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[121860, 2],
#      subgraph_edge_idx=[121860],
#      subgraph_edge_ang=[121860, 25],
#      subgraph_index=[121860],
#    },
#    spinful=[1],
#    mask=[1474, 2888],
#    label=[1474, 2888],
#    y=-3.6621999740600586
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1456],
#    edge_attr=[1456, 10],
#    stru_id='8',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118688, 2],
#      subgraph_edge_idx=[118688],
#      subgraph_edge_ang=[118688, 25],
#      subgraph_index=[118688],
#    },
#    spinful=[1],
#    mask=[1456, 2888],
#    label=[1456, 2888],
#    y=-3.6721694469451904
#  ),
#  Data(
#    x=[36],
#    edge_index=[2, 1458],
#    edge_attr=[1458, 10],
#    stru_id='9',
#    atom_num_orbital=[36],
#    subgraph_dict={
#      subgraph_atom_idx=[118988, 2],
#      subgraph_edge_idx=[118988],
#      subgraph_edge_ang=[118988, 25],
#      subgraph_index=[118988],
#    },
#    spinful=[1],
#    mask=[1458, 2888],
#    label=[1458, 2888],
#    y=-3.666837692260742
#  )]

# %%
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2
train_size = int(train_ratio * dataset_size)
val_size = int(val_ratio * dataset_size)
test_size = int(test_ratio * dataset_size)
indices = list(range(dataset_size))
np.random.shuffle(indices)
train_sampler = SubsetRandomSampler(indices[:train_size])
val_sampler = SubsetRandomSampler(indices[train_size:train_size + val_size])
test_sampler = SubsetRandomSampler(indices[train_size + val_size:train_size + val_size + test_size])
from deeph.graph import Collater

train_loader = DataLoader(dataset, batch_size=1,
                            shuffle=False, sampler=train_sampler,
                            collate_fn=Collater(True))
val_loader = DataLoader(dataset, batch_size=1,
                        shuffle=False, sampler=val_sampler,
                        collate_fn=Collater(True))
test_loader = DataLoader(dataset, batch_size=1,
                            shuffle=False, sampler=test_sampler,
                            collate_fn=Collater(True))

# %%
lr1 = 1e-5
weight_decay = 0
criterion_hamil= nn.MSELoss()  
criterion_dos = nn.MSELoss()
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
# optimizer = optim.SGD(model_parameters, lr=learning_rate, weight_decay=weight_decay)
optimizer = optim.Adam(model_parameters, lr=lr1, betas=(0.9, 0.999))
best_loss = float('inf')
best_model_path =  '/home/t.hsu/deeph_dev/Fermi_best_multimodal.pth'


epochs = np.arange(1, 201)
losses = []
for e in epochs:
    model.train()
    epoch_loss = 0
    num_batches = 0
    for step, batch_tuple in enumerate(train_loader):
        if if_lcmp:
            batch, subgraph = batch_tuple
            sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index = subgraph
            out_hamil, out_fermi = model(
                batch.x.to(device),
                batch.edge_index.to(device),
                batch.edge_attr.to(device),
                batch.batch.to(device),
                sub_atom_idx.to(device),
                sub_edge_idx.to(device),
                sub_edge_ang.to(device),
                sub_index.to(device)
                    )
            
            labels_hamil = batch.label.to(device)
            labels_fermi = batch.y.to(device)
            
            loss_hamil = criterion_hamil(out_hamil,labels_hamil)
            loss_dos = criterion_dos(out_fermi,labels_fermi)
            total_loss = loss_hamil + loss_dos


            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()
            
            epoch_loss += total_loss.item()
            num_batches += 1
            
    avg_epoch_loss = epoch_loss / num_batches
    losses.append(avg_epoch_loss)
    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss  # Update the best loss
        torch.save(model.state_dict(), best_model_path)  # Save the model with the best loss
        print(f"Epoch {e+1}: New best model saved with loss {best_loss:.4f}")

    print(f"Epoch {e+1}: Average Loss = {avg_epoch_loss:.4f}")

print("Training complete. Best model saved as 'best_model.pth'.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[126], line 45
#      42         total_loss.backward()
#      43         optimizer.step()
# ---> 45         epoch_loss += total_loss.item()
#      46         num_batches += 1
#      48 avg_epoch_loss = epoch_loss / num_batches
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.plot(epochs,losses)

plt.title('Training Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)

plt.grid(True)

# Ticks and limits
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim([epochs[0], epochs[-1]])
plt.ylim([min(losses) - 0.0001, max(losses) + 0.0001])

# Adding legend
plt.legend(fontsize=12)
plt.savefig('training_loss_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
losses
# Out:
# [1.5455401514967282,
#  0.626105943073829,
#  0.40642163964609307,
#  0.28105447596559924,
#  0.20831531782944998,
#  0.16440350376069546,
#  0.1517342229684194,
#  0.13295108716314039,
#  0.12027530372142792,
#  0.12615111051127315,
#  0.11934168466056387,
#  0.11024447546030085,
#  0.11813130090013146,
#  0.11260472734769185,
#  0.10820523245881002,
#  0.12109996813038985,
#  0.12131860014051199,
#  0.11398331743354599,
#  0.11237289104610682,
#  0.12927746213972569,
#  0.12730633995185295,
#  0.11582780287911494,
#  0.104567083530128,
#  0.10857657250016928,
#  0.10296918793270986,
#  0.10451778909191489,
#  0.10068474477156997,
#  0.10089355396727721,
#  0.11556189848730962,
#  0.10144503833726048,
#  0.1096666428881387,
#  0.1145311021246016,
#  0.12335528650631507,
#  0.11505360358084242,
#  0.09914425093059738,
#  0.1080183860224982,
#  0.11982190453757842,
#  0.10667719909300406,
#  0.09853996988385916,
#  0.10756366420537233,
#  0.11916016104320686,
#  0.12179459724575281,
#  0.1285783713683486,
#  0.10803006589412689,
#  0.09587951004505157,
#  0.09703008690848947,
#  0.10614527963722746,
#  0.09609854857747753,
#  0.09804518908883135,
#  0.09747471582765381,
#  0.09543987285966675,
#  0.09615906436617176,
#  0.11182857025414705,
#  0.11582206965734561,
#  0.10208367680509885,
#  0.09905005215356748,
#  0.10144365842764576,
#  0.09901287670557697,
#  0.09576858238627513,
#  0.09742035856470466,
#  0.1042670610671242,
#  0.0950941212164859,
#  0.10527876609315474,
#  0.10068749993418653,
#  0.10531931820635994,
#  0.10431679462393124,
#  0.11570755826930205,
#  0.09425402044629057,
#  0.09846400516107678,
#  0.09250071442996462,
#  0.09466441596547763,
#  0.09434388872856896,
#  0.08896707743406296,
#  0.0917800017632544,
#  0.0898796059191227,
#  0.09234519644329946,
#  0.09514381100113194,
#  0.09718099655583501,
#  0.09409044155230124,
#  0.09409592160955071,
#  0.09355444336930911,
#  0.09861094069977601,
#  0.10844864991183083,
#  0.09266229734445612,
#  0.09081881027668715,
#  0.11476747396712501,
#  0.10761015675961971,
#  0.09420443046838045,
#  0.09120657000069816,
#  0.10080483322963119,
#  0.09112170493851106,
#  0.09192749687160055,
#  0.09643920868014295,
#  0.09724749019369483,
#  0.08905044818917911,
#  0.09875367085138957,
#  0.09751721161107223,
#  0.10397053540994723,
#  0.09463807598998149,
#  0.09049803825716178,
#  0.1046015575217704,
#  0.09132523695006967,
#  0.08961634493122499,
#  0.09250421666850646,
#  0.09730928220475714,
#  0.08865779855599006,
#  0.0946903876028955,
#  0.08866548802082737,
#  0.087591711897403,
#  0.09105647448450327,
#  0.09610079027091463,
#  0.09189862478524446,
#  0.08815916425858934,
#  0.09005499351769686,
#  0.0873450399376452,
#  0.08856581182529528,
#  0.08808847113202016,
#  0.08764551859349012,
#  0.0886274604126811,
#  0.089623781076322,
#  0.08890802102784316,
#  0.089337392244488,
#  0.08915332580606143,
#  0.0947165375885864,
#  0.08980707700053851,
#  0.10255046871801217,
#  0.09482755713785689,
#  0.09274430402244131,
#  0.09442834199095766,
#  0.09794669427598517,
#  0.10274011129513383,
#  0.09354045987129211,
#  0.10052415014555056,
#  0.10268229277183612,
#  0.08995269580433767,
#  0.08939624857157469,
#  0.09038597888623674,
#  0.09204372437670827,
#  0.09849008700499932,
#  0.0934811313636601,
#  0.0889577620352308,
#  0.08874728080506127,
#  0.0883660518253843,
#  0.08836129043872158,
#  0.08724458143115044,
#  0.08885355588669579,
#  0.09062377999847133,
#  0.08865533722564578,
#  0.09515124342093866,
#  0.10691175640871127,
#  0.09518907374391954,
#  0.09340756696959336,
#  0.08819091754655044,
#  0.09168832842260599,
#  0.09762664791196585,
#  0.11381923733279109,
#  0.08897818919892113,
#  0.0934186374458174,
#  0.09361537965014577,
#  0.09494079711536567,
#  0.09362234283859532,
#  0.09356742134938638,
#  0.08932505423823993,
#  0.09166032836462061,
#  0.09032116147379081,
#  0.09009170113131404,
#  0.08748865438004334,
#  0.08708414016291499,
#  0.09230909605200092,
#  0.09126749355345964,
#  0.08751072346543272,
#  0.08665892854332924,
#  0.08735404644782345,
#  0.08833137853071094,
#  0.08694637365018328,
#  0.08860774089892705,
#  0.08667191630229354,
#  0.08843740324179332,
#  0.08867039515947302,
#  0.08742558164522052,
#  0.0873170845831434,
#  0.08971946081146598,
#  0.08716253641371925,
#  0.08920201426371932,
#  0.08671247555563848,
#  0.09690836723893881,
#  0.08591626506919663,
#  0.0867430898360908,
#  0.09383937049036224,
#  0.10509173075358073,
#  0.09011242461080353,
#  0.08718686100716393,
#  0.09050081049402554,
#  0.0912495544180274,
#  0.08848299303402503,
#  0.08947473283236225,
#  0.08888197736814618,
#  0.08793650676185887,
#  0.08474803188194831,
#  0.08624959674974282]

# %%
model.load_state_dict(torch.load(best_model_path))
model.eval()
difference = []
diff = []
diff_abs = []
diff_percentage = []
difference = np.zeros((len(test_loader),3))
with torch.no_grad():
    for step, batch_tuple in enumerate(test_loader):
        if if_lcmp:
            batch, subgraph = batch_tuple
            sub_atom_idx, sub_edge_idx, sub_edge_ang, sub_index = subgraph
            out_hamil, out_fermi = model(
                batch.x.to(device),
                batch.edge_index.to(device),
                batch.edge_attr.to(device),
                batch.batch.to(device),
                sub_atom_idx.to(device),
                sub_edge_idx.to(device),
                sub_edge_ang.to(device),
                sub_index.to(device)
                    )
            labels_fermi = batch.y.to(device)
            difference[step, 0] = out_fermi.cpu().detach().numpy() - labels_fermi.cpu().detach().numpy()
            difference[step, 1] = abs(out_fermi.cpu().detach().numpy() - labels_fermi.cpu().detach().numpy())
            difference[step, 2] = (out_fermi.cpu().detach().numpy() - labels_fermi.cpu().detach().numpy()) / labels_fermi.cpu().detach().numpy() * 100
            # diff.append(prediction.cpu().detach().numpy() - target_labels.cpu().detach().numpy())
            # diff_abs.append(abs(prediction.cpu().detach().numpy() - target_labels.cpu().detach().numpy()))
            # diff_percentage.append((prediction.cpu().detach().numpy() - target_labels.cpu().detach().numpy()) / target_labels.cpu().detach().numpy() * 100)

# %%
aux = np.hstack((np.array(diff), np.array(diff_abs)))
error = np.hstack((aux, np.array(diff_percentage)))

# %%
difference[:10444asdr44
# Out:
# array([[-0.014853  ,  0.014853  ,  0.40631694],
#        [ 0.00726056,  0.00726056, -0.19868401],
#        [-0.00375366,  0.00375366,  0.10354902],
#        [ 0.0349288 ,  0.0349288 , -0.96217263],
#        [ 0.03263569,  0.03263569, -0.8963322 ],
#        [ 0.00524688,  0.00524688, -0.14373103],
#        [ 0.05943537,  0.05943537, -1.63798606],
#        [-0.00380111,  0.00380111,  0.10389102],
#        [-0.01486969,  0.01486969,  0.40850142],
#        [-0.0042305 ,  0.0042305 ,  0.11637227]])

# %%
import pandas as pd
df = pd.DataFrame({
    "Difference": difference[:10,0],
    "Abs": difference[:10,1],
    "Relative in %": difference[:10,2]
})
styled_df = df.style.set_properties(**{'text-align': 'center'})
display(styled_df)
# Out:
# <style type="text/css">
# #T_94ab4_row0_col0, #T_94ab4_row0_col1, #T_94ab4_row0_col2, #T_94ab4_row1_col0, #T_94ab4_row1_col1, #T_94ab4_row1_col2, #T_94ab4_row2_col0, #T_94ab4_row2_col1, #T_94ab4_row2_col2, #T_94ab4_row3_col0, #T_94ab4_row3_col1, #T_94ab4_row3_col2, #T_94ab4_row4_col0, #T_94ab4_row4_col1, #T_94ab4_row4_col2, #T_94ab4_row5_col0, #T_94ab4_row5_col1, #T_94ab4_row5_col2, #T_94ab4_row6_col0, #T_94ab4_row6_col1, #T_94ab4_row6_col2, #T_94ab4_row7_col0, #T_94ab4_row7_col1, #T_94ab4_row7_col2, #T_94ab4_row8_col0, #T_94ab4_row8_col1, #T_94ab4_row8_col2, #T_94ab4_row9_col0, #T_94ab4_row9_col1, #T_94ab4_row9_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_94ab4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94ab4_level0_col0" class="col_heading level0 col0" >Difference</th>
#       <th id="T_94ab4_level0_col1" class="col_heading level0 col1" >Abs</th>
#       <th id="T_94ab4_level0_col2" class="col_heading level0 col2" >Relative in %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94ab4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94ab4_row0_col0" class="data row0 col0" >-0.014853</td>
#       <td id="T_94ab4_row0_col1" class="data row0 col1" >0.014853</td>
#       <td id="T_94ab4_row0_col2" class="data row0 col2" >0.406317</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94ab4_row1_col0" class="data row1 col0" >0.007261</td>
#       <td id="T_94ab4_row1_col1" class="data row1 col1" >0.007261</td>
#       <td id="T_94ab4_row1_col2" class="data row1 col2" >-0.198684</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94ab4_row2_col0" class="data row2 col0" >-0.003754</td>
#       <td id="T_94ab4_row2_col1" class="data row2 col1" >0.003754</td>
#       <td id="T_94ab4_row2_col2" class="data row2 col2" >0.103549</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94ab4_row3_col0" class="data row3 col0" >0.034929</td>
#       <td id="T_94ab4_row3_col1" class="data row3 col1" >0.034929</td>
#       <td id="T_94ab4_row3_col2" class="data row3 col2" >-0.962173</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94ab4_row4_col0" class="data row4 col0" >0.032636</td>
#       <td id="T_94ab4_row4_col1" class="data row4 col1" >0.032636</td>
#       <td id="T_94ab4_row4_col2" class="data row4 col2" >-0.896332</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94ab4_row5_col0" class="data row5 col0" >0.005247</td>
#       <td id="T_94ab4_row5_col1" class="data row5 col1" >0.005247</td>
#       <td id="T_94ab4_row5_col2" class="data row5 col2" >-0.143731</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94ab4_row6_col0" class="data row6 col0" >0.059435</td>
#       <td id="T_94ab4_row6_col1" class="data row6 col1" >0.059435</td>
#       <td id="T_94ab4_row6_col2" class="data row6 col2" >-1.637986</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94ab4_row7_col0" class="data row7 col0" >-0.003801</td>
#       <td id="T_94ab4_row7_col1" class="data row7 col1" >0.003801</td>
#       <td id="T_94ab4_row7_col2" class="data row7 col2" >0.103891</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94ab4_row8_col0" class="data row8 col0" >-0.014870</td>
#       <td id="T_94ab4_row8_col1" class="data row8 col1" >0.014870</td>
#       <td id="T_94ab4_row8_col2" class="data row8 col2" >0.408501</td>
#     </tr>
#     <tr>
#       <th id="T_94ab4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94ab4_row9_col0" class="data row9 col0" >-0.004230</td>
#       <td id="T_94ab4_row9_col1" class="data row9 col1" >0.004230</td>
#       <td id="T_94ab4_row9_col2" class="data row9 col2" >0.116372</td>
#     </tr>
#   </tbody>
# </table>
